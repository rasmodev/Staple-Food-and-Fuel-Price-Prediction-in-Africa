# %% [markdown]
# <h2 style="text-align: center;">PREDICTIVE ANALYSIS AND FORECASTING OF STAPLE FOOD AND FUEL PRICES ACROSS AFRICA: A COMPREHENSIVE DATA-DRIVEN APPROACH USING MACHINE LEARNING</h2>
#
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://www.welthungerhilfe.org/fileadmin/_processed_/9/8/csm_Simbabwe_Marktstand_WHH_5647936c7a.jpg" width="600">
# </div>

# %% [markdown]
# # 1. Introduction
# ---

# %% [markdown]
# ## 1.1. Background:
# ---

# %% [markdown]
# Kenya, like many African nations, has experienced significant challenges due to fluctuating staple food and fuel prices. These price instabilities have a profound impact on the country's economy, exacerbating poverty and inequality. Monitoring staple food prices is crucial for understanding food security and economic stability, as these prices reflect the availability and accessibility of essential commodities, directly affecting the well-being of populations. The `Famine Early Warning Systems Network (FEWS NET)` plays a critical role in gathering and disseminating price data across several countries. By analyzing historical price patterns and identifying key determinants of price fluctuations using FEWS NET's comprehensive dataset, we can support informed decision-making and policy interventions. This data is integral for assessing food security and guiding policy decisions in countries with significant food security challenges. Understanding the underlying factors driving price fluctuations is essential for improving economic stability and food security outcomes in Kenya and beyond.

# %% [markdown]
# ## 1.2. Research Problem:
# ---

# %% [markdown]
# Kenya has faced significant economic challenges due to rising food and fuel prices, particularly since the Kenya Kwanza regime assumed office in August 2022. This increase in costs has severely impacted the livelihoods of its citizens, leading to widespread protests and public discontent. The government attributes these rising prices to factors such as the removal of fuel subsidies, global economic shocks, and the ongoing Russia-Ukraine conflict. Conversely, critics argue that government mismanagement and ineffective economic policies are to blame. In response to the crisis, the Kenyan government has implemented various measures, including increasing subsidies and introducing new social programs. However, these interventions have not fully addressed the public's concerns, and anti-government protests persist. To better understand and address these issues, analyzing and predicting food and fuel price trends is essential. By including data from other developing countries, we can gain insights into regional and global price dynamics, providing a comparative context for understanding Kenya's situation. This project aims to leverage an extensive dataset to forecast future price trends, identify patterns, and assess the impact of various economic factors. This approach will help develop effective strategies to mitigate the economic impact on Kenyan citizens and improve food security policies both locally and globally.

# %% [markdown]
# ## 1.3. Objectives:
# ---

# %% [markdown]
# i. Identify and analyze factors influencing the price of staple foods and fuels in the countries listed in the dataset.
#
# ii. Utilize data preprocessing, EDA, and machine learning techniques to build and evaluate predictive models for price forecasting.
#
# iii. Develop time series forecasting models for predicting future prices.
#
# iv. Deploy the best-performing model as a web-application to enable real-time predictions.
#
# v. Complete the analysis, model training, and deployment by 31st July 2024.

# %% [markdown]
# ## 1.4. Hypothesis:
# ---

# %% [markdown]
# **Hypothesis:** Influence of Region on Price
#    - **Null Hypothesis (H₀):** There is no significant difference in prices based on the administrative regions or countries.
#
#    - **Alternative Hypothesis (H₁):** There is a significant difference in prices based on the administrative regions or countries.

# %% [markdown]
# # 2. Methodology, Results and Discussion
# ---

# %% [markdown]
# ## 2.1. Data Description
#
# | Column            | Description                                       |
# |-------------------|---------------------------------------------------|
# | `country`         | Country where the data was collected.            |
# | `market`          | Specific market or city within the country where the product's price was recorded.           |
# | `admin_1`         | Administrative region or province within the country.                 |
# | `longitude`       | Longitude coordinate (geographical coordinate indicating the east-west position) of the location where the price was recorded.             |
# | `latitude`        | Latitude coordinate (geographical coordinate indicating the north-south position) of the location where the price was recorded.          |
# | `cpcv2`           | Product code associated with the item being priced.                                     |
# | `product`         | Name of the product or commodity (staple food or fuel).                  |
# | `source_document` | Source of the data document providing the price information.                    |
# | `period_date`     | Date when the price was recorded.                       |
# | `price_type`      | Describes the pricing type (e.g. retail, wholesale).                     |
# | `product_source`  | Indicates the origin or provider of the product (e.g., Local).                                               |
# | `unit`            | Unit of measurement (e.g., kg, L).                |
# | `unit_type`       | Type of unit (e.g., Weight, Volume).             |
# | `currency`        | Currency code for the currency in which the price is recorded (e.g., KES for Kenyan Shilling).                       |
# | `value`           | Numerical value representing the price value of the product.                      |

# %% [markdown]
# The dataset under examination is sourced from the Famine Early Warning Systems Network (FEWS NET), a global organization that monitors and provides data on staple food and fuel prices. The dataset spans from January 31, 1995, to May 31, 2024, encompassing a comprehensive collection of price data for various products across multiple countries, reflecting significant regional and global influence. The data covers regions such as Southern Africa (Angola, Malawi, Zimbabwe), East Africa (Kenya, Djibouti, Ethiopia, Somalia, South Sudan), West Africa (Mauritania, Nigeria), Central Africa (Chad, The Democratic Republic of Congo) and Haiti from the Caribbean region. The data was gathered through direct field enumeration by FEWS NET staff and contributions from national and international partners. Enumerators collected the data in various local markets, ensuring accuracy through routine verification processes. The dataset includes information on staple foods and fuels, with variables indicating the product type, market location, administrative region, and price details.

# %% [markdown]
# **Data Source:** https://fews.net/staple-food-price-data
#
# ---

# %% [markdown]
# ## 2.2. Methodology

# %% [markdown]
# To achieve the project objectives, we will follow the Cross-Industry Standard Process for Data Mining (CRISP-DM) framework, a process used to guide the machine learning lifecycle.
#
# <div style="text-align: center;">
#     <img src="https://th.bing.com/th/id/R.76331bc842a9190a03f9ce4b46cb0c63?rik=R45rDR%2b53hANOQ&pid=ImgRaw&r=0" width="600">
# </div>
#
# It is a six-phase process consisting of these key phases:
#
# i. **Business Understanding**:
#    - Understand the problem of predicting staple food and fuel prices and its significance.
#    - Define the project objectives, including analyzing and forecasting food and fuel prices to support decision-making and intervention strategies for food security.
#
# ii. **Data Understanding**:
#    - Load the dataset "Staple_Food_Price_Data.xlsx".
#    - Explore the dataset and variable descriptions.
#    - Conduct detailed Exploratory Data Analysis (EDA), including univariate, bivariate, and multivariate analysis, and perform hypothesis testing if applicable to validate assumptions.
#
# iii. **Data Preparation**:
#    - Clean the dataset by handling missing values, duplicates, outliers, and inconsistencies.
#    - Encode categorical variables and perform feature engineering to prepare the data for machine learning modeling.
#    - Select relevant variables and transform data as needed to prepare the dataset for modeling.
#
# iv. **Modeling**:
#    - Split the dataset into training and validation sets to facilitate model training and evaluation.
#    - Select and implement suitable regression algorithms (e.g., Linear Regression, Random Forest Regression, Gradient Boosting Regression) for predicting staple food and fuel prices.
#    - Train the models on the prepared dataset.
#
# v. **Evaluation**:
#    - Assess the models' performance using metrics like RMSE and MAE.
#    - Fine-tune the model hyperparameters using techniques like grid search or random search to optimize performance.
#    - Use the best-performing model to make predictions on the test set.
#
# vi. **Deployment**:
#    - Deploy the trained model as a web application for real-time prediction or using .ke Streamlit, Gradio, or FastAPI.
#
# ---
# By following the CRISP-DM framework, we aim to create a robust model for predicting staple food and fuel prices, leveraging detailed EDA to inform the data preparation and modeling stages, ensuring accurate and reliable predictions for stakeholders.

# %% [markdown]
# ### Setup

# %% [markdown]
# #### Installations

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\user\anaconda3\lib\site-packages (0.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importation

# %%
# Data Handling
import numpy as np
import pandas as pd
import seaborn as sns
import requests
from dotenv import dotenv_values

# Visualization
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.patches as mpatches
import seaborn as sns
import plotly.express as px

# Statistical Analysis
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.tsa.stattools import adfuller
from scipy.stats import ttest_ind
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error

# Feature Processing
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# Modelling
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import RandomizedSearchCV
import pickle

# Other Packages
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Loading

# %% [markdown]
# ### Loading the data

# %%
# read the data from the excel file
df = pd.read_excel("data/Staple_Food_Price_Data.xlsx")

# Display an overview of the dataset
df.head()
# Out:
#   country            market admin_1  longitude  latitude     cpcv2  \
# 0  Angola  Huambo, Alemanha     NaN    15.7365  -12.7716  R01701AA
# 1  Angola  Huambo, Alemanha     NaN    15.7365  -12.7716  R01701AA
# 2  Angola  Huambo, Alemanha     NaN    15.7365  -12.7716  R01701AA
# 3  Angola  Huambo, Alemanha     NaN    15.7365  -12.7716  R01701AA
# 4  Angola  Huambo, Alemanha     NaN    15.7365  -12.7716  R01701AA
#
#          product                                    source_document  \
# 0  Beans (mixed)  Famine Early Warning Systems Network (FEWS NET...
# 1  Beans (mixed)  Famine Early Warning Systems Network (FEWS NET...
# 2  Beans (mixed)  Famine Early Warning Systems Network (FEWS NET...
# 3  Beans (mixed)  Famine Early Warning Systems Network (FEWS NET...
# 4  Beans (mixed)  Famine Early Warning Systems Network (FEWS NET...
#
#   period_date price_type product_source unit unit_type currency    value
# 0  2013-12-31     Retail          Local   kg    Weight      AOA  229.670
# 1  2014-01-31     Retail          Local   kg    Weight      AOA  221.355
# 2  2014-02-28     Retail          Local   kg    Weight      AOA  228.385
# 3  2014-03-31     Retail          Local   kg    Weight      AOA  221.740
# 4  2014-04-30     Retail          Local   kg    Weight      AOA  219.785

# %% [markdown]
# The dataset contains `time series data`, a type of data where each observation is recorded at a specific point in time. These observations have also been collected at regular intervals.

# %% [markdown]
# # 2.3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 2.3.1. Understanding the datasets

# %% [markdown]
# An in-depth exploration of the datasets is presented to gain insights into the available variables,their distributions and relationships. This step will provide an initial undertanding of the datasets to identify any data quality issues that will inform the cleaning and pre-processing.

# %% [markdown]
# ### i. Shape of The Datasets

# %%
# View the shape of the dataset
df.shape
# Out:
# (1011744, 15)

# %% [markdown]
# The dataset contains 1,011,744 rows and 15 columns.
#
# ----

# %% [markdown]
# ### ii. Column Information of The Dataset

# %%
# Get the column information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011744 entries, 0 to 1011743
# Data columns (total 15 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   country          1011744 non-null  object
#  1   market           1011744 non-null  object
#  2   admin_1          1010464 non-null  object
#  3   longitude        1011744 non-null  float64
#  4   latitude         1011744 non-null  float64
#  5   cpcv2            1011744 non-null  object
#  6   product          1011744 non-null  object
#  7   source_document  1011744 non-null  object
#  8   period_date      1011744 non-null  object
#  9   price_type       1011744 non-null  object
#  10  product_source   1011744 non-null  object
#  11  unit             1011744 non-null  object
#  12  unit_type        1011744 non-null  object
#  13  currency         1011744 non-null  object
#  14  value            806586 non-null   float64
# dtypes: float64(3), object(12)
# memory usage: 115.8+ MB

# %% [markdown]
# - The dataset contains 1,011,744 entries and 15 columns:  `country`, `market`, `admin_1`, `longitude`, `latitude`, `cpcv2`, `product`, `source_document`, `period_date`, `price_type`, `product_source`, `unit`, `unit_type`, `currency`, and `value`.
# - The `admin_1` column has 101,0464 non-null values out of 1,011,744 total entries, indicating missing values for some records.
# - The `period_date` column is of type object and needs to be converted to a datetime data type for further analysis.
# - The `value` column is the target variable, representing the prices of products, and contains 806,586 non-null entries, indicating some missing values.
# - The dataset will be used to analyze and forecast prices of staple foods and fuels. The model will utilize these features to predict the `value` column. accuracy.
#
# ---

# %% [markdown]
# ### iii. Transforming the 'period_date' column to datetime format

# %%
# Converting the 'date' column in the datasets to datetime format
# Train dataset
df['period_date'] = pd.to_datetime(df['period_date'])

# %%
# Confirm the data type of the 'date' column after transformation
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011744 entries, 0 to 1011743
# Data columns (total 15 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   country          1011744 non-null  object
#  1   market           1011744 non-null  object
#  2   admin_1          1010464 non-null  object
#  3   longitude        1011744 non-null  float64
#  4   latitude         1011744 non-null  float64
#  5   cpcv2            1011744 non-null  object
#  6   product          1011744 non-null  object
#  7   source_document  1011744 non-null  object
#  8   period_date      1011744 non-null  datetime64[ns]
#  9   price_type       1011744 non-null  object
#  10  product_source   1011744 non-null  object
#  11  unit             1011744 non-null  object
#  12  unit_type        1011744 non-null  object
#  13  currency         1011744 non-null  object
#  14  value            806586 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(11)
# memory usage: 115.8+ MB

# %% [markdown]
# The `period_date` columns in the dataset is now formatted correctly.

# %% [markdown]
# ### iv. Summary statistics of the datasets

# %%
# Checking for the summary statistics of the dataset 
df.describe().round(3).T
# Out:
#                  count                           mean                  min  \
# longitude    1011744.0                         -4.539              -74.114
# latitude     1011744.0                         10.895              -20.147
# period_date    1011744  2018-06-10 10:28:23.415883776  1995-01-31 00:00:00
# value         806586.0                      41194.111                  0.0
#
#                              25%                  50%                  75%  \
# longitude                 -71.72                9.583               29.195
# latitude                   7.383                 11.6               18.235
# period_date  2015-11-04 00:00:00  2019-12-10 00:00:00  2022-05-25 00:00:00
# value                      140.0               416.67               6000.0
#
#                              max         std
# longitude                  50.23      42.685
# latitude                  20.946       7.481
# period_date  2024-05-31 00:00:00         NaN
# value                 26300000.0  421937.949

# %% [markdown]
# - The `value` column contains a **high maximum value (26,300,000.0)** which is substantially higher than the **mean (41,194.111)** and the **75th percentile (6,000)**. This suggests the presence of extreme outliers or erroneous data points. These anomalies could skew statistical analyses and model performance, necessitating further investigation and potential cleaning to improve data reliability.
#
# - **: The `period_date` column is of type `datetime64[ns]`, which is a special data type used to handle dates and times. Statistical measures lan, standard deviaance do not apply to datetime columns as they do for numeric colu Therefore, the: The `NaN` for `std` is expected in this case because it's not meaningful to calculate the standard deviation for datetime p with the converted data or further analysis, let me know!

# %% [markdown]
# ### iv.  Checking For Duplicate Values in The Dataset

# %%
# Check for duplicates in the dataset
df_duplicates = df[df.duplicated()]

# Display the duplicate rows in the dataset, if any
if not df_duplicates.empty:
    print("Duplicate Rows in Dataset:")
    display(df_duplicates)
else:
    print("No Duplicate Rows in Dataset")
# Out:
# No Duplicate Rows in Dataset

# %% [markdown]
# The dataset has no duplicate records in the dataset.
#
# ---

# %% [markdown]
# ### v. Checking The Unique Values in The Datasets¶

# %% [markdown]
# We proceed to examine unique values in the dataset to identify any inconsistencies, unusual characters or symbols (e.g., "NA" vs "?") representing missing data and standardize the dataset to ensure it is reliable and ready for further analysis.

# %%
# Define The datasets
datasets = {'data': df}

# Define a function to print unique values for columns in the datasets
def print_unique_categorical(datasets):
  
  # Check if column is categorical (object dtype)  
  for col in datasets.select_dtypes(include='object'):
    underline = '-' * len(f"Column: {col}")
    print(f"Column: {col}")
    print(underline)
    
    # Print unique values
    unique_values = datasets[col].unique()
    print(f"Unique Values: {unique_values}")
    print()

# %%
# Print unique values for categorical columns in the dataset.
print("Unique values in categorical columns in the dataset):")
print("=" * 53) 
print_unique_categorical(df)
# Out:
# Unique values in categorical columns in the dataset):
# =====================================================
# Column: country
# ---------------
# Unique Values: ['Angola' 'Chad' 'Congo, The Democratic Republic of the' 'Djibouti'
#  'Ethiopia' 'Haiti' 'Kenya' 'Malawi' 'Mauritania' 'Nigeria' 'Somalia'
#  'South Sudan' 'Zimbabwe']
#
# Column: market
# --------------
# Unique Values: ['Huambo, Alemanha' 'Luanda, 30 Market' 'Lubango, Joao de Almeida'
#  'Abeche' 'Amtiman' 'Bagasola' 'Biltine' 'Bol' 'Bongor' 'Faya' 'Kelo'
#  'Mao' 'Mongo' 'Moundou' 'Moussoro' "N'Djamena" 'Pala' 'Peni' 'Sarh'
#  'Beni, Kilokwa' 'Bukavu, Kadutu (Central)' 'Bunia, Marché Central'
#  'Gbadolite, Marché Central' 'Goma, Virunga (Central)'
#  'Inongo, Marché Central' 'Kalemie, Lukuga' 'Kananga, Ndesha'
#  'Kasumbalesa, Marché Central' 'Kikwit, Marché Central' 'Kindu, Mama Yemo'
#  'Kinshasa, Central' 'Kinshasa, Marché de Matadi Kibala'
#  'Kinshasa, Marché de Somba Zigida' 'Kisangani, Marché du 24 Novembre'
#  'Lubumbashi, Laurent Kabila' 'Lusambo, Marché Central'
#  'Matadi, Marché Central' 'Mbadaka, Marché Central'
#  'Mbuji-mayi, Marché Central' 'Tshikapa, Kamalengo' 'Uvira, Maendeleo'
#  'Djibouti City' 'Addis Ababa, Merkato' 'Awash' 'Bahir Dar' 'Beddenno'
#  'Chereti' 'Degehabour' 'Dessie' 'Dire Dawa, Kezira' 'Gambella' 'Gode'
#  'Jinka' 'Logia' 'Mekele' 'Nazareth, Adama' 'Nekemte' 'Sekota'
#  'Shashemene' 'Shire' 'Sikela' 'Sodo' 'Warder' 'Yabelo' 'Cap Haitien'
#  'Cayes' 'Fond-des-Negres' 'Gonaives' 'Hinche' 'Jacmel' 'Jeremie'
#  'Ouanaminthe' 'Port-au-Prince, Croix-de-Bossales' 'Port-de-Paix'
#  'Nairobi' 'Balaka' 'Jenda' 'Karonga' 'Lilongwe' 'Lunzu' 'Mangochi'
#  'Mitundu' 'Mzuzu' 'Nsanje, Nsanje Boma' 'Ntcheu' 'Phalombe' 'Salima'
#  'Adel Bagrou' 'Aoujeft' 'Boghé' 'Kankossa' 'Magta-lahjar' 'Nouadhibou'
#  'Nouakchott, Marché SCIM' 'Tintane' 'Toufoude Cive' 'Aba' 'Aba, Akwete'
#  'Aba, Udele' 'Biu' 'Damaturu' 'Dandume' 'Geidam, Kasuwan Shanu' 'Giwa'
#  'Gombe' 'Gombe, Tiken Shanu' 'Gujungu' 'Gujungu, Kara' 'Gwandu, Dodoru'
#  'Ibadan, Akinyele' 'Ibadan, Bodija' 'Ilela, Kara Shanu' 'Kano, Dawanau'
#  'Kaura Namoda' 'Lagos, Kara' 'Lagos, Mile 12' 'Maiadua' 'Maiduguri'
#  'Maiduguri, Kasuwan Shanu' 'Maigatari, Kara' 'Mubi' 'Mubi, Tike'
#  'Port-Harcourt, Trans-Amadi' 'Potiskum' 'Potiskum, Tike' 'Saminaka'
#  'Abudwak' 'Adanyabal' 'Afgoi' 'Afmadow' 'Baidoa' 'Bardera' 'Beled Hawa'
#  'Beled Weyn' 'Borama' 'Bossaso' 'Buale' 'Burao' 'Dhusamareb' 'Dinsor'
#  'Doblei' 'El Barde' 'El Dhere' 'Elwak' 'Erigavo' 'Galkayo' 'Garowe'
#  'Hara Dhere' 'Hargeisa' 'Hudur' 'Iskushuban' 'Jamame' 'Jilib' 'Jowhar'
#  'Kismayo' 'Lasanod' 'Lugh' 'Merka' 'Mogadishu, Bakara' 'Qansah Dere'
#  'Qorioley' 'Saakow' 'Togwajale' 'Wanle Weyne' 'Zeilac/Lawayacado' 'Aweil'
#  'Bor' 'Fangak' 'Juba, Konyokonyo' 'Kapoeta' 'Leer' 'Maiwut'
#  'Malakal, Aburoc' 'Meyendit' 'Pibor' 'Poktap' 'Torit' 'Wau' 'Yei'
#  'Bulawayo, Renkini' 'Gweru, Kombayi' 'Harare, Mbare' 'Masvingo, Mucheke'
#  'Mutare, Sakubva']
#
# Column: admin_1
# ---------------
# Unique Values: [nan 'Ouaddai' 'Salamat' 'Kanem' 'Wadi Fira' 'Lac' 'Mayo-Kebbi Est'
#  'Borkou' 'Tandjile' 'Guera' 'Logone Oriental' 'Barh el Gazel' "N'Djamena"
#  'Mayo-Kebbi Ouest' 'Mandoul' 'Moyen-Chari' 'North Kivu' 'South Kivu'
#  'Ituri' 'North Ubangi' 'Mai-Ndombe' 'Tanganyika' 'Kasai-Central'
#  'Haut-Katanga' 'Kwilu' 'Maniema' 'Kinshasa' 'Tshopo' 'Sankuru'
#  'Kongo-Central' 'Equateur' 'Kasai-Oriental' 'Kasai' 'Addis Ababa' 'Afar'
#  'Amhara' 'Oromia' 'Somali' 'Dire Dawa' 'Gambela' 'South Ethiopia'
#  'Tigray' 'Nord' 'Sud' 'Nippes' 'Artibonite' 'Centre' 'Sud-Est'
#  "Grand'Anse" 'Nord-Est' 'Ouest' 'Nord-Ouest' 'Nairobi' 'Southern'
#  'Northern' 'Central' 'Hodh ech Chargui' 'Adrar' 'Brakna' 'Assaba'
#  'Dakhlet Nouadhibou' 'Nouakchott' 'Hodh el Gharbi' 'Gorgol' 'Abia'
#  'Borno' 'Yobe' 'Katsina' 'Kaduna' 'Gombe' 'Jigawa' 'Kebbi' 'Oyo' 'Sokoto'
#  'Kano' 'Zamfara' 'Lagos' 'Adamawa' 'Rivers' 'Galgaduud' 'Middle Shabelle'
#  'Lower Shabelle' 'Lower Juba' 'Bay' 'Gedo' 'Hiiraan' 'Awdal' 'Bari'
#  'Middle Juba' 'Togdheer' 'Bakool' 'Sanaag' 'Mudug' 'Nugaal'
#  'Woqooyi Galbeed' 'Sool' 'Banaadir' 'Northern Bahr el Ghazal' 'Jonglei'
#  'Central Equatoria' 'Eastern Equatoria' 'Unity' 'Upper Nile'
#  'Western Bahr el Ghazal' 'Bulawayo' 'Midlands' 'Harare' 'Masvingo'
#  'Manicaland']
#
# Column: cpcv2
# -------------
# Unique Values: ['R01701AA' 'R01592AA' 'R01122AC' 'P23130AA' 'R01591AA' 'L02121AE'
#  'L02111AB' 'L02151AB' 'R01709AE' 'P33360AA' 'P33310AA' 'L02123AD'
#  'P21421AA' 'P23710AH' 'R01182AD' 'R01253AA' 'P23520AA' 'P21549AA'
#  'P23161AG' 'P23161AA' 'R01444AB' 'L02122AD' 'R01142AT' 'R01142AC'
#  'R01142AD' 'P23710AA' 'P23110AA' 'R01701AF' 'P21393AA' 'P23170AA' 'S8AA'
#  'L02111AH' 'P34510AA' 'R01640AA' 'P03130AA' 'L02123AH' 'R01122AB'
#  'P23130AG' 'P23130AF' 'P21535AA' 'R01610AE' 'L02140AB' 'R01970AA'
#  'P33341AA' 'P23120AA' 'R01701BD' 'L02121AB' 'L02123AB' 'R01702AB'
#  'R01190AA' 'L02111AO' 'L02122AP' 'R01142AE' 'R01112AA' 'R01701AC'
#  'R01701AU' 'R01701AR' 'R01701AG' 'P23130AE' 'P23130AD' 'P22229AA'
#  'P22229AB' 'P21549AD' 'P21549AF' 'P21549AH' 'P21549AE' 'P21549AI'
#  'P21549AG' 'P23163AD' 'P23161AH' 'P23163AC' 'P23163AB' 'P23163AA'
#  'P23163AE' 'P16200AA' 'R01142AA' 'P23710AC' 'P23710AG' 'P23710AD'
#  'P23710AF' 'P23710AE' 'P23530AA' 'P23995AD' 'P23995AE' 'P23995AC'
#  'P23490AA' 'P22110AA' 'R01709AF' 'P21111AA' 'P21117AA' 'L02121AD'
#  'L02111AK' 'L02111AG' 'P21231AB' 'L02123AG' 'R01182AA' 'P21115AA'
#  'P23710AB' 'P39120AC' 'P23161AB' 'R01913AB' 'L02122AF' 'R01142AL'
#  'R01142AM' 'R01142AN' 'P39120AB' 'P22211AA' 'R01913AC' 'P33410AA'
#  'R01709AA' 'R01709AC' 'P23170AC' 'P23170AB' 'P21545AA' 'R01142AB'
#  'R01593AA' 'L02111AI' 'L02123AJ' 'L02122AJ' 'P02293AA' 'R01709AB'
#  'P23161AT' 'R01620AA' 'P18000AA' 'L02123AC' 'S88161AA' 'P35322AA'
#  'R01701AP' 'R01701AM' 'L02151AC' 'R01704AC' 'R01422AA' 'R01424AA'
#  'P23120AC' 'L02122AG' 'R01142AH' 'P23130AB']
#
# Column: product
# ---------------
# Unique Values: ['Beans (mixed)' 'Cassava' 'Maize Grain (White)' 'Maize Meal'
#  'Sweet Potatoes' 'Camels (Male, Average)'
#  'Cattle (Male, 2-3 years old, Local Quality)' 'Chickens'
#  'Cowpeas (Mixed)' 'Diesel' 'Gasoline'
#  'Goats (Male, Medium-sized, Castrated)' 'Groundnuts (Shelled)' 'Macaroni'
#  'Millet (Pearl)' 'Onions' 'Refined sugar' 'Refined Vegetable Oil'
#  'Rice (5% Broken)' 'Rice (Milled)' 'Sesame (White)'
#  'Sheep (Male, Medium-sized, Castrated)' 'Sorghum (Berbere)'
#  'Sorghum (Red)' 'Sorghum (White)' 'Spaghetti' 'Wheat Flour'
#  'Beans (White)' 'Cassava Chips' 'Cassava Flour'
#  'Casual Labor (unskilled, daily, without food)'
#  'Cattle (Medium-sized bull)' 'Charcoal' 'Cocoa' 'Firewood'
#  'Goats (Adult, Male, Medium-sized)' 'Maize Grain (Yellow)'
#  'Maize Meal (White)' 'Maize Meal (Yellow)' 'Palm oil, crude'
#  'Parchment Coffee' 'Pig (Adult, Male, Medium-sized)'
#  'Tobacco (unspecified)' 'Kerosene' 'Sorghum Flour' 'Beans (Haricot)'
#  'Camels (Local Quality)' 'Goats (Local Quality)' 'Horse beans'
#  'Mixed Teff' 'Oxen (Local Quality)' 'Sheep (Local Quality)'
#  'Sorghum (Yellow)' 'Wheat Grain' 'Beans (Black)' 'Beans (Lima)'
#  'Beans (Pinto)' 'Beans (Red)' 'Maize Meal (Alberto)'
#  'Maize Meal (Gradoro)' 'Milk (Bongu)' 'Milk (Vita)'
#  'Refined Vegetable Oil (Alberto)' 'Refined Vegetable Oil (Bongu)'
#  'Refined Vegetable Oil (Gourmet)' 'Refined Vegetable Oil (Rika)'
#  'Refined Vegetable Oil (Sinistre)' 'Refined Vegetable Oil (Ti malice)'
#  'Rice (10/10)' 'Rice (4% Broken)' 'Rice (Bongu)' 'Rice (Mega)'
#  'Rice (Tchako)' 'Rice (TCS)' 'Salt' 'Sorghum' 'Spaghetti (Bongu)'
#  'Spaghetti (Gourmet)' 'Spaghetti (Itala)' 'Spaghetti (Lavagi)'
#  'Spaghetti (Vita)' 'Sugar (Cream)' 'Tomato Paste (Famoza)'
#  'Tomato Paste (Laperla)' 'Tomato Paste (Rika)' 'Bread'
#  "Cow's Milk (Fresh, Pasteurized)" 'Pigeon Peas'
#  'Beef (Fresh bovine meat)' 'Camel Meat' 'Camels (Female, Average)'
#  'Cattle (Male, 1-2 years old, Uncastrated)' 'Cattle (Medium-sized cow)'
#  'Fish (Dried, Yay Boy)' 'Goats (Female, Medium-sized)' 'Millet'
#  'Mutton (Sheep)' 'Pasta (Mixed)' 'Rakhel (Feed)' 'Rice (100% Broken)'
#  'Rice Straw' 'Sheep (1 year old, Female)' 'Sorghum (Bichna, Mixed))'
#  "Sorghum (R'haya, Brown)" 'Sorghum (Taghalit, Mixed)' 'Wheat bran'
#  'Whole milk powder' 'Wild Straw' 'Propane and butanes, liquefied'
#  'Cowpeas (Brown)' 'Cowpeas (White)' 'Gari (White)' 'Gari (Yellow)'
#  'Palm Oil (Refined)' 'Sorghum (Brown)' 'Yams' 'Cattle (Male)'
#  'Goats (Male)' 'Sheep (Male)' "Camel's Milk (Raw)" 'Cowpeas (Red)'
#  'Rice (Parboiled)' 'Tea leaves (Mixed)' 'Water (potable, drinking)'
#  'Goats (Export Quality)' 'Grain milling services' 'Soap' 'Beans (Brown)'
#  'Beans (Yellow)' 'Chickens (Live)' 'Dry Lentils' 'Groundnuts (In Shell)'
#  'Groundnut (without shell)' 'Maize Flour'
#  'Sheep (2-3 years, Average Quality)' 'Sorghum (Feterita)'
#  'Roller Maize Meal']
#
# Column: source_document
# -----------------------
# Unique Values: ['Famine Early Warning Systems Network (FEWS NET), Angola, Price'
#  'Famine Early Warning Systems Network (FEWS NET), Chad, Price (weekly)'
#  'Famine Early Warning Systems Network (FEWS NET), Democratic Republic of the Congo, Price (weekly)'
#  'Famine Early Warning Systems Network (FEWS NET), Djibouti, Price'
#  'Famine Early Warning Systems Network (FEWS NET), Ethiopia, Price (weekly)'
#  'Coordination Nationale de la Sécurité Alimentaire (CNSA)/Famine Early Warning Systems Network (FEWS NET), Haiti, Price'
#  'Famine Early Warning Systems Network (FEWS NET), Kenya, Price'
#  'Ministry of Agriculture and Food Security (MoAFS)/Famine Early Warning Systems Network (FEWS NET), Malawi, Price (weekly)'
#  'Famine Early Warning Systems Network (FEWS NET), Mauritania, Price'
#  'Famine Early Warning Systems Network (FEWS NET), Nigeria, Price (weekly)'
#  'Famine Early Warning Systems Network (FEWS NET), Nigeria, Livestock Price (weekly)'
#  'Food Security and Nutrition Analysis Unit/Famine Early Warning Systems Network (FSNAU/FEWS NET), Somalia, Price'
#  'Famine Early Warning Systems Network (FEWS NET), South Sudan, Price'
#  'Famine Early Warning Systems Network (FEWS NET), Zimbabwe, Price (USD)'
#  'Famine Early Warning Systems Network (FEWS NET), Zimbabwe, Price (ZWL)']
#
# Column: price_type
# ------------------
# Unique Values: ['Retail' 'Wage' 'Wholesale']
#
# Column: product_source
# ----------------------
# Unique Values: ['Local' 'Import']
#
# Column: unit
# ------------
# Unique Values: ['kg' 'ea' 'L' '500_g' '400_g' 'day' 'pile' '6_lb' 'bag' 'gal' '170_g'
#  '350_g' '226.8_g' '500_ml' '2_kg' '50_kg' '12_kg' '100_kg' '30_L'
#  '100_tubers' '60_tubers' '200_L' '3.5_kg' '90_kg' '700_g' '125_g']
#
# Column: unit_type
# -----------------
# Unique Values: ['Weight' 'Item' 'Volume']
#
# Column: currency
# ----------------
# Unique Values: ['AOA' 'XAF' 'CDF' 'DJF' 'ETB' 'HTG' 'KES' 'MWK' 'MRU' 'NGN' 'SOS' 'SLS'
#  'SSP' 'USD' 'ZWL']

# %% [markdown]
# ---
#
# From the analysis of unique values of categorical columns. The following are the observations:
#
# ---
#
# **a. Columns to Drop:**
#
# - **`source_document`**:
# The column contains metadata about the source of the data, which is not directly relevant to the analysis or modelling since the analysis is focused on price trends and comparisons without needing to know the source of each data point.
#
# - **`unit_type`**:
# Indicates whether the unit is related to weight, volume, or items. The `unit` column already provides sufficient information about the type of measurement (e.g., weight, volume); the `unit_type` column is, therefore, the column is redundant.
#
# ---

# %%
# Create a copy of the dataframe
df = df.copy()

# Dropping Columns
columns_to_drop = ['source_document', 'unit_type']
df = df.drop(columns=columns_to_drop)

# %% [markdown]
# The unnecessary columns have been dropped.
#
# ---

# %% [markdown]
# **b. Columns to Rename:**
#
# - **`cpcv2`** → **`product_code`**:
# The term `cpcv2` is unclear. Renaming it to `product_code` makes it explicit that this column contains each product's unique code or identifier.
#
# - **`admin_1`** → **`administrative_region`**:
# `admin_1` is vague/ambiguous. Changing it to `administrative_region` better describes its role as representing a specific administrative division within the country.
#
# - **`price_type`** → **`price_category`**:
# `price_type` is confusing. Renaming it to `price_category` clarifies that this column categorizes the type of pricing (e.g., retail, wholesale).
#
# - **`unit`** → **`measurement_unit`**:
# `unit` is too generic. Renaming to `measurement_unit` helps specify that this column indicates the unit of measurement used for each price entry, providing clarity and reducing ambiguity.
# ---

# %%
# Renaming Columns
rename_dict = {
    'cpcv2': 'product_code',
    'admin_1': 'administrative_region',
    'price_type': 'price_category',
    'unit': 'measurement_unit'
}
df = df.rename(columns=rename_dict)

# Display the updated DataFrame
df.head()
# Out:
#   country            market administrative_region  longitude  latitude  \
# 0  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 1  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 2  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 3  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 4  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
#
#   product_code        product period_date price_category product_source  \
# 0     R01701AA  Beans (mixed)  2013-12-31         Retail          Local
# 1     R01701AA  Beans (mixed)  2014-01-31         Retail          Local
# 2     R01701AA  Beans (mixed)  2014-02-28         Retail          Local
# 3     R01701AA  Beans (mixed)  2014-03-31         Retail          Local
# 4     R01701AA  Beans (mixed)  2014-04-30         Retail          Local
#
#   measurement_unit currency    value
# 0               kg      AOA  229.670
# 1               kg      AOA  221.355
# 2               kg      AOA  228.385
# 3               kg      AOA  221.740
# 4               kg      AOA  219.785

# %% [markdown]
# The columns have been renamed successfully.
#
# ---

# %% [markdown]
# **c. Country to Rename:**
#
# - **`Congo, The Democratic Republic of the`** → **`Congo (DRC)`**:
# The long name `"Congo, The Democratic Republic of the"` can be cumbersome and may lead to inconsistencies or errors in data processing. Using `"Congo (DRC)"` ensures clarity and reduces the risk of confusion with the neighbouring `"Congo"`, which is officially named `"Republic of Congo"`.
#
# ---

# %%
# Rename 'Congo, The Democratic Republic of the' to 'Congo'
df['country'] = df['country'].replace('Congo, The Democratic Republic of the', 'Congo (DRC)')

# Confirm the renaming
if 'Congo, The Democratic Republic of the' not in df['country'].unique():
    print("Renaming confirmed: 'Congo, The Democratic Republic of the' has been replaced.")
else:
    print("Renaming failed: 'Congo, The Democratic Republic of the' still exists.")
# Out:
# Renaming confirmed: 'Congo, The Democratic Republic of the' has been replaced.

# %% [markdown]
# ---
#
# The renaming has been done successfully.
#
# ---

# %% [markdown]
# **d. Product to Rename:**
#
# - **`Gasoline`** → **`Petrol`**:
# The name "Gasoline" does not align with regional terminology and is inconsistent with local market conventions, especially in African markets where "Petrol" is the commonly used term.
#
# ---

# %%
# Renaming 'Gasoline' to 'Petrol'
df['product'] = df['product'].replace('Gasoline', 'Petrol')

# Confirm the renaming
unique_values_after_rename = df['product'].unique()

# Check if 'Gasoline' still exists
if 'Gasoline' in unique_values_after_rename:
    print("Gasoline still exists in the DataFrame.")
else:
    print("Gasoline does not exist in the DataFrame.")
# Out:
# Gasoline does not exist in the DataFrame.

# %% [markdown]
# ---
#
# The renaming of the product `Gasoline` to `Petrol` has been done successfully.
#
# ---

# %% [markdown]
# ---
# **e. Aspects that Do Not Conform**
#
# From the dataset, several aspects don't conform with staple food and fuel price prediction based on the unique values in the categorical columns:
#
# **`Non-Food Items`**:
# Products like `Casual Labor (unskilled, daily, without food)`, are not staple foods or fuels. Casual Labor represents wages for labour rather than a product.
#    - This is not a product or commodity; it’s a service, and it is not applicable to predicting staple food or fuel prices. Therefore, I will filter them out from the dataset.
#
# ---

# %%
# Filter out non-food items
# Product to filter out
product_to_filter = 'Casual Labor (unskilled, daily, without food)'

# Filter out the specified product
filtered_df = df[df['product'] != product_to_filter]

# Check if the product exists in the filtered DataFrame
product_exists = filtered_df['product'].str.contains(product_to_filter, case=False, na=False).any()

# Print result
if not product_exists:
    print(f"'{product_to_filter}' does not exist in the filtered DataFrame.")
else:
    print(f"'{product_to_filter}' still exists in the filtered DataFrame.")
# Out:
# 'Casual Labor (unskilled, daily, without food)' does not exist in the filtered DataFrame.

# %% [markdown]
# ---
# Dropping unnecessary columns, renaming others, standardizing country names, and filtering out non-relevant products, such as "Casual Labor (unskilled, daily, without food)," enhance the DataFrame's manageability and consistency. These steps simplify data analysis and operations by ensuring the dataset contains only relevant and accurate information.
#
# ---

# %% [markdown]
# ### vi. Checking for Missing Values in The Datasets

# %%
# Calculate missing values for the entire DataFrame
missing_values = df.isnull().sum()

# Exclude columns with 0 missing values
missing_values = missing_values[missing_values > 0]

# Calculate the percentage of missing values
missing_percentages = ((missing_values / len(df)) * 100).round(2)

# Create a dataFrame with columns sorted by missing values percentage (highest to lowest)
missing_info = pd.DataFrame({
    'Column': missing_values.index,
    'Missing Values': missing_values,
    'Missing Values Percentage (%)': missing_percentages
}).sort_values(by='Missing Values Percentage (%)', ascending=False)

# Print the results
title = "Missing values in the df dataset:"
underline = '=' * len(title)
print(title)
print(underline)
print(missing_info.to_string(index=False))
# Out:
# Missing values in the df dataset:
# =================================
#                Column  Missing Values  Missing Values Percentage (%)
#                 value          205158                          20.28
# administrative_region            1280                           0.13

# %%
# Visualize missing values in the entire DataFrame
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Data Heatmap')
plt.show()

# %% [markdown]
# - The `value` column has the highest number of missing values, accounting for 20.28% of the total data
# - The `administrative_region` column has 1,280 missing values, representing 0.13% of the dataset.
# - Let's analyse them to come up with an imputation strategy that will be used to handle them.
#
# ---

# %% [markdown]
# ### vii. Handling Missing Values

# %%
# Check the data types of the columns with missing values
title = "Data types of selected columns:"
underline = '=' * len(title)
print(title)
print(underline)
print(df[['value', 'administrative_region']].dtypes)
# Out:
# Data types of selected columns:
# ===============================
# value                    float64
# administrative_region     object
# dtype: object

# %% [markdown]
# ---
#
# Based on the data types of the `value` and `administrative_region` columns:
#
# - The **`value` column** is numerical, which means it contains floating-point numbers. Missing values in numeric columns can often be handled using statistical methods such as mean or median imputation.
#
# - The **`administrative_region` column** is categorical. The column represents the administrative region or province within the country where the pricing data is being collected. Given that each country has a distinct administrative structure with its own provinces, regions, or states, a blanket imputation strategy, like mode imputation across the entire dataset, may not be appropriate.
# ---

# %% [markdown]
# #### a. Handling Missing Values in the `administrative_region` Column

# %%
# Identify countries with missing administrative_region values
title = "Countries with Missing administrative_region Values:"
underline = '=' * len(title)
print(title)
print(underline)

# Count missing values for each country
missing_adm_reg = df[df['administrative_region'].isnull()].groupby('country').size()

# Display the result
print(missing_adm_reg)
# Out:
# Countries with Missing administrative_region Values:
# ====================================================
# country
# Angola       215
# Djibouti    1065
# dtype: int64

# %% [markdown]
# For the countries with missing `administrative_region` values (Angola and Djibouti), there are 215 and 1065 missing entries, respectively. These missing values need to be accurately imputed to ensure the completeness and usability of the dataset.
#
# ---

# %%
# Filter the DataFrame for rows with missing `administrative_region` values in Angola and Djibouti
missing_admin_reg_df = df[df['administrative_region'].isnull() & df['country'].isin(['Angola', 'Djibouti'])]

# Display the head of the filtered DataFrame
missing_admin_reg_df.head()
# Out:
#   country            market administrative_region  longitude  latitude  \
# 0  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 1  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 2  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 3  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 4  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
#
#   product_code        product period_date price_category product_source  \
# 0     R01701AA  Beans (mixed)  2013-12-31         Retail          Local
# 1     R01701AA  Beans (mixed)  2014-01-31         Retail          Local
# 2     R01701AA  Beans (mixed)  2014-02-28         Retail          Local
# 3     R01701AA  Beans (mixed)  2014-03-31         Retail          Local
# 4     R01701AA  Beans (mixed)  2014-04-30         Retail          Local
#
#   measurement_unit currency    value
# 0               kg      AOA  229.670
# 1               kg      AOA  221.355
# 2               kg      AOA  228.385
# 3               kg      AOA  221.740
# 4               kg      AOA  219.785

# %% [markdown]
# Since we have the latitudes and longitudes for each entry, we can use geocoding services to determine the missing `administrative_region` values. By querying the coordinates with the `Google Maps Geocoding API`, we can accurately fill in the missing administrative region or province.
#
# ----

# %%
# Add an 'index' column in the missing_admin_reg_df dataframe to keep track of original indices
missing_admin_reg_df['index'] = missing_admin_reg_df.index

# Group by latitude and longitude to get unique coordinates
grouped_coords = missing_admin_reg_df.groupby(['latitude', 'longitude']).agg({
    'index': lambda x: (x.min(), x.max())  # Get first and last indices
}).reset_index()

grouped_coords.rename(columns={'index': 'indices_range'}, inplace=True)

# %%
# Load environment variables from the .env file into a dictionary
environment_vars = dotenv_values('.env')

# Define the API request function
def get_admin_reg_from_coords(lat, lon):
    api_key = environment_vars.get("API_KEY")
    url = f'https://maps.googleapis.com/maps/api/geocode/json?latlng={lat},{lon}&key={api_key}'
    response = requests.get(url)
    result = response.json()
    if result['status'] == 'OK':
        address_components = result['results'][0]['address_components']
        # Extracting the administrative area level 1
        for component in address_components:
            if 'administrative_area_level_1' in component['types']:
                return component['long_name']
    return None

# Dictionary to store results for unique coordinates
admin_reg_results = {}

# Retrieve administrative_region values for unique coordinates
for _, row in grouped_coords.iterrows():
    lat = row['latitude']
    lon = row['longitude']
    if (lat, lon) not in admin_reg_results:
        admin_reg = get_admin_reg_from_coords(lat, lon)
        admin_reg_results[(lat, lon)] = admin_reg

# Map the retrieved administrative_region values back to the original DataFrame
def map_admin_reg(row):
    return admin_reg_results.get((row['latitude'], row['longitude']), None)

missing_admin_reg_df['administrative_region'] = missing_admin_reg_df.apply(map_admin_reg, axis=1)

# Print the header with formatting
print("\033[1mAdministrative Region Values for Missing Entries in Angola and Djibouti\033[0m")
print("=" * 58)

# Print unique latitudes, longitudes, indices ranges, and their corresponding administrative_region values
for _, row in grouped_coords.iterrows():
    lat = row['latitude']
    lon = row['longitude']
    indices_range = row['indices_range']
    admin_reg = admin_reg_results.get((lat, lon), 'Not Found')
    print(f"\033[1mIndices Range:\033[0m {indices_range[0]} - {indices_range[1]}")
    print(f"\033[1mLatitude:\033[0m {lat}")
    print(f"\033[1mLongitude:\033[0m {lon}")
    print(f"\033[1mAdministrative Region:\033[0m {admin_reg}")
    print("-" * 30)
# Out:
# Administrative Region Values for Missing Entries in Angola and Djibouti
# ==========================================================
# Indices Range: 175 - 214
# Latitude: -14.905
# Longitude: 13.5132
# Administrative Region: None
# ------------------------------
# Indices Range: 0 - 89
# Latitude: -12.7716
# Longitude: 15.7365
# Administrative Region: None
# ------------------------------
# Indices Range: 90 - 174
# Latitude: -8.82876
# Longitude: 13.2427
# Administrative Region: None
# ------------------------------
# Indices Range: 146433 - 147497
# Latitude: 11.59
# Longitude: 43.1485
# Administrative Region: None
# ------------------------------

# %% [markdown]
#    - **Huila Province**: The coordinates `Latitude: -14.905, Longitude: 13.5132` correspond to **Huila Province**, indicating that data points in the index range `175 - 214` are located in this administrative region of **Angola**.
#    - **Huambo Province**: The coordinates `Latitude: -12.7716, Longitude: 15.7365` are associated with **Huambo Province** in **Angola**. This encompasses data points with indices ranging from `0 - 89`.
#    - **Luanda**: For coordinates `Latitude: -8.82876, Longitude: 13.2427`, the administrative area is **Luanda** in **Angola**, covering the indices `90 - 174`.
#    - **Djibouti**: Coordinates `Latitude: 11.59, Longitude: 43.1485` refer to **Djibouti City** in **Djibouti**, covering indices from `146433 - 147497`.
# ---
# - The imputed `administrative_region` values align well with expected administrative regions based on provided latitudes and longitudes. This suggests that the Google Maps API effectively matched coordinates to their corresponding administrative regions.
# - With all missing `administrative_region` values filled, analyses that depend on administrative regions (e.g., regional comparisons, spatial trends) can now be conducted confidently.
#
# ---

# %%
# Merge updated `administrative_region` values back to the original DataFrame `df`
# Use common columns to ensure accurate merging
common_columns = ['country', 'market', 'longitude', 'latitude', 'product_code', 'product', 'period_date', 'price_category', 'product_source', 'measurement_unit', 'currency', 'value']
                    
# Merge based on common columns
df_updated = df.merge(missing_admin_reg_df[common_columns + ['administrative_region']], on=common_columns, how='left', suffixes=('', '_updated'))

# Update the `admin_1` column in the original DataFrame with the imputed values
df_updated['administrative_region'] = df_updated['administrative_region_updated'].fillna(df_updated['administrative_region'])

# Drop the extra columns used for merging
df_updated = df_updated.drop(columns=['administrative_region_updated'])

# Print an overview of the updated DataFrame to verify changes
df_updated.head()
# Out:
#   country            market administrative_region  longitude  latitude  \
# 0  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 1  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 2  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 3  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 4  Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
#
#   product_code        product period_date price_category product_source  \
# 0     R01701AA  Beans (mixed)  2013-12-31         Retail          Local
# 1     R01701AA  Beans (mixed)  2014-01-31         Retail          Local
# 2     R01701AA  Beans (mixed)  2014-02-28         Retail          Local
# 3     R01701AA  Beans (mixed)  2014-03-31         Retail          Local
# 4     R01701AA  Beans (mixed)  2014-04-30         Retail          Local
#
#   measurement_unit currency    value
# 0               kg      AOA  229.670
# 1               kg      AOA  221.355
# 2               kg      AOA  228.385
# 3               kg      AOA  221.740
# 4               kg      AOA  219.785

# %%
# Check if there are still missing values in the 'administrative_region' column
missing_values = df_updated['administrative_region'].isnull().sum()
print(f"Number of missing administrative_region values after imputation: {missing_values}")

# Filter rows with missing 'administrative_region' values for Angola and Djibouti
missing_admin_1_rows = df_updated[df_updated['administrative_region'].isnull() & df_updated['country'].isin(['Angola', 'Djibouti'])]

# Print the rows with missing 'administrative_region' values for Angola and Djibouti
print("\nRows with Missing administrative_region Values for Angola and Djibouti:")
print("=" * 57)
missing_admin_1_rows
# Out:
# Number of missing administrative_region values after imputation: 1280
#
# Rows with Missing administrative_region Values for Angola and Djibouti:
# =========================================================
#          country            market administrative_region  longitude  latitude  \
# 0         Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 1         Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 2         Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 3         Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# 4         Angola  Huambo, Alemanha                   NaN    15.7365  -12.7716
# ...          ...               ...                   ...        ...       ...
# 147493  Djibouti     Djibouti City                   NaN    43.1485   11.5900
# 147494  Djibouti     Djibouti City                   NaN    43.1485   11.5900
# 147495  Djibouti     Djibouti City                   NaN    43.1485   11.5900
# 147496  Djibouti     Djibouti City                   NaN    43.1485   11.5900
# 147497  Djibouti     Djibouti City                   NaN    43.1485   11.5900
#
#        product_code        product period_date price_category product_source  \
# 0          R01701AA  Beans (mixed)  2013-12-31         Retail          Local
# 1          R01701AA  Beans (mixed)  2014-01-31         Retail          Local
# 2          R01701AA  Beans (mixed)  2014-02-28         Retail          Local
# 3          R01701AA  Beans (mixed)  2014-03-31         Retail          Local
# 4          R01701AA  Beans (mixed)  2014-04-30         Retail          Local
# ...             ...            ...         ...            ...            ...
# 147493     P23110AA    Wheat Flour  2017-05-29         Retail         Import
# 147494     P23110AA    Wheat Flour  2017-06-05         Retail         Import
# 147495     P23110AA    Wheat Flour  2017-06-12         Retail         Import
# 147496     P23110AA    Wheat Flour  2017-06-19         Retail         Import
# 147497     P23110AA    Wheat Flour  2017-06-26         Retail         Import
#
#        measurement_unit currency    value
# 0                    kg      AOA  229.670
# 1                    kg      AOA  221.355
# 2                    kg      AOA  228.385
# 3                    kg      AOA  221.740
# 4                    kg      AOA  219.785
# ...                 ...      ...      ...
# 147493               kg      DJF  120.000
# 147494               kg      DJF  120.000
# 147495               kg      DJF  120.000
# 147496               kg      DJF  120.000
# 147497               kg      DJF  120.000
#
# [1280 rows x 13 columns]

# %% [markdown]
# Since there are no missing values in the `administrative_region` column after imputation, it indicates that the imputation process was successful.
#
# ---

# %% [markdown]
# #### b. Handling Missing Values in the `value` Column

# %%
df_updated['value']
# Out:
# 0          229.670
# 1          221.355
# 2          228.385
# 3          221.740
# 4          219.785
#             ...
# 1011739    154.560
# 1011740    152.870
# 1011741    167.910
# 1011742    213.490
# 1011743    252.400
# Name: value, Length: 1011744, dtype: float64

# %% [markdown]
# The `value` column in the dataset is numerical and represents a crucial piece of information related to the commodity prices. Missing values in this column can impact the quality of analyses and predictions.
#
# ---

# %%
# Identify countries with missing values in the `value` column
# Count missing values for each country
missing_counts = df_updated[df_updated['value'].isnull()].groupby('country').size()

# Calculate total entries for each country
total_entries = df_updated.groupby('country').size()

# Compute percentages
missing_percentages = (missing_counts / total_entries * 100).fillna(0)

# Combine counts and percentages into a single DataFrame
missing_summary = pd.DataFrame({
    'Missing Count': missing_counts,
    'Total Count': total_entries,
    'Missing Percentage': missing_percentages
})

# Format the percentage column to include the percentage sign
missing_summary['Missing Percentage'] = missing_summary['Missing Percentage'].apply(lambda x: f"{x:.2f}%")

# Convert 'Missing Percentage' column to numeric for sorting
missing_summary['Missing Percentage Numeric'] = missing_summary['Missing Percentage'].str.rstrip('%').astype(float)

# Sort the DataFrame by 'Missing Percentage Numeric' in descending order
missing_summary_sorted = missing_summary.sort_values(by='Missing Percentage Numeric', ascending=False)

# Drop the numeric percentage column used for sorting
missing_summary_sorted = missing_summary_sorted.drop(columns='Missing Percentage Numeric')

# Display the result
missing_summary_sorted
# Out:
#              Missing Count  Total Count Missing Percentage
# country
# South Sudan          24784        44971             55.11%
# Mauritania           17193        61061             28.16%
# Ethiopia             24079        96684             24.90%
# Haiti                54398       260705             20.87%
# Nigeria              55996       305288             18.34%
# Congo (DRC)          13956        83245             16.76%
# Somalia              10038        84339             11.90%
# Malawi                 524         4958             10.57%
# Zimbabwe               446         4878              9.14%
# Chad                  3676        62973              5.84%
# Djibouti                55         1065              5.16%
# Angola                   5          215              2.33%
# Kenya                    8         1362              0.59%

# %%
# Specify the dataframe to work with
missing_values_df = missing_summary_sorted

# Plotting
fig, ax = plt.subplots(figsize=(14, 10))

# Plot total counts
missing_values_df['Total Count'].plot(kind='bar', color='lightgrey', edgecolor='black', ax=ax, width=0.8)

# Plot missing counts on top of total counts
missing_values_df['Missing Count'].plot(kind='bar', color='red', edgecolor='black', ax=ax, width=0.8, alpha=0.7)

# Annotate missing percentage on top of each missing count bar
for i, (missing, percentage) in enumerate(zip(missing_values_df['Missing Count'], missing_values_df['Missing Percentage'])):
    ax.text(i, missing + 0.01 * missing, f'{percentage}', ha='center', va='bottom', fontweight='bold', color='black')

# Customize the plot
plt.title('Total Count vs Missing Count by Country with Missing Percentage')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(['Total Count', 'Missing Count'])
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ---
#
# - **Country**: Different countries have varying economic conditions and currency values, affecting the price of products.
#   - **AdministratiRegionionadministrative_regionn_1`)**: Within a country, different regions may have different economic conditions, market dynamics, and access to products, impacting prices.
#   - **Product**: Prices for different products can vary widely even within the same country and region.
#
# - **Limitations of Simple Imputation**:
#   - Using a global mean or median does not account for these contextual variations and can lead to inaccurate imputations.
#   - Prices can vary significantly between countries, regions, and product types, making a single mean or median inappropriate.
#
# - **Outliers Consideration**:
#   - **Outliers**: Extreme values in pricing data can significantly skew the mean, making it less representative of the typical value.
#   - Using the mean in the presence of outliers can lead to overestimation or underestimation of typical prices.
# ---
#
# So we proceed by first checking for .
#
# ---ted values.

# %% [markdown]
# ##### _Checking for Outliers in the `value` Column_
# ---

# %%
# Plot the boxplot
plt.figure(figsize=(20, 4))

plt.subplot(1, 2, 1)
sns.boxplot(x=df_updated['value'])
plt.title('Box Plot of Values Before Imputation')

plt.tight_layout()
plt.show()

# %%
# Plotting the distribution of 'value'
plt.figure(figsize=(20, 6))

# Histogram
plt.subplot(1, 2, 1)
sns.histplot(df['value'], bins=50, kde=True)
plt.title('Histogram of Value')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# - **Extreme Right Skew:** The histogram shows that the `value` column is heavily skewed to the right. This means that most of the data points are concentrated in the lower values, with a few extremely large values pulling the tail of the distribution to the right.
# - **Large Number of Zero Values:** A significant portion of the data points have values close to zero. This is evident from the tall bar at the leftmost end of the histogram.
# - **Sparse Data:** The histogram is quite sparse, with most bins having very few data points. This suggests that the data is not evenly distributed across the value range.
#
# - **Outliers:** The extreme right skew indicates the presence of potential outliers, which are the data points in the long tail of the distribution. These outliers could significantly impact statistical calculations like the mean.
#
# To gain deeper insights into these outliers, I will further analyse the column.
#
# ---

# %%
# Load the updated DataFrame
df_missing_value = df_updated

# Plot box plots for visualization
plt.figure(figsize=(12, 8))
sns.boxplot(x='country', y='value', data=df_missing_value, showfliers=True)
plt.xticks(rotation=90)
plt.title('Box Plot of `value` Column by Country')
plt.show()

# %%
# Create a list to store summary statistics
stats_list = []

# List unique countries
countries = df_missing_value['country'].unique()

# Analyze each country
for country in countries:
    country_df = df_missing_value[df_missing_value['country'] == country]['value']
    
    # Summary statistics
    min_val = country_df.min()
    q25 = country_df.quantile(0.25)
    q50 = country_df.median()
    q75 = country_df.quantile(0.75)
    max_val = country_df.max()
    iqr = q75 - q25
    lower_bound = q25 - 1.5 * iqr
    upper_bound = q75 + 1.5 * iqr
    
    # Count outliers
    num_outliers = ((country_df < lower_bound) | (country_df > upper_bound)).sum()
    
    # Append to stats_list
    stats_list.append({
        'Country': country,
        'Min': min_val,
        '25th Percentile': q25,
        '50th Percentile': q50,
        '75th Percentile': q75,
        'Max': max_val,
        'IQR': iqr,
        'Lower Bound': lower_bound,
        'Upper Bound': upper_bound,
        'Outlier Count': num_outliers
    })

# Convert the list to DataFrame
stats_df = pd.DataFrame(stats_list)

# Sort by 'Max' value to rank countries with extreme outliers
stats_df = stats_df.sort_values(by='Max', ascending=False).reset_index(drop=True)

# Print the leaderboard
print("Leaderboard of Countries Based on Maximum Outlier Values:")
print('='*57)
stats_df
# Out:
# Leaderboard of Countries Based on Maximum Outlier Values:
# =========================================================
#         Country         Min  25th Percentile  50th Percentile  \
# 0       Somalia   97.000000      7800.000000        20000.000
# 1   Congo (DRC)    8.000000      1420.000000         2492.000
# 2   South Sudan  100.000000      1460.000000         3500.000
# 3       Nigeria    1.000000       188.888889          528.630
# 4          Chad   25.500000       270.000000          500.000
# 5      Ethiopia    1.000000        33.000000           61.000
# 6    Mauritania    1.000000        25.000000           73.290
# 7         Haiti    8.000000        90.000000          180.000
# 8      Zimbabwe    0.000476         0.980000            1.340
# 9        Malawi   40.000000       170.000000          375.000
# 10        Kenya   20.000000        50.000000           88.945
# 11     Djibouti   80.000000       120.000000          140.000
# 12       Angola    7.560000        54.940000           72.650
#
#     75th Percentile          Max           IQR   Lower Bound    Upper Bound  \
# 0         55000.000  26300000.00  47200.000000 -63000.000000  125800.000000
# 1          4430.770   5920000.00   3010.770000  -3096.155000    8946.925000
# 2         18000.000   1120000.00  16540.000000 -23350.000000   42810.000000
# 3         17000.000    799000.00  16811.111111 -25027.777778   42216.666667
# 4          1650.000    355530.00   1380.000000  -1800.000000    3720.000000
# 5           164.000    324202.80    131.000000   -163.500000     360.500000
# 6           730.000     75000.00    705.000000  -1032.500000    1787.500000
# 7           362.500      3500.00    272.500000   -318.750000     771.250000
# 8             1.550      1849.00      0.570000      0.125000       2.405000
# 9           500.000      1500.00    330.000000   -325.000000     995.000000
# 10          117.680       622.00     67.680000    -51.520000     219.200000
# 11          187.750       405.00     67.750000     18.375000     289.375000
# 12          144.235       249.94     89.295000    -79.002500     278.177500
#
#     Outlier Count
# 0           13070
# 1            9615
# 2            2879
# 3           18464
# 4           11874
# 5           14265
# 6            8529
# 7           16910
# 8            1005
# 9              35
# 10            133
# 11              3
# 12              0

# %%
# List of products to iterate through
products = df_missing_value['product'].unique()

# Iterate through each product to analyze outliers
for product in products:
    # Filter data for the current product
    product_df = df_missing_value[df_missing_value['product'] == product]
    value_series = product_df['value']
    
    # Summary statistics
    q25 = value_series.quantile(0.25)
    q75 = value_series.quantile(0.75)
    iqr = q75 - q25
    lower_bound = q25 - 1.5 * iqr
    upper_bound = q75 + 1.5 * iqr
    
    # Identify outliers
    outliers = product_df[(value_series < lower_bound) | (value_series > upper_bound)]
    
    if not outliers.empty:
        print(f"\n\033[1m\033[4mOutlier Analysis for {product}\033[0m")  # Bold and Underline
        
        # Group by country to avoid repeating markets
        unique_outlier_countries = outliers.groupby('country')
        for country, group in unique_outlier_countries:
            indices = group.index
            min_val = group['value'].min()
            max_val = group['value'].max()
            print()
            country_title = f"\033[1mCountry: {country}\033[0m"
            separator = "=" * len(country_title)
            
            print(country_title)
            print(separator)
            print(f"Min Value: {min_val}, Max Value: {max_val}, Indices: {indices[0]} - {indices[-1]}")
            print()
            
            # Group by market within each country to summarize outlier indices
            unique_markets = group.groupby('market')
            for market, market_group in unique_markets:
                market_indices = market_group.index
                
                # Get the measurement_unit for the product in the current market
                measurement_unit = product_df[(product_df['country'] == country) & (product_df['market'] == market)]['measurement_unit'].iloc[0]
                
                # Calculate the minimum and maximum product price for the market
                market_min_value = product_df[(product_df['country'] == country) & (product_df['market'] == market)]['value'].min()
                market_max_value = product_df[(product_df['country'] == country) & (product_df['market'] == market)]['value'].max()
                
                # Print date range for each market
                date_range = market_group['period_date'].min(), market_group['period_date'].max()
                print(f"\033[1mMarket:\033[0m {market},  \033[1mUnit:\033[0m {measurement_unit},  \033[1mMin Value:\033[0m {market_min_value:.2f},  \033[1mMax Value:\033[0m {market_max_value:.2f},  \033[1mDate Range\033[0m:\033[0m {date_range[0]} to {date_range[1]}")

    else:
        print(f"\n\033[1m\033[4mNo outliers detected for Product: {product}.\033[0m")
# Out:
# Outlier Analysis for Beans (mixed)
#
# Country: Congo (DRC)
# ============================
# Min Value: 7333.33, Max Value: 10133.33, Indices: 63389 - 105195
#
# Market: Beni, Kilokwa,  Unit: kg,  Min Value: 390.00,  Max Value: 9752.65,  Date Range: 2023-09-13 00:00:00 to 2023-10-11 00:00:00
# Market: Gbadolite, Marché Central,  Unit: kg,  Min Value: 7500.00,  Max Value: 9107.14,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Inongo, Marché Central,  Unit: kg,  Min Value: 7397.26,  Max Value: 7762.56,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kalemie, Lukuga,  Unit: kg,  Min Value: 571.00,  Max Value: 8805.03,  Date Range: 2023-08-30 00:00:00 to 2023-08-30 00:00:00
# Market: Kindu, Mama Yemo,  Unit: kg,  Min Value: 650.00,  Max Value: 10133.33,  Date Range: 2023-05-17 00:00:00 to 2024-05-15 00:00:00
#
# Outlier Analysis for Cassava
#
# Country: South Sudan
# ============================
# Min Value: 2300.0, Max Value: 163333.33, Indices: 967797 - 1003201
#
# Market: Juba, Konyokonyo,  Unit: 100_kg,  Min Value: 4666.67,  Max Value: 163333.33,  Date Range: 2024-01-12 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: 100_kg,  Min Value: 5000.00,  Max Value: 5000.00,  Date Range: 2021-10-01 00:00:00 to 2021-10-29 00:00:00
# Market: Meyendit,  Unit: 100_kg,  Min Value: 420.00,  Max Value: 12000.00,  Date Range: 2021-12-31 00:00:00 to 2022-01-28 00:00:00
# Market: Torit,  Unit: 100_kg,  Min Value: 500.00,  Max Value: 10000.00,  Date Range: 2021-10-01 00:00:00 to 2024-05-31 00:00:00
# Market: Yei,  Unit: 100_kg,  Min Value: 364.00,  Max Value: 90000.00,  Date Range: 2021-06-18 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Maize Grain (White)
#
# Country: Nigeria
# ========================
# Min Value: 19900.0, Max Value: 78700.0, Indices: 580863 - 866954
#
# Market: Aba,  Unit: kg,  Min Value: 74.52,  Max Value: 78700.00,  Date Range: 2021-03-03 00:00:00 to 2024-05-15 00:00:00
# Market: Biu,  Unit: kg,  Min Value: 35.16,  Max Value: 55800.00,  Date Range: 2020-09-02 00:00:00 to 2024-05-15 00:00:00
# Market: Damaturu,  Unit: kg,  Min Value: 54.30,  Max Value: 60000.00,  Date Range: 2020-09-02 00:00:00 to 2024-05-15 00:00:00
# Market: Dandume,  Unit: kg,  Min Value: 29.62,  Max Value: 60200.00,  Date Range: 2020-09-02 00:00:00 to 2024-05-15 00:00:00
# Market: Giwa,  Unit: kg,  Min Value: 32.00,  Max Value: 60000.00,  Date Range: 2020-09-09 00:00:00 to 2024-05-15 00:00:00
# Market: Gombe,  Unit: kg,  Min Value: 48.00,  Max Value: 62000.00,  Date Range: 2020-09-02 00:00:00 to 2024-05-15 00:00:00
# Market: Gujungu,  Unit: kg,  Min Value: 42.31,  Max Value: 66000.00,  Date Range: 2020-08-26 00:00:00 to 2024-05-15 00:00:00
# Market: Gwandu, Dodoru,  Unit: kg,  Min Value: 44.22,  Max Value: 64700.00,  Date Range: 2020-09-02 00:00:00 to 2024-05-15 00:00:00
# Market: Ibadan, Bodija,  Unit: kg,  Min Value: 20.00,  Max Value: 66000.00,  Date Range: 2020-08-12 00:00:00 to 2024-05-15 00:00:00
# Market: Kano, Dawanau,  Unit: 100_kg,  Min Value: 44.05,  Max Value: 63900.00,  Date Range: 2017-04-26 00:00:00 to 2024-05-15 00:00:00
# Market: Kaura Namoda,  Unit: kg,  Min Value: 30.00,  Max Value: 61900.00,  Date Range: 2020-09-02 00:00:00 to 2024-05-15 00:00:00
# Market: Lagos, Mile 12,  Unit: kg,  Min Value: 70.00,  Max Value: 66400.00,  Date Range: 2020-08-19 00:00:00 to 2024-05-15 00:00:00
# Market: Maiduguri,  Unit: kg,  Min Value: 50.00,  Max Value: 67000.00,  Date Range: 2021-02-24 00:00:00 to 2024-05-15 00:00:00
# Market: Mubi,  Unit: kg,  Min Value: 36.00,  Max Value: 63000.00,  Date Range: 2020-09-02 00:00:00 to 2024-05-15 00:00:00
# Market: Potiskum,  Unit: kg,  Min Value: 30.00,  Max Value: 60000.00,  Date Range: 2020-08-26 00:00:00 to 2024-05-15 00:00:00
# Market: Saminaka,  Unit: kg,  Min Value: 28.00,  Max Value: 57000.00,  Date Range: 2021-06-16 00:00:00 to 2024-05-15 00:00:00
#
# Country: Somalia
# ========================
# Min Value: 19950.0, Max Value: 1300000.0, Indices: 880711 - 947724
#
# Market: Afgoi,  Unit: kg,  Min Value: 799.00,  Max Value: 20666.00,  Date Range: 2011-06-30 00:00:00 to 2011-06-30 00:00:00
# Market: Afmadow,  Unit: kg,  Min Value: 900.00,  Max Value: 24500.00,  Date Range: 2008-06-30 00:00:00 to 2008-08-31 00:00:00
# Market: Buale,  Unit: kg,  Min Value: 840.00,  Max Value: 25500.00,  Date Range: 2011-05-31 00:00:00 to 2011-08-31 00:00:00
# Market: Doblei,  Unit: kg,  Min Value: 1525.00,  Max Value: 21000.00,  Date Range: 2008-08-31 00:00:00 to 2008-11-30 00:00:00
# Market: Elwak,  Unit: kg,  Min Value: 3000.00,  Max Value: 41500.00,  Date Range: 2020-07-31 00:00:00 to 2024-05-31 00:00:00
# Market: Galkayo,  Unit: kg,  Min Value: 1900.00,  Max Value: 33000.00,  Date Range: 2008-06-30 00:00:00 to 2024-05-31 00:00:00
# Market: Jamame,  Unit: kg,  Min Value: 771.00,  Max Value: 20000.00,  Date Range: 2008-07-31 00:00:00 to 2008-07-31 00:00:00
# Market: Jilib,  Unit: kg,  Min Value: 680.00,  Max Value: 22250.00,  Date Range: 2008-06-30 00:00:00 to 2011-08-31 00:00:00
# Market: Jowhar,  Unit: kg,  Min Value: 825.00,  Max Value: 21950.00,  Date Range: 2011-04-30 00:00:00 to 2011-06-30 00:00:00
# Market: Kismayo,  Unit: kg,  Min Value: 1000.00,  Max Value: 26000.00,  Date Range: 2008-06-30 00:00:00 to 2022-08-31 00:00:00
# Market: Lugh,  Unit: kg,  Min Value: 700.00,  Max Value: 24000.00,  Date Range: 2011-07-31 00:00:00 to 2024-04-30 00:00:00
# Market: Merka,  Unit: kg,  Min Value: 806.00,  Max Value: 22832.00,  Date Range: 2011-06-30 00:00:00 to 2011-08-31 00:00:00
# Market: Mogadishu, Bakara,  Unit: kg,  Min Value: 1000.00,  Max Value: 1300000.00,  Date Range: 1995-02-28 00:00:00 to 2024-05-31 00:00:00
#
# Country: South Sudan
# ============================
# Min Value: 20000.0, Max Value: 213800.0, Indices: 966458 - 1005648
#
# Market: Bor,  Unit: 3.5_kg,  Min Value: 61333.33,  Max Value: 61333.33,  Date Range: 2024-04-26 00:00:00 to 2024-04-26 00:00:00
# Market: Juba, Konyokonyo,  Unit: 3.5_kg,  Min Value: 600.00,  Max Value: 61666.67,  Date Range: 2024-01-12 00:00:00 to 2024-05-31 00:00:00
# Market: Kapoeta,  Unit: 90_kg,  Min Value: 2566.67,  Max Value: 62333.33,  Date Range: 2024-01-12 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: 3.5_kg,  Min Value: 765.00,  Max Value: 120000.00,  Date Range: 2021-06-18 00:00:00 to 2024-05-31 00:00:00
# Market: Meyendit,  Unit: 3.5_kg,  Min Value: 1500.00,  Max Value: 34000.00,  Date Range: 2021-08-20 00:00:00 to 2022-03-11 00:00:00
# Market: Pibor,  Unit: 3.5_kg,  Min Value: 1400.00,  Max Value: 213800.00,  Date Range: 2022-02-18 00:00:00 to 2023-12-01 00:00:00
# Market: Torit,  Unit: 3.5_kg,  Min Value: 500.00,  Max Value: 68750.00,  Date Range: 2022-08-19 00:00:00 to 2024-05-31 00:00:00
# Market: Yei,  Unit: 3.5_kg,  Min Value: 392.00,  Max Value: 79200.00,  Date Range: 2021-06-18 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Maize Meal
#
# Country: Haiti
# ======================
# Min Value: 275.0, Max Value: 1000.0, Indices: 250875 - 485054
#
# Market: Cap Haitien,  Unit: 6_lb,  Min Value: 42.00,  Max Value: 900.00,  Date Range: 2020-05-05 00:00:00 to 2024-04-30 00:00:00
# Market: Cayes,  Unit: 6_lb,  Min Value: 30.00,  Max Value: 1000.00,  Date Range: 2022-03-22 00:00:00 to 2024-04-30 00:00:00
# Market: Fond-des-Negres,  Unit: 6_lb,  Min Value: 50.00,  Max Value: 750.00,  Date Range: 2022-03-22 00:00:00 to 2024-04-30 00:00:00
# Market: Gonaives,  Unit: 6_lb,  Min Value: 35.00,  Max Value: 600.00,  Date Range: 2022-03-22 00:00:00 to 2024-04-30 00:00:00
# Market: Hinche,  Unit: 6_lb,  Min Value: 30.00,  Max Value: 700.00,  Date Range: 2022-04-19 00:00:00 to 2024-04-30 00:00:00
# Market: Jacmel,  Unit: 6_lb,  Min Value: 36.00,  Max Value: 750.00,  Date Range: 2022-02-01 00:00:00 to 2024-04-30 00:00:00
# Market: Jeremie,  Unit: 6_lb,  Min Value: 20.00,  Max Value: 800.00,  Date Range: 2022-03-29 00:00:00 to 2024-04-30 00:00:00
# Market: Ouanaminthe,  Unit: 6_lb,  Min Value: 24.00,  Max Value: 630.00,  Date Range: 2021-10-05 00:00:00 to 2023-09-26 00:00:00
# Market: Port-au-Prince, Croix-de-Bossales,  Unit: 6_lb,  Min Value: 50.00,  Max Value: 600.00,  Date Range: 2022-03-22 00:00:00 to 2024-04-30 00:00:00
# Market: Port-de-Paix,  Unit: 6_lb,  Min Value: 50.00,  Max Value: 750.00,  Date Range: 2020-08-25 00:00:00 to 2024-04-30 00:00:00
#
# No outliers detected for Product: Sweet Potatoes.
#
# Outlier Analysis for Camels (Male, Average)
#
# Country: Chad
# =====================
# Min Value: 127500.0, Max Value: 355530.0, Indices: 215 - 50873
#
# Market: Abeche,  Unit: ea,  Min Value: 180000.00,  Max Value: 215000.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Amtiman,  Unit: ea,  Min Value: 226000.00,  Max Value: 259000.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Bagasola,  Unit: ea,  Min Value: 130000.00,  Max Value: 193200.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Biltine,  Unit: ea,  Min Value: 168700.00,  Max Value: 212500.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Faya,  Unit: ea,  Min Value: 311000.00,  Max Value: 355530.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Mao,  Unit: ea,  Min Value: 175000.00,  Max Value: 325000.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Mongo,  Unit: ea,  Min Value: 219000.00,  Max Value: 246000.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Moussoro,  Unit: ea,  Min Value: 127500.00,  Max Value: 145500.00,  Date Range: 2023-09-13 00:00:00 to 2024-05-29 00:00:00
# Market: N'Djamena,  Unit: ea,  Min Value: 205000.00,  Max Value: 293000.00,  Date Range: 2023-09-13 00:00:00 to 2024-05-29 00:00:00
#
# Outlier Analysis for Cattle (Male, 2-3 years old, Local Quality)
#
# Country: Somalia
# ========================
# Min Value: 3700000.0, Max Value: 8950000.0, Indices: 882464 - 956439
#
# Market: Afmadow,  Unit: ea,  Min Value: 382500.00,  Max Value: 7700000.00,  Date Range: 2008-01-31 00:00:00 to 2024-03-31 00:00:00
# Market: Baidoa,  Unit: ea,  Min Value: 165000.00,  Max Value: 7990000.00,  Date Range: 2008-05-31 00:00:00 to 2024-05-31 00:00:00
# Market: Bardera,  Unit: ea,  Min Value: 119333.00,  Max Value: 6050000.00,  Date Range: 2008-03-31 00:00:00 to 2024-05-31 00:00:00
# Market: Beled Weyn,  Unit: ea,  Min Value: 242500.00,  Max Value: 5000000.00,  Date Range: 2008-08-31 00:00:00 to 2023-07-31 00:00:00
# Market: Buale,  Unit: ea,  Min Value: 309000.00,  Max Value: 5425000.00,  Date Range: 2009-11-30 00:00:00 to 2024-05-31 00:00:00
# Market: Dinsor,  Unit: ea,  Min Value: 400000.00,  Max Value: 5200000.00,  Date Range: 2008-04-30 00:00:00 to 2024-05-31 00:00:00
# Market: Jowhar,  Unit: ea,  Min Value: 212000.00,  Max Value: 8950000.00,  Date Range: 2008-04-30 00:00:00 to 2024-05-31 00:00:00
# Market: Qorioley,  Unit: ea,  Min Value: 385000.00,  Max Value: 5625000.00,  Date Range: 2008-06-30 00:00:00 to 2021-10-31 00:00:00
# Market: Togwajale,  Unit: ea,  Min Value: 63800.00,  Max Value: 6330000.00,  Date Range: 2021-02-28 00:00:00 to 2024-04-30 00:00:00
#
# Outlier Analysis for Chickens
#
# Country: Chad
# =====================
# Min Value: 275.0, Max Value: 7500.0, Indices: 720 - 51413
#
# Market: Abeche,  Unit: ea,  Min Value: 275.00,  Max Value: 3750.00,  Date Range: 2016-10-31 00:00:00 to 2017-10-31 00:00:00
# Market: Faya,  Unit: ea,  Min Value: 3000.00,  Max Value: 7500.00,  Date Range: 2018-05-31 00:00:00 to 2024-05-29 00:00:00
# Market: Kelo,  Unit: ea,  Min Value: 1130.00,  Max Value: 3500.00,  Date Range: 2018-09-30 00:00:00 to 2018-09-30 00:00:00
# Market: Mao,  Unit: ea,  Min Value: 2000.00,  Max Value: 5900.00,  Date Range: 2018-10-31 00:00:00 to 2023-04-19 00:00:00
# Market: Mongo,  Unit: ea,  Min Value: 1500.00,  Max Value: 5000.00,  Date Range: 2020-05-06 00:00:00 to 2020-05-06 00:00:00
# Market: N'Djamena,  Unit: ea,  Min Value: 2400.00,  Max Value: 4250.00,  Date Range: 2023-04-19 00:00:00 to 2023-04-19 00:00:00
#
# Outlier Analysis for Cowpeas (Mixed)
#
# Country: Congo (DRC)
# ============================
# Min Value: 1413.0, Max Value: 6726.46, Indices: 78867 - 137837
#
# Market: Gbadolite, Marché Central,  Unit: kg,  Min Value: 1835.21,  Max Value: 2022.47,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Inongo, Marché Central,  Unit: kg,  Min Value: 2901.55,  Max Value: 4766.84,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kalemie, Lukuga,  Unit: kg,  Min Value: 1563.00,  Max Value: 2063.00,  Date Range: 2020-10-07 00:00:00 to 2020-12-23 00:00:00
# Market: Kananga, Ndesha,  Unit: kg,  Min Value: 1083.33,  Max Value: 4166.67,  Date Range: 2020-10-07 00:00:00 to 2024-05-29 00:00:00
# Market: Kasumbalesa, Marché Central,  Unit: kg,  Min Value: 1000.00,  Max Value: 6726.46,  Date Range: 2020-10-07 00:00:00 to 2024-05-29 00:00:00
# Market: Kikwit, Marché Central,  Unit: kg,  Min Value: 1903.00,  Max Value: 4000.00,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Kindu, Mama Yemo,  Unit: kg,  Min Value: 400.00,  Max Value: 6666.67,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Central,  Unit: kg,  Min Value: 1300.00,  Max Value: 5200.00,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Marché de Matadi Kibala,  Unit: kg,  Min Value: 4625.00,  Max Value: 6350.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Marché de Somba Zigida,  Unit: kg,  Min Value: 4950.00,  Max Value: 5750.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kisangani, Marché du 24 Novembre,  Unit: kg,  Min Value: 3237.79,  Max Value: 3694.27,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Lubumbashi, Laurent Kabila,  Unit: kg,  Min Value: 1440.00,  Max Value: 3625.00,  Date Range: 2022-01-12 00:00:00 to 2024-05-29 00:00:00
# Market: Matadi, Marché Central,  Unit: kg,  Min Value: 1918.80,  Max Value: 4812.83,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Mbadaka, Marché Central,  Unit: kg,  Min Value: 650.00,  Max Value: 6080.00,  Date Range: 2020-09-02 00:00:00 to 2024-05-29 00:00:00
# Market: Mbuji-mayi, Marché Central,  Unit: kg,  Min Value: 1229.00,  Max Value: 3889.29,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Tshikapa, Kamalengo,  Unit: kg,  Min Value: 1421.40,  Max Value: 4766.51,  Date Range: 2022-12-07 00:00:00 to 2024-05-29 00:00:00
#
# Outlier Analysis for Diesel
#
# Country: Congo (DRC)
# ============================
# Min Value: 3160.0, Max Value: 19560.0, Indices: 65111 - 143277
#
# Market: Beni, Kilokwa,  Unit: L,  Min Value: 1560.00,  Max Value: 6200.00,  Date Range: 2022-01-26 00:00:00 to 2024-05-29 00:00:00
# Market: Bukavu, Kadutu (Central),  Unit: L,  Min Value: 1650.00,  Max Value: 4270.00,  Date Range: 2022-04-13 00:00:00 to 2024-05-29 00:00:00
# Market: Bunia, Marché Central,  Unit: L,  Min Value: 1500.00,  Max Value: 5700.00,  Date Range: 2022-06-01 00:00:00 to 2024-05-29 00:00:00
# Market: Gbadolite, Marché Central,  Unit: L,  Min Value: 4500.00,  Max Value: 4500.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Goma, Virunga (Central),  Unit: L,  Min Value: 1733.00,  Max Value: 4270.00,  Date Range: 2022-06-29 00:00:00 to 2024-05-29 00:00:00
# Market: Inongo, Marché Central,  Unit: L,  Min Value: 4000.00,  Max Value: 4066.67,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kalemie, Lukuga,  Unit: L,  Min Value: 1950.00,  Max Value: 6000.00,  Date Range: 2022-03-16 00:00:00 to 2024-05-29 00:00:00
# Market: Kananga, Ndesha,  Unit: L,  Min Value: 2550.00,  Max Value: 5100.00,  Date Range: 2021-04-07 00:00:00 to 2024-05-29 00:00:00
# Market: Kasumbalesa, Marché Central,  Unit: L,  Min Value: 1700.00,  Max Value: 5000.00,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Kikwit, Marché Central,  Unit: L,  Min Value: 2370.00,  Max Value: 3800.00,  Date Range: 2023-01-04 00:00:00 to 2024-05-29 00:00:00
# Market: Kindu, Mama Yemo,  Unit: L,  Min Value: 2415.00,  Max Value: 19560.00,  Date Range: 2020-10-07 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Central,  Unit: L,  Min Value: 1985.00,  Max Value: 3445.00,  Date Range: 2023-10-25 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Marché de Matadi Kibala,  Unit: L,  Min Value: 3000.00,  Max Value: 3440.00,  Date Range: 2024-05-08 00:00:00 to 2024-05-29 00:00:00
# Market: Kisangani, Marché du 24 Novembre,  Unit: L,  Min Value: 3880.00,  Max Value: 4220.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Lubumbashi, Laurent Kabila,  Unit: L,  Min Value: 1815.00,  Max Value: 4395.00,  Date Range: 2022-09-21 00:00:00 to 2024-05-29 00:00:00
# Market: Mbadaka, Marché Central,  Unit: L,  Min Value: 1538.00,  Max Value: 3880.00,  Date Range: 2022-05-25 00:00:00 to 2024-05-29 00:00:00
# Market: Mbuji-mayi, Marché Central,  Unit: L,  Min Value: 2775.00,  Max Value: 7000.00,  Date Range: 2020-10-07 00:00:00 to 2024-05-29 00:00:00
# Market: Tshikapa, Kamalengo,  Unit: L,  Min Value: 2000.00,  Max Value: 4420.00,  Date Range: 2022-08-03 00:00:00 to 2024-05-22 00:00:00
# Market: Uvira, Maendeleo,  Unit: L,  Min Value: 1620.00,  Max Value: 4270.00,  Date Range: 2022-04-20 00:00:00 to 2024-05-29 00:00:00
#
# Country: Mauritania
# ===========================
# Min Value: 4362.0, Max Value: 4362.0, Indices: 555068 - 555068
#
# Market: Nouakchott, Marché SCIM,  Unit: L,  Min Value: 4.20,  Max Value: 4362.00,  Date Range: 2018-05-02 00:00:00 to 2018-05-02 00:00:00
#
# Country: Somalia
# ========================
# Min Value: 3375.0, Max Value: 254000.0, Indices: 885967 - 952701
#
# Market: Baidoa,  Unit: L,  Min Value: 2000.00,  Max Value: 42250.00,  Date Range: 2000-01-31 00:00:00 to 2024-05-31 00:00:00
# Market: Bossaso,  Unit: L,  Min Value: 2500.00,  Max Value: 47000.00,  Date Range: 2000-12-31 00:00:00 to 2024-05-31 00:00:00
# Market: Burao,  Unit: L,  Min Value: 1337.50,  Max Value: 10000.00,  Date Range: 2003-02-28 00:00:00 to 2024-05-31 00:00:00
# Market: Dhusamareb,  Unit: L,  Min Value: 7000.00,  Max Value: 254000.00,  Date Range: 2002-03-31 00:00:00 to 2024-05-31 00:00:00
# Market: Kismayo,  Unit: L,  Min Value: 5000.00,  Max Value: 48250.00,  Date Range: 1999-12-31 00:00:00 to 2024-05-31 00:00:00
# Market: Mogadishu, Bakara,  Unit: L,  Min Value: 1525.00,  Max Value: 47500.00,  Date Range: 2000-01-31 00:00:00 to 2024-05-31 00:00:00
# Market: Qorioley,  Unit: L,  Min Value: 3000.00,  Max Value: 50000.00,  Date Range: 2000-01-31 00:00:00 to 2024-05-31 00:00:00
#
# Country: South Sudan
# ============================
# Min Value: 3160.0, Max Value: 1120000.0, Indices: 963347 - 1004119
#
# Market: Aweil,  Unit: L,  Min Value: 1666.67,  Max Value: 5000.00,  Date Range: 2024-03-29 00:00:00 to 2024-05-31 00:00:00
# Market: Fangak,  Unit: L,  Min Value: 5000.00,  Max Value: 1120000.00,  Date Range: 2024-01-12 00:00:00 to 2024-05-31 00:00:00
# Market: Juba, Konyokonyo,  Unit: L,  Min Value: 1252.67,  Max Value: 4316.67,  Date Range: 2024-04-05 00:00:00 to 2024-05-31 00:00:00
# Market: Kapoeta,  Unit: L,  Min Value: 1400.00,  Max Value: 4133.33,  Date Range: 2024-04-26 00:00:00 to 2024-05-31 00:00:00
# Market: Leer,  Unit: L,  Min Value: 1350.00,  Max Value: 7680.00,  Date Range: 2022-09-02 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: L,  Min Value: 650.00,  Max Value: 12000.00,  Date Range: 2023-09-15 00:00:00 to 2024-05-31 00:00:00
# Market: Malakal, Aburoc,  Unit: L,  Min Value: 800.00,  Max Value: 17050.00,  Date Range: 2023-05-19 00:00:00 to 2024-05-31 00:00:00
# Market: Pibor,  Unit: L,  Min Value: 750.00,  Max Value: 36500.00,  Date Range: 2023-01-06 00:00:00 to 2024-05-31 00:00:00
# Market: Torit,  Unit: L,  Min Value: 400.00,  Max Value: 4500.00,  Date Range: 2024-04-26 00:00:00 to 2024-05-31 00:00:00
# Market: Yei,  Unit: L,  Min Value: 450.00,  Max Value: 4650.00,  Date Range: 2024-04-26 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Petrol
#
# Country: Congo (DRC)
# ============================
# Min Value: 2640.0, Max Value: 12900.0, Indices: 65502 - 143669
#
# Market: Beni, Kilokwa,  Unit: L,  Min Value: 1560.00,  Max Value: 5000.00,  Date Range: 2022-01-19 00:00:00 to 2024-05-29 00:00:00
# Market: Bukavu, Kadutu (Central),  Unit: L,  Min Value: 1887.50,  Max Value: 4220.00,  Date Range: 2022-02-23 00:00:00 to 2024-05-29 00:00:00
# Market: Bunia, Marché Central,  Unit: L,  Min Value: 1420.00,  Max Value: 5700.00,  Date Range: 2021-10-27 00:00:00 to 2024-05-29 00:00:00
# Market: Gbadolite, Marché Central,  Unit: L,  Min Value: 4980.00,  Max Value: 5400.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Goma, Virunga (Central),  Unit: L,  Min Value: 1667.00,  Max Value: 4220.00,  Date Range: 2022-02-23 00:00:00 to 2024-05-29 00:00:00
# Market: Inongo, Marché Central,  Unit: L,  Min Value: 4500.00,  Max Value: 4600.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kalemie, Lukuga,  Unit: L,  Min Value: 1970.00,  Max Value: 6200.00,  Date Range: 2021-12-08 00:00:00 to 2024-05-29 00:00:00
# Market: Kananga, Ndesha,  Unit: L,  Min Value: 2340.00,  Max Value: 5200.00,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Kasumbalesa, Marché Central,  Unit: L,  Min Value: 1500.00,  Max Value: 4500.00,  Date Range: 2022-02-02 00:00:00 to 2024-05-29 00:00:00
# Market: Kikwit, Marché Central,  Unit: L,  Min Value: 2370.00,  Max Value: 3810.00,  Date Range: 2022-06-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kindu, Mama Yemo,  Unit: L,  Min Value: 2380.00,  Max Value: 12900.00,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Central,  Unit: L,  Min Value: 1985.00,  Max Value: 3475.00,  Date Range: 2022-09-21 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Marché de Matadi Kibala,  Unit: L,  Min Value: 3000.00,  Max Value: 3440.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Marché de Somba Zigida,  Unit: L,  Min Value: 3500.00,  Max Value: 3500.00,  Date Range: 2024-05-15 00:00:00 to 2024-05-29 00:00:00
# Market: Kisangani, Marché du 24 Novembre,  Unit: L,  Min Value: 3780.00,  Max Value: 3880.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Lubumbashi, Laurent Kabila,  Unit: L,  Min Value: 1816.00,  Max Value: 4165.00,  Date Range: 2022-04-06 00:00:00 to 2024-05-29 00:00:00
# Market: Lusambo, Marché Central,  Unit: L,  Min Value: 5000.00,  Max Value: 5000.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Mbadaka, Marché Central,  Unit: L,  Min Value: 1680.00,  Max Value: 4460.00,  Date Range: 2021-01-20 00:00:00 to 2024-05-29 00:00:00
# Market: Mbuji-mayi, Marché Central,  Unit: L,  Min Value: 1500.00,  Max Value: 7000.00,  Date Range: 2020-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Tshikapa, Kamalengo,  Unit: L,  Min Value: 2000.00,  Max Value: 4440.00,  Date Range: 2017-10-31 00:00:00 to 2024-05-29 00:00:00
# Market: Uvira, Maendeleo,  Unit: L,  Min Value: 1900.00,  Max Value: 11200.00,  Date Range: 2022-03-09 00:00:00 to 2024-05-29 00:00:00
#
# Country: Somalia
# ========================
# Min Value: 2656.0, Max Value: 50500.0, Indices: 886597 - 952996
#
# Market: Baidoa,  Unit: L,  Min Value: 2500.00,  Max Value: 45000.00,  Date Range: 1995-07-31 00:00:00 to 2024-05-31 00:00:00
# Market: Bossaso,  Unit: L,  Min Value: 3500.00,  Max Value: 50500.00,  Date Range: 1995-07-31 00:00:00 to 2024-05-31 00:00:00
# Market: Burao,  Unit: L,  Min Value: 1580.00,  Max Value: 12000.00,  Date Range: 2000-12-31 00:00:00 to 2024-05-31 00:00:00
# Market: Dhusamareb,  Unit: L,  Min Value: 8000.00,  Max Value: 40000.00,  Date Range: 2002-03-31 00:00:00 to 2024-05-31 00:00:00
# Market: Kismayo,  Unit: L,  Min Value: 5000.00,  Max Value: 45000.00,  Date Range: 1999-12-31 00:00:00 to 2024-05-31 00:00:00
# Market: Mogadishu, Bakara,  Unit: L,  Min Value: 2100.00,  Max Value: 40000.00,  Date Range: 1996-01-31 00:00:00 to 2024-05-31 00:00:00
# Market: Qorioley,  Unit: L,  Min Value: 3500.00,  Max Value: 43750.00,  Date Range: 1999-11-30 00:00:00 to 2024-05-31 00:00:00
#
# Country: South Sudan
# ============================
# Min Value: 2650.0, Max Value: 13380.0, Indices: 963653 - 1004425
#
# Market: Aweil,  Unit: L,  Min Value: 1633.33,  Max Value: 5000.00,  Date Range: 2024-03-29 00:00:00 to 2024-05-31 00:00:00
# Market: Juba, Konyokonyo,  Unit: L,  Min Value: 1350.00,  Max Value: 4300.00,  Date Range: 2024-03-29 00:00:00 to 2024-05-31 00:00:00
# Market: Kapoeta,  Unit: L,  Min Value: 2400.00,  Max Value: 11333.33,  Date Range: 2024-02-02 00:00:00 to 2024-05-31 00:00:00
# Market: Leer,  Unit: L,  Min Value: 1300.00,  Max Value: 8020.00,  Date Range: 2022-07-08 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: L,  Min Value: 700.00,  Max Value: 7000.00,  Date Range: 2023-01-06 00:00:00 to 2024-05-31 00:00:00
# Market: Malakal, Aburoc,  Unit: L,  Min Value: 1200.00,  Max Value: 7500.00,  Date Range: 2023-07-21 00:00:00 to 2024-05-31 00:00:00
# Market: Pibor,  Unit: L,  Min Value: 1500.00,  Max Value: 13380.00,  Date Range: 2023-02-10 00:00:00 to 2024-05-31 00:00:00
# Market: Torit,  Unit: L,  Min Value: 400.00,  Max Value: 4625.00,  Date Range: 2024-03-29 00:00:00 to 2024-05-31 00:00:00
# Market: Yei,  Unit: L,  Min Value: 450.00,  Max Value: 4650.00,  Date Range: 2024-03-29 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Goats (Male, Medium-sized, Castrated)
#
# Country: Chad
# =====================
# Min Value: 5000.0, Max Value: 57000.0, Indices: 1441 - 52099
#
# Market: Abeche,  Unit: ea,  Min Value: 5000.00,  Max Value: 25000.00,  Date Range: 2016-08-31 00:00:00 to 2017-11-30 00:00:00
# Market: Bagasola,  Unit: ea,  Min Value: 16000.00,  Max Value: 26800.00,  Date Range: 2024-04-10 00:00:00 to 2024-04-10 00:00:00
# Market: Biltine,  Unit: ea,  Min Value: 11000.00,  Max Value: 26000.00,  Date Range: 2022-07-06 00:00:00 to 2022-07-06 00:00:00
# Market: Bol,  Unit: ea,  Min Value: 8000.00,  Max Value: 30000.00,  Date Range: 2022-07-06 00:00:00 to 2024-04-10 00:00:00
# Market: Faya,  Unit: ea,  Min Value: 26800.00,  Max Value: 57000.00,  Date Range: 2018-05-31 00:00:00 to 2024-05-29 00:00:00
# Market: Mao,  Unit: ea,  Min Value: 11300.00,  Max Value: 35800.00,  Date Range: 2012-09-30 00:00:00 to 2024-03-20 00:00:00
# Market: Moundou,  Unit: ea,  Min Value: 8860.00,  Max Value: 26000.00,  Date Range: 2014-12-31 00:00:00 to 2014-12-31 00:00:00
# Market: Moussoro,  Unit: ea,  Min Value: 10800.00,  Max Value: 27000.00,  Date Range: 2015-08-31 00:00:00 to 2021-07-21 00:00:00
# Market: N'Djamena,  Unit: ea,  Min Value: 14600.00,  Max Value: 35000.00,  Date Range: 2021-11-24 00:00:00 to 2023-06-26 00:00:00
#
# Outlier Analysis for Groundnuts (Shelled)
#
# Country: Nigeria
# ========================
# Min Value: 54800.0, Max Value: 154000.0, Indices: 579575 - 865432
#
# Market: Aba,  Unit: kg,  Min Value: 119.05,  Max Value: 149760.00,  Date Range: 2021-03-03 00:00:00 to 2024-05-15 00:00:00
# Market: Biu,  Unit: kg,  Min Value: 134.45,  Max Value: 92900.00,  Date Range: 2022-01-19 00:00:00 to 2024-05-15 00:00:00
# Market: Damaturu,  Unit: kg,  Min Value: 129.69,  Max Value: 90000.00,  Date Range: 2023-11-22 00:00:00 to 2024-05-15 00:00:00
# Market: Dandume,  Unit: kg,  Min Value: 134.54,  Max Value: 94700.00,  Date Range: 2023-05-03 00:00:00 to 2024-05-15 00:00:00
# Market: Giwa,  Unit: kg,  Min Value: 58.62,  Max Value: 154000.00,  Date Range: 2021-02-17 00:00:00 to 2024-05-01 00:00:00
# Market: Gombe,  Unit: kg,  Min Value: 166.66,  Max Value: 110000.00,  Date Range: 2021-07-07 00:00:00 to 2024-05-15 00:00:00
# Market: Gujungu,  Unit: kg,  Min Value: 168.06,  Max Value: 120000.00,  Date Range: 2022-02-23 00:00:00 to 2024-05-15 00:00:00
# Market: Gwandu, Dodoru,  Unit: kg,  Min Value: 118.46,  Max Value: 118400.00,  Date Range: 2015-11-18 00:00:00 to 2024-05-15 00:00:00
# Market: Ibadan, Bodija,  Unit: kg,  Min Value: 195.17,  Max Value: 109800.00,  Date Range: 2023-05-31 00:00:00 to 2023-08-16 00:00:00
# Market: Kano, Dawanau,  Unit: kg,  Min Value: 75.91,  Max Value: 108300.00,  Date Range: 2021-06-16 00:00:00 to 2024-05-15 00:00:00
# Market: Kaura Namoda,  Unit: kg,  Min Value: 136.32,  Max Value: 124600.00,  Date Range: 2021-06-30 00:00:00 to 2024-05-15 00:00:00
# Market: Lagos, Mile 12,  Unit: kg,  Min Value: 187.50,  Max Value: 129400.00,  Date Range: 2021-08-11 00:00:00 to 2024-05-15 00:00:00
# Market: Maiduguri,  Unit: kg,  Min Value: 105.45,  Max Value: 120000.00,  Date Range: 2021-05-19 00:00:00 to 2024-05-15 00:00:00
# Market: Mubi,  Unit: kg,  Min Value: 99.13,  Max Value: 90000.00,  Date Range: 2022-08-17 00:00:00 to 2024-05-15 00:00:00
# Market: Potiskum,  Unit: kg,  Min Value: 112.50,  Max Value: 85000.00,  Date Range: 2022-06-29 00:00:00 to 2024-05-15 00:00:00
# Market: Saminaka,  Unit: kg,  Min Value: 106.89,  Max Value: 145800.00,  Date Range: 2019-11-06 00:00:00 to 2024-05-15 00:00:00
#
# No outliers detected for Product: Macaroni.
#
# Outlier Analysis for Millet (Pearl)
#
# Country: Nigeria
# ========================
# Min Value: 25080.0, Max Value: 78300.0, Indices: 583207 - 869769
#
# Market: Aba,  Unit: kg,  Min Value: 82.14,  Max Value: 78300.00,  Date Range: 2016-08-24 00:00:00 to 2024-05-15 00:00:00
# Market: Biu,  Unit: kg,  Min Value: 37.59,  Max Value: 54860.00,  Date Range: 2021-07-07 00:00:00 to 2024-05-15 00:00:00
# Market: Damaturu,  Unit: kg,  Min Value: 37.59,  Max Value: 60000.00,  Date Range: 2023-06-28 00:00:00 to 2024-05-15 00:00:00
# Market: Dandume,  Unit: kg,  Min Value: 26.00,  Max Value: 59700.00,  Date Range: 2021-07-28 00:00:00 to 2024-05-15 00:00:00
# Market: Giwa,  Unit: kg,  Min Value: 41.48,  Max Value: 60800.00,  Date Range: 2021-06-30 00:00:00 to 2024-05-15 00:00:00
# Market: Gombe,  Unit: kg,  Min Value: 46.15,  Max Value: 60000.00,  Date Range: 2022-07-27 00:00:00 to 2024-05-15 00:00:00
# Market: Gujungu,  Unit: kg,  Min Value: 32.23,  Max Value: 62000.00,  Date Range: 2021-07-14 00:00:00 to 2024-05-15 00:00:00
# Market: Gwandu, Dodoru,  Unit: kg,  Min Value: 39.35,  Max Value: 64440.00,  Date Range: 2021-06-23 00:00:00 to 2024-05-15 00:00:00
# Market: Ibadan, Bodija,  Unit: kg,  Min Value: 60.98,  Max Value: 48000.00,  Date Range: 2021-06-30 00:00:00 to 2023-08-16 00:00:00
# Market: Kano, Dawanau,  Unit: 100_kg,  Min Value: 37.31,  Max Value: 67900.00,  Date Range: 2018-08-08 00:00:00 to 2024-05-15 00:00:00
# Market: Kaura Namoda,  Unit: kg,  Min Value: 21.00,  Max Value: 61200.00,  Date Range: 2021-06-23 00:00:00 to 2024-05-15 00:00:00
# Market: Lagos, Mile 12,  Unit: kg,  Min Value: 60.00,  Max Value: 66200.00,  Date Range: 2021-04-28 00:00:00 to 2024-05-15 00:00:00
# Market: Maiduguri,  Unit: kg,  Min Value: 41.50,  Max Value: 65000.00,  Date Range: 2021-07-28 00:00:00 to 2024-05-15 00:00:00
# Market: Mubi,  Unit: kg,  Min Value: 60.15,  Max Value: 64200.00,  Date Range: 2021-06-23 00:00:00 to 2024-05-15 00:00:00
# Market: Potiskum,  Unit: kg,  Min Value: 25.00,  Max Value: 60000.00,  Date Range: 2023-05-17 00:00:00 to 2024-05-15 00:00:00
# Market: Saminaka,  Unit: kg,  Min Value: 40.00,  Max Value: 65000.00,  Date Range: 2022-11-16 00:00:00 to 2024-04-17 00:00:00
#
# Outlier Analysis for Onions
#
# Country: Chad
# =====================
# Min Value: 1409.77, Max Value: 3150.0, Indices: 12452 - 60922
#
# Market: Biltine,  Unit: kg,  Min Value: 305.00,  Max Value: 1500.00,  Date Range: 2023-11-15 00:00:00 to 2023-11-15 00:00:00
# Market: Bol,  Unit: kg,  Min Value: 180.00,  Max Value: 1842.11,  Date Range: 2023-11-22 00:00:00 to 2023-11-29 00:00:00
# Market: Bongor,  Unit: kg,  Min Value: 350.00,  Max Value: 3150.00,  Date Range: 2010-07-31 00:00:00 to 2020-09-30 00:00:00
# Market: Faya,  Unit: kg,  Min Value: 240.00,  Max Value: 2250.00,  Date Range: 2023-11-01 00:00:00 to 2023-12-27 00:00:00
# Market: Moundou,  Unit: kg,  Min Value: 300.00,  Max Value: 1536.00,  Date Range: 2023-10-11 00:00:00 to 2023-11-29 00:00:00
# Market: Peni,  Unit: kg,  Min Value: 601.50,  Max Value: 2124.06,  Date Range: 2023-11-15 00:00:00 to 2023-12-06 00:00:00
# Market: Sarh,  Unit: kg,  Min Value: 300.00,  Max Value: 1696.43,  Date Range: 2019-01-31 00:00:00 to 2023-11-29 00:00:00
#
# Outlier Analysis for Refined sugar
#
# Country: Chad
# =====================
# Min Value: 684.931506849315, Max Value: 1400.0, Indices: 3130 - 60987
#
# Market: Abeche,  Unit: kg,  Min Value: 1000.00,  Max Value: 1300.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Amtiman,  Unit: kg,  Min Value: 1007.41,  Max Value: 1111.11,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Bagasola,  Unit: kg,  Min Value: 982.14,  Max Value: 1200.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Biltine,  Unit: kg,  Min Value: 1056.00,  Max Value: 1300.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Bol,  Unit: kg,  Min Value: 1000.00,  Max Value: 1140.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Bongor,  Unit: kg,  Min Value: 862.07,  Max Value: 1040.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Faya,  Unit: kg,  Min Value: 1000.00,  Max Value: 1400.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Kelo,  Unit: kg,  Min Value: 862.07,  Max Value: 1200.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Mao,  Unit: kg,  Min Value: 925.93,  Max Value: 1103.70,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Mongo,  Unit: kg,  Min Value: 1000.00,  Max Value: 1111.11,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Moundou,  Unit: kg,  Min Value: 879.00,  Max Value: 1076.92,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Moussoro,  Unit: kg,  Min Value: 1055.55,  Max Value: 1111.11,  Date Range: 2023-09-13 00:00:00 to 2024-05-29 00:00:00
# Market: N'Djamena,  Unit: kg,  Min Value: 962.96,  Max Value: 1056.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Pala,  Unit: kg,  Min Value: 862.07,  Max Value: 1120.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Peni,  Unit: kg,  Min Value: 684.93,  Max Value: 1060.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
# Market: Sarh,  Unit: kg,  Min Value: 776.00,  Max Value: 1000.00,  Date Range: 2023-09-06 00:00:00 to 2024-05-29 00:00:00
#
# Country: Haiti
# ======================
# Min Value: 510.0, Max Value: 1400.0, Indices: 254497 - 488542
#
# Market: Cap Haitien,  Unit: 6_lb,  Min Value: 60.00,  Max Value: 900.00,  Date Range: 2022-11-29 00:00:00 to 2024-04-30 00:00:00
# Market: Fond-des-Negres,  Unit: 6_lb,  Min Value: 150.00,  Max Value: 1400.00,  Date Range: 2019-10-29 00:00:00 to 2023-07-11 00:00:00
# Market: Gonaives,  Unit: 6_lb,  Min Value: 70.00,  Max Value: 900.00,  Date Range: 2022-08-09 00:00:00 to 2024-04-30 00:00:00
# Market: Hinche,  Unit: 6_lb,  Min Value: 70.00,  Max Value: 1400.00,  Date Range: 2022-01-04 00:00:00 to 2024-04-30 00:00:00
# Market: Jacmel,  Unit: 6_lb,  Min Value: 60.00,  Max Value: 900.00,  Date Range: 2022-05-03 00:00:00 to 2024-04-30 00:00:00
# Market: Jeremie,  Unit: 6_lb,  Min Value: 80.00,  Max Value: 1200.00,  Date Range: 2022-01-25 00:00:00 to 2024-04-30 00:00:00
# Market: Ouanaminthe,  Unit: 6_lb,  Min Value: 90.00,  Max Value: 1163.75,  Date Range: 2022-05-17 00:00:00 to 2024-04-30 00:00:00
# Market: Port-au-Prince, Croix-de-Bossales,  Unit: 6_lb,  Min Value: 60.00,  Max Value: 600.00,  Date Range: 2022-08-09 00:00:00 to 2022-09-27 00:00:00
# Market: Port-de-Paix,  Unit: 6_lb,  Min Value: 70.00,  Max Value: 1200.00,  Date Range: 2022-04-05 00:00:00 to 2024-04-30 00:00:00
#
# Country: Somalia
# ========================
# Min Value: 2933.0, Max Value: 36250.0, Indices: 888396 - 953947
#
# Market: Baidoa,  Unit: kg,  Min Value: 3450.00,  Max Value: 35500.00,  Date Range: 1995-07-31 00:00:00 to 2024-05-31 00:00:00
# Market: Kismayo,  Unit: kg,  Min Value: 3000.00,  Max Value: 34750.00,  Date Range: 1996-01-31 00:00:00 to 2024-05-31 00:00:00
# Market: Mogadishu, Bakara,  Unit: kg,  Min Value: 2933.00,  Max Value: 36250.00,  Date Range: 1995-01-31 00:00:00 to 2024-05-31 00:00:00
# Market: Qorioley,  Unit: kg,  Min Value: 3000.00,  Max Value: 36250.00,  Date Range: 1997-12-31 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Refined Vegetable Oil
#
# Country: Congo (DRC)
# ============================
# Min Value: 4773.0, Max Value: 11000.0, Indices: 67615 - 145741
#
# Market: Beni, Kilokwa,  Unit: L,  Min Value: 833.00,  Max Value: 8000.00,  Date Range: 2022-07-06 00:00:00 to 2023-05-24 00:00:00
# Market: Bukavu, Kadutu (Central),  Unit: L,  Min Value: 1821.00,  Max Value: 6500.00,  Date Range: 2022-03-02 00:00:00 to 2023-06-07 00:00:00
# Market: Bunia, Marché Central,  Unit: L,  Min Value: 1700.00,  Max Value: 5860.00,  Date Range: 2022-03-09 00:00:00 to 2022-09-07 00:00:00
# Market: Gbadolite, Marché Central,  Unit: L,  Min Value: 7812.50,  Max Value: 7812.50,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Goma, Virunga (Central),  Unit: L,  Min Value: 1500.00,  Max Value: 7143.00,  Date Range: 2020-12-16 00:00:00 to 2024-04-24 00:00:00
# Market: Inongo, Marché Central,  Unit: L,  Min Value: 6428.57,  Max Value: 6904.76,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kalemie, Lukuga,  Unit: L,  Min Value: 1429.00,  Max Value: 7500.00,  Date Range: 2018-03-31 00:00:00 to 2024-01-24 00:00:00
# Market: Kananga, Ndesha,  Unit: L,  Min Value: 2333.33,  Max Value: 8100.00,  Date Range: 2021-02-17 00:00:00 to 2024-05-29 00:00:00
# Market: Kasumbalesa, Marché Central,  Unit: L,  Min Value: 2000.00,  Max Value: 7333.00,  Date Range: 2021-06-09 00:00:00 to 2024-05-29 00:00:00
# Market: Kikwit, Marché Central,  Unit: L,  Min Value: 2900.00,  Max Value: 5000.00,  Date Range: 2023-02-22 00:00:00 to 2024-05-29 00:00:00
# Market: Kindu, Mama Yemo,  Unit: L,  Min Value: 2100.00,  Max Value: 8333.33,  Date Range: 2020-06-30 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Central,  Unit: L,  Min Value: 700.00,  Max Value: 5199.80,  Date Range: 2022-04-27 00:00:00 to 2023-01-25 00:00:00
# Market: Kinshasa, Marché de Matadi Kibala,  Unit: L,  Min Value: 6066.67,  Max Value: 11000.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kinshasa, Marché de Somba Zigida,  Unit: L,  Min Value: 5000.00,  Max Value: 5000.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Kisangani, Marché du 24 Novembre,  Unit: L,  Min Value: 5333.33,  Max Value: 5333.33,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Lubumbashi, Laurent Kabila,  Unit: L,  Min Value: 1700.00,  Max Value: 7166.00,  Date Range: 2018-07-31 00:00:00 to 2024-05-29 00:00:00
# Market: Lusambo, Marché Central,  Unit: L,  Min Value: 8726.00,  Max Value: 8726.00,  Date Range: 2024-05-01 00:00:00 to 2024-05-29 00:00:00
# Market: Mbadaka, Marché Central,  Unit: L,  Min Value: 1125.00,  Max Value: 6111.11,  Date Range: 2022-06-15 00:00:00 to 2024-03-20 00:00:00
# Market: Mbuji-mayi, Marché Central,  Unit: L,  Min Value: 1644.00,  Max Value: 8287.67,  Date Range: 2018-08-31 00:00:00 to 2024-05-29 00:00:00
# Market: Tshikapa, Kamalengo,  Unit: L,  Min Value: 1866.67,  Max Value: 5333.00,  Date Range: 2022-04-06 00:00:00 to 2024-05-29 00:00:00
# Market: Uvira, Maendeleo,  Unit: L,  Min Value: 1452.00,  Max Value: 7000.00,  Date Range: 2021-11-17 00:00:00 to 2024-01-31 00:00:00
#
# Country: Somalia
# ========================
# Min Value: 5000.0, Max Value: 100000.0, Indices: 888743 - 954228
#
# Market: Baidoa,  Unit: L,  Min Value: 7875.00,  Max Value: 85000.00,  Date Range: 2001-02-28 00:00:00 to 2024-05-31 00:00:00
# Market: Burao,  Unit: L,  Min Value: 4500.00,  Max Value: 25400.00,  Date Range: 2001-02-28 00:00:00 to 2024-05-31 00:00:00
# Market: Dhusamareb,  Unit: L,  Min Value: 14666.00,  Max Value: 90000.00,  Date Range: 2002-03-31 00:00:00 to 2024-05-31 00:00:00
# Market: Kismayo,  Unit: L,  Min Value: 7000.00,  Max Value: 100000.00,  Date Range: 2000-12-31 00:00:00 to 2024-05-31 00:00:00
# Market: Mogadishu, Bakara,  Unit: L,  Min Value: 6500.00,  Max Value: 64000.00,  Date Range: 2000-12-31 00:00:00 to 2024-05-31 00:00:00
# Market: Qorioley,  Unit: L,  Min Value: 6166.00,  Max Value: 70000.00,  Date Range: 2001-01-31 00:00:00 to 2024-05-31 00:00:00
#
# Country: South Sudan
# ============================
# Min Value: 4780.0, Max Value: 15800.0, Indices: 964968 - 1005802
#
# Market: Aweil,  Unit: L,  Min Value: 1033.33,  Max Value: 7000.00,  Date Range: 2024-05-10 00:00:00 to 2024-05-31 00:00:00
# Market: Fangak,  Unit: L,  Min Value: 600.00,  Max Value: 7000.00,  Date Range: 2024-02-09 00:00:00 to 2024-05-31 00:00:00
# Market: Juba, Konyokonyo,  Unit: L,  Min Value: 2000.00,  Max Value: 7475.00,  Date Range: 2024-05-03 00:00:00 to 2024-05-31 00:00:00
# Market: Kapoeta,  Unit: L,  Min Value: 2400.00,  Max Value: 10000.00,  Date Range: 2024-03-22 00:00:00 to 2024-05-31 00:00:00
# Market: Leer,  Unit: L,  Min Value: 2000.00,  Max Value: 5320.00,  Date Range: 2024-02-09 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: L,  Min Value: 762.00,  Max Value: 7000.00,  Date Range: 2023-08-25 00:00:00 to 2024-05-31 00:00:00
# Market: Malakal, Aburoc,  Unit: L,  Min Value: 1020.00,  Max Value: 8000.00,  Date Range: 2023-07-14 00:00:00 to 2024-05-31 00:00:00
# Market: Meyendit,  Unit: L,  Min Value: 1366.67,  Max Value: 15800.00,  Date Range: 2023-10-13 00:00:00 to 2024-05-31 00:00:00
# Market: Pibor,  Unit: L,  Min Value: 1400.00,  Max Value: 12900.00,  Date Range: 2023-02-10 00:00:00 to 2024-05-31 00:00:00
# Market: Poktap,  Unit: L,  Min Value: 1200.00,  Max Value: 8000.00,  Date Range: 2024-01-12 00:00:00 to 2024-05-31 00:00:00
# Market: Torit,  Unit: L,  Min Value: 800.00,  Max Value: 9000.00,  Date Range: 2022-02-25 00:00:00 to 2024-05-31 00:00:00
# Market: Yei,  Unit: L,  Min Value: 500.00,  Max Value: 6000.00,  Date Range: 2024-05-17 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Rice (5% Broken)
#
# Country: Nigeria
# ========================
# Min Value: 36200.0, Max Value: 86000.0, Indices: 585504 - 871752
#
# Market: Aba,  Unit: kg,  Min Value: 94.34,  Max Value: 81000.00,  Date Range: 2022-10-19 00:00:00 to 2024-05-15 00:00:00
# Market: Biu,  Unit: kg,  Min Value: 171.26,  Max Value: 76840.00,  Date Range: 2021-02-10 00:00:00 to 2024-05-15 00:00:00
# Market: Damaturu,  Unit: kg,  Min Value: 181.00,  Max Value: 78000.00,  Date Range: 2023-08-09 00:00:00 to 2024-05-15 00:00:00
# Market: Dandume,  Unit: kg,  Min Value: 95.00,  Max Value: 45860.00,  Date Range: 2023-05-03 00:00:00 to 2023-09-13 00:00:00
# Market: Giwa,  Unit: kg,  Min Value: 95.00,  Max Value: 64160.00,  Date Range: 2022-11-09 00:00:00 to 2024-02-14 00:00:00
# Market: Gombe,  Unit: kg,  Min Value: 146.66,  Max Value: 85000.00,  Date Range: 2022-09-28 00:00:00 to 2024-05-15 00:00:00
# Market: Gwandu, Dodoru,  Unit: kg,  Min Value: 127.69,  Max Value: 75900.00,  Date Range: 2023-08-23 00:00:00 to 2024-05-15 00:00:00
# Market: Ibadan, Bodija,  Unit: kg,  Min Value: 140.24,  Max Value: 83000.00,  Date Range: 2022-11-16 00:00:00 to 2024-05-15 00:00:00
# Market: Kano, Dawanau,  Unit: kg,  Min Value: 98.50,  Max Value: 66500.00,  Date Range: 2024-04-24 00:00:00 to 2024-05-15 00:00:00
# Market: Kaura Namoda,  Unit: kg,  Min Value: 93.00,  Max Value: 67960.00,  Date Range: 2023-07-26 00:00:00 to 2024-05-15 00:00:00
# Market: Lagos, Mile 12,  Unit: kg,  Min Value: 120.00,  Max Value: 85800.00,  Date Range: 2022-10-26 00:00:00 to 2024-05-15 00:00:00
# Market: Maiduguri,  Unit: kg,  Min Value: 131.00,  Max Value: 86000.00,  Date Range: 2022-08-17 00:00:00 to 2024-05-15 00:00:00
# Market: Mubi,  Unit: kg,  Min Value: 139.13,  Max Value: 60000.00,  Date Range: 2023-07-05 00:00:00 to 2024-05-15 00:00:00
# Market: Potiskum,  Unit: kg,  Min Value: 181.15,  Max Value: 47000.00,  Date Range: 2023-05-17 00:00:00 to 2023-11-29 00:00:00
# Market: Saminaka,  Unit: kg,  Min Value: 144.00,  Max Value: 72000.00,  Date Range: 2021-04-21 00:00:00 to 2024-01-03 00:00:00
#
# Outlier Analysis for Rice (Milled)
#
# Country: Congo (DRC)
# ============================
# Min Value: 5900.0, Max Value: 12000.0, Indices: 68108 - 146173
#
# Market: Beni, Kilokwa,  Unit: kg,  Min Value: 729.00,  Max Value: 10747.33,  Date Range: 2023-08-09 00:00:00 to 2023-12-06 00:00:00
# Market: Kindu, Mama Yemo,  Unit: kg,  Min Value: 570.00,  Max Value: 7255.81,  Date Range: 2023-10-11 00:00:00 to 2023-12-27 00:00:00
# Market: Lubumbashi, Laurent Kabila,  Unit: kg,  Min Value: 633.00,  Max Value: 12000.00,  Date Range: 2020-12-16 00:00:00 to 2023-07-12 00:00:00
# Market: Mbuji-mayi, Marché Central,  Unit: kg,  Min Value: 875.00,  Max Value: 7300.00,  Date Range: 2018-10-31 00:00:00 to 2021-10-13 00:00:00
# Market: Uvira, Maendeleo,  Unit: kg,  Min Value: 259.00,  Max Value: 10657.14,  Date Range: 2023-10-25 00:00:00 to 2023-10-25 00:00:00
#
# Country: Nigeria
# ========================
# Min Value: 6000.0, Max Value: 141900.0, Indices: 586140 - 873250
#
# Market: Aba,  Unit: kg,  Min Value: 135.00,  Max Value: 124160.00,  Date Range: 2012-06-06 00:00:00 to 2024-05-15 00:00:00
# Market: Biu,  Unit: kg,  Min Value: 106.76,  Max Value: 54900.00,  Date Range: 2015-01-28 00:00:00 to 2024-05-15 00:00:00
# Market: Damaturu,  Unit: kg,  Min Value: 124.55,  Max Value: 127000.00,  Date Range: 2015-01-21 00:00:00 to 2024-05-15 00:00:00
# Market: Dandume,  Unit: kg,  Min Value: 92.66,  Max Value: 126000.00,  Date Range: 2013-11-27 00:00:00 to 2024-05-15 00:00:00
# Market: Giwa,  Unit: kg,  Min Value: 100.00,  Max Value: 126800.00,  Date Range: 2013-11-27 00:00:00 to 2024-05-01 00:00:00
# Market: Gombe,  Unit: kg,  Min Value: 86.66,  Max Value: 110000.00,  Date Range: 2012-05-02 00:00:00 to 2024-05-15 00:00:00
# Market: Gujungu,  Unit: kg,  Min Value: 116.72,  Max Value: 128000.00,  Date Range: 2012-05-02 00:00:00 to 2024-05-15 00:00:00
# Market: Gwandu, Dodoru,  Unit: kg,  Min Value: 105.00,  Max Value: 123000.00,  Date Range: 2012-05-02 00:00:00 to 2024-05-15 00:00:00
# Market: Ibadan, Bodija,  Unit: kg,  Min Value: 83.00,  Max Value: 138000.00,  Date Range: 2014-07-23 00:00:00 to 2024-05-15 00:00:00
# Market: Kano, Dawanau,  Unit: kg,  Min Value: 100.00,  Max Value: 141900.00,  Date Range: 2013-11-27 00:00:00 to 2024-05-15 00:00:00
# Market: Kaura Namoda,  Unit: kg,  Min Value: 100.00,  Max Value: 131000.00,  Date Range: 2013-11-27 00:00:00 to 2024-05-15 00:00:00
# Market: Lagos, Mile 12,  Unit: kg,  Min Value: 160.00,  Max Value: 65200.00,  Date Range: 2012-05-02 00:00:00 to 2024-05-15 00:00:00
# Market: Maiduguri,  Unit: kg,  Min Value: 122.22,  Max Value: 120000.00,  Date Range: 2012-05-02 00:00:00 to 2024-05-15 00:00:00
# Market: Mubi,  Unit: kg,  Min Value: 99.16,  Max Value: 47000.00,  Date Range: 2015-01-28 00:00:00 to 2024-05-15 00:00:00
# Market: Potiskum,  Unit: kg,  Min Value: 96.08,  Max Value: 120000.00,  Date Range: 2015-01-21 00:00:00 to 2024-05-15 00:00:00
# Market: Saminaka,  Unit: kg,  Min Value: 100.00,  Max Value: 121000.00,  Date Range: 2012-05-02 00:00:00 to 2024-05-15 00:00:00
#
# Outlier Analysis for Sesame (White)
#
# Country: Chad
# =====================
# Min Value: 1372.09, Max Value: 2000.0, Indices: 10582 - 49621
#
# Market: Bagasola,  Unit: kg,  Min Value: 860.00,  Max Value: 1424.00,  Date Range: 2023-09-20 00:00:00 to 2023-09-27 00:00:00
# Market: Bol,  Unit: kg,  Min Value: 420.00,  Max Value: 2000.00,  Date Range: 2018-07-31 00:00:00 to 2023-11-01 00:00:00
# Market: Bongor,  Unit: kg,  Min Value: 260.00,  Max Value: 1627.91,  Date Range: 2023-09-27 00:00:00 to 2023-11-15 00:00:00
# Market: Kelo,  Unit: kg,  Min Value: 180.00,  Max Value: 1416.00,  Date Range: 2023-10-11 00:00:00 to 2023-10-11 00:00:00
# Market: Moundou,  Unit: kg,  Min Value: 200.00,  Max Value: 1657.00,  Date Range: 2023-10-11 00:00:00 to 2024-05-22 00:00:00
# Market: Moussoro,  Unit: kg,  Min Value: 490.00,  Max Value: 1440.22,  Date Range: 2023-09-27 00:00:00 to 2023-09-27 00:00:00
#
# Outlier Analysis for Sheep (Male, Medium-sized, Castrated)
#
# Country: Chad
# =====================
# Min Value: 65000.0, Max Value: 315000.0, Indices: 13068 - 35500
#
# Market: Biltine,  Unit: ea,  Min Value: 14000.00,  Max Value: 315000.00,  Date Range: 2013-01-31 00:00:00 to 2021-04-28 00:00:00
# Market: Faya,  Unit: ea,  Min Value: 21000.00,  Max Value: 78000.00,  Date Range: 2019-03-31 00:00:00 to 2023-06-26 00:00:00
# Market: Mao,  Unit: ea,  Min Value: 13500.00,  Max Value: 66600.00,  Date Range: 2013-09-30 00:00:00 to 2013-09-30 00:00:00
#
# Outlier Analysis for Sorghum (Berbere)
#
# Country: Chad
# =====================
# Min Value: 423.404255319148, Max Value: 775.0, Indices: 17658 - 26932
#
# ...
# Market: Dinsor,  Unit: kg,  Min Value: 850.00,  Max Value: 66250.00,  Date Range: 2011-11-30 00:00:00 to 2011-11-30 00:00:00
# Market: Erigavo,  Unit: kg,  Min Value: 4000.00,  Max Value: 69500.00,  Date Range: 2022-10-31 00:00:00 to 2024-05-31 00:00:00
# Market: Galkayo,  Unit: kg,  Min Value: 2000.00,  Max Value: 80000.00,  Date Range: 2017-08-31 00:00:00 to 2024-05-31 00:00:00
# Market: Garowe,  Unit: kg,  Min Value: 2750.00,  Max Value: 87600.00,  Date Range: 2011-11-30 00:00:00 to 2024-01-31 00:00:00
# Market: Hudur,  Unit: kg,  Min Value: 1500.00,  Max Value: 78000.00,  Date Range: 2011-10-31 00:00:00 to 2023-05-31 00:00:00
# Market: Jowhar,  Unit: kg,  Min Value: 900.00,  Max Value: 78325.00,  Date Range: 2011-07-31 00:00:00 to 2011-10-31 00:00:00
# Market: Lasanod,  Unit: kg,  Min Value: 3900.00,  Max Value: 120000.00,  Date Range: 2011-09-30 00:00:00 to 2024-05-31 00:00:00
# Market: Lugh,  Unit: kg,  Min Value: 1500.00,  Max Value: 130000.00,  Date Range: 2008-05-31 00:00:00 to 2024-05-31 00:00:00
# Market: Mogadishu, Bakara,  Unit: kg,  Min Value: 1733.00,  Max Value: 66666.00,  Date Range: 2011-07-31 00:00:00 to 2011-07-31 00:00:00
# Market: Qorioley,  Unit: kg,  Min Value: 1718.00,  Max Value: 74750.00,  Date Range: 2011-07-31 00:00:00 to 2011-08-31 00:00:00
#
# Outlier Analysis for Rice (Parboiled)
#
# Country: Somalia
# ========================
# Min Value: 39750.0, Max Value: 60000.0, Indices: 879391 - 954358
#
# Market: Adanyabal,  Unit: kg,  Min Value: 20000.00,  Max Value: 41500.00,  Date Range: 2016-04-30 00:00:00 to 2023-05-31 00:00:00
# Market: Afmadow,  Unit: kg,  Min Value: 4000.00,  Max Value: 46000.00,  Date Range: 2008-07-31 00:00:00 to 2008-12-31 00:00:00
# Market: Baidoa,  Unit: kg,  Min Value: 3150.00,  Max Value: 43500.00,  Date Range: 2008-06-30 00:00:00 to 2008-09-30 00:00:00
# Market: Beled Weyn,  Unit: kg,  Min Value: 4000.00,  Max Value: 44000.00,  Date Range: 2008-07-31 00:00:00 to 2008-09-30 00:00:00
# Market: Bossaso,  Unit: kg,  Min Value: 3500.00,  Max Value: 45500.00,  Date Range: 2008-07-31 00:00:00 to 2008-08-31 00:00:00
# Market: Buale,  Unit: kg,  Min Value: 1775.00,  Max Value: 60000.00,  Date Range: 2008-06-30 00:00:00 to 2008-10-31 00:00:00
# Market: Dhusamareb,  Unit: kg,  Min Value: 6000.00,  Max Value: 48500.00,  Date Range: 2008-06-30 00:00:00 to 2009-01-31 00:00:00
# Market: El Barde,  Unit: kg,  Min Value: 21600.00,  Max Value: 50000.00,  Date Range: 2018-06-30 00:00:00 to 2024-01-31 00:00:00
# Market: Erigavo,  Unit: kg,  Min Value: 3600.00,  Max Value: 45000.00,  Date Range: 2008-06-30 00:00:00 to 2024-04-30 00:00:00
# Market: Galkayo,  Unit: kg,  Min Value: 3666.00,  Max Value: 48500.00,  Date Range: 2008-06-30 00:00:00 to 2008-09-30 00:00:00
# Market: Garowe,  Unit: kg,  Min Value: 3500.00,  Max Value: 48250.00,  Date Range: 2008-07-31 00:00:00 to 2008-09-30 00:00:00
# Market: Kismayo,  Unit: kg,  Min Value: 3500.00,  Max Value: 47000.00,  Date Range: 2008-06-30 00:00:00 to 2008-10-31 00:00:00
# Market: Lasanod,  Unit: kg,  Min Value: 14000.00,  Max Value: 43500.00,  Date Range: 2022-09-30 00:00:00 to 2024-05-31 00:00:00
# Market: Lugh,  Unit: kg,  Min Value: 4500.00,  Max Value: 60000.00,  Date Range: 2008-05-31 00:00:00 to 2011-04-30 00:00:00
# Market: Mogadishu, Bakara,  Unit: kg,  Min Value: 2125.00,  Max Value: 42200.00,  Date Range: 2008-06-30 00:00:00 to 2008-06-30 00:00:00
# Market: Qorioley,  Unit: kg,  Min Value: 3166.00,  Max Value: 43000.00,  Date Range: 2008-07-31 00:00:00 to 2008-09-30 00:00:00
#
# Outlier Analysis for Tea leaves (Mixed)
#
# Country: Somalia
# ========================
# Min Value: 98000.0, Max Value: 123000.0, Indices: 910885 - 927463
#
# Market: Dhusamareb,  Unit: kg,  Min Value: 60000.00,  Max Value: 102800.00,  Date Range: 2022-02-28 00:00:00 to 2024-03-31 00:00:00
# Market: El Barde,  Unit: kg,  Min Value: 55000.00,  Max Value: 120000.00,  Date Range: 2018-07-31 00:00:00 to 2023-01-31 00:00:00
# Market: Erigavo,  Unit: kg,  Min Value: 52500.00,  Max Value: 123000.00,  Date Range: 2021-02-28 00:00:00 to 2024-04-30 00:00:00
# Market: Hara Dhere,  Unit: kg,  Min Value: 56800.00,  Max Value: 98000.00,  Date Range: 2022-10-31 00:00:00 to 2022-10-31 00:00:00
#
# Outlier Analysis for Water (potable, drinking)
#
# Country: Somalia
# ========================
# Min Value: 61000.0, Max Value: 185000.0, Indices: 884255 - 955094
#
# Market: Afmadow,  Unit: 200_L,  Min Value: 10000.00,  Max Value: 80000.00,  Date Range: 2017-09-30 00:00:00 to 2018-03-31 00:00:00
# Market: El Barde,  Unit: 200_L,  Min Value: 18500.00,  Max Value: 83750.00,  Date Range: 2017-07-31 00:00:00 to 2022-04-30 00:00:00
# Market: El Dhere,  Unit: 200_L,  Min Value: 8000.00,  Max Value: 100000.00,  Date Range: 2016-06-30 00:00:00 to 2016-07-31 00:00:00
# Market: Hudur,  Unit: 200_L,  Min Value: 15000.00,  Max Value: 129000.00,  Date Range: 2022-02-28 00:00:00 to 2024-05-31 00:00:00
# Market: Kismayo,  Unit: 200_L,  Min Value: 37500.00,  Max Value: 80000.00,  Date Range: 2015-05-31 00:00:00 to 2024-05-31 00:00:00
# Market: Lasanod,  Unit: 200_L,  Min Value: 30000.00,  Max Value: 185000.00,  Date Range: 2016-08-31 00:00:00 to 2024-04-30 00:00:00
# Market: Qorioley,  Unit: 200_L,  Min Value: 10000.00,  Max Value: 62500.00,  Date Range: 2016-03-31 00:00:00 to 2016-04-30 00:00:00
#
# No outliers detected for Product: Goats (Export Quality).
#
# Outlier Analysis for Grain milling services
#
# Country: Somalia
# ========================
# Min Value: 8000.0, Max Value: 24000.0, Indices: 912253 - 922618
#
# Market: Dinsor,  Unit: kg,  Min Value: 2000.00,  Max Value: 8000.00,  Date Range: 2021-02-28 00:00:00 to 2021-02-28 00:00:00
# Market: Erigavo,  Unit: kg,  Min Value: 3000.00,  Max Value: 24000.00,  Date Range: 2021-01-31 00:00:00 to 2024-05-31 00:00:00
# Market: Galkayo,  Unit: kg,  Min Value: 3000.00,  Max Value: 9500.00,  Date Range: 2021-04-30 00:00:00 to 2021-04-30 00:00:00
#
# Outlier Analysis for Soap
#
# Country: Somalia
# ========================
# Min Value: 1700.0, Max Value: 19000.0, Indices: 924014 - 931143
#
# Market: Galkayo,  Unit: ea,  Min Value: 12000.00,  Max Value: 19000.00,  Date Range: 2021-11-30 00:00:00 to 2022-04-30 00:00:00
# Market: Hargeisa,  Unit: ea,  Min Value: 1700.00,  Max Value: 5000.00,  Date Range: 2009-06-30 00:00:00 to 2013-03-31 00:00:00
#
# Country: Zimbabwe
# =========================
# Min Value: 1.59, Max Value: 293.19, Indices: 1010490 - 1010553
#
# Market: Harare, Mbare,  Unit: ea,  Min Value: 1.59,  Max Value: 293.19,  Date Range: 2018-02-28 00:00:00 to 2022-04-30 00:00:00
#
# Outlier Analysis for Beans (Brown)
#
# Country: South Sudan
# ============================
# Min Value: 3920.0, Max Value: 76000.0, Indices: 962033 - 1002742
#
# Market: Aweil,  Unit: kg,  Min Value: 600.00,  Max Value: 8833.33,  Date Range: 2024-02-23 00:00:00 to 2024-05-31 00:00:00
# Market: Juba, Konyokonyo,  Unit: kg,  Min Value: 450.00,  Max Value: 6333.33,  Date Range: 2024-03-29 00:00:00 to 2024-05-31 00:00:00
# Market: Kapoeta,  Unit: kg,  Min Value: 1533.33,  Max Value: 4333.33,  Date Range: 2024-05-10 00:00:00 to 2024-05-10 00:00:00
# Market: Leer,  Unit: kg,  Min Value: 1000.00,  Max Value: 7900.00,  Date Range: 2024-03-08 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: kg,  Min Value: 566.67,  Max Value: 76000.00,  Date Range: 2024-03-15 00:00:00 to 2024-05-31 00:00:00
# Market: Meyendit,  Unit: kg,  Min Value: 400.00,  Max Value: 11111.11,  Date Range: 2024-05-31 00:00:00 to 2024-05-31 00:00:00
# Market: Pibor,  Unit: kg,  Min Value: 880.00,  Max Value: 6550.00,  Date Range: 2023-11-24 00:00:00 to 2024-05-31 00:00:00
# Market: Torit,  Unit: kg,  Min Value: 500.00,  Max Value: 5160.00,  Date Range: 2023-12-22 00:00:00 to 2023-12-29 00:00:00
# Market: Yei,  Unit: kg,  Min Value: 373.00,  Max Value: 4000.00,  Date Range: 2024-05-17 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Beans (Yellow)
#
# Country: South Sudan
# ============================
# Min Value: 5430.0, Max Value: 36383.33, Indices: 962198 - 1001969
#
# Market: Aweil,  Unit: kg,  Min Value: 1866.67,  Max Value: 5500.00,  Date Range: 2024-05-17 00:00:00 to 2024-05-24 00:00:00
# Market: Juba, Konyokonyo,  Unit: kg,  Min Value: 1916.67,  Max Value: 6000.00,  Date Range: 2024-05-03 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: kg,  Min Value: 600.00,  Max Value: 12433.33,  Date Range: 2024-03-08 00:00:00 to 2024-05-31 00:00:00
# Market: Meyendit,  Unit: kg,  Min Value: 300.00,  Max Value: 27500.00,  Date Range: 2021-06-25 00:00:00 to 2024-05-31 00:00:00
# Market: Pibor,  Unit: kg,  Min Value: 920.00,  Max Value: 7966.67,  Date Range: 2023-05-26 00:00:00 to 2024-05-31 00:00:00
# Market: Poktap,  Unit: kg,  Min Value: 900.00,  Max Value: 6444.44,  Date Range: 2024-05-03 00:00:00 to 2024-05-31 00:00:00
# Market: Wau,  Unit: kg,  Min Value: 2000.00,  Max Value: 36383.33,  Date Range: 2024-05-10 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Chickens (Live)
#
# Country: South Sudan
# ============================
# Min Value: 12333.33, Max Value: 27433.33, Indices: 963198 - 1003966
#
# Market: Aweil,  Unit: ea,  Min Value: 4166.67,  Max Value: 15666.67,  Date Range: 2024-04-26 00:00:00 to 2024-05-31 00:00:00
# Market: Juba, Konyokonyo,  Unit: ea,  Min Value: 15100.00,  Max Value: 15100.00,  Date Range: 2024-02-16 00:00:00 to 2024-02-16 00:00:00
# Market: Kapoeta,  Unit: ea,  Min Value: 6500.00,  Max Value: 12500.00,  Date Range: 2024-05-24 00:00:00 to 2024-05-24 00:00:00
# Market: Leer,  Unit: ea,  Min Value: 3000.00,  Max Value: 13050.00,  Date Range: 2024-05-17 00:00:00 to 2024-05-31 00:00:00
# Market: Malakal, Aburoc,  Unit: ea,  Min Value: 760.00,  Max Value: 17150.00,  Date Range: 2024-03-22 00:00:00 to 2024-03-22 00:00:00
# Market: Meyendit,  Unit: ea,  Min Value: 2750.00,  Max Value: 27433.33,  Date Range: 2024-03-22 00:00:00 to 2024-03-22 00:00:00
# Market: Pibor,  Unit: ea,  Min Value: 2200.00,  Max Value: 14760.00,  Date Range: 2023-11-24 00:00:00 to 2024-05-17 00:00:00
# Market: Torit,  Unit: ea,  Min Value: 3000.00,  Max Value: 20000.00,  Date Range: 2023-12-15 00:00:00 to 2024-05-31 00:00:00
# Market: Yei,  Unit: ea,  Min Value: 4300.00,  Max Value: 26860.00,  Date Range: 2023-09-01 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Dry Lentils
#
# Country: South Sudan
# ============================
# Min Value: 5300.0, Max Value: 9233.33, Indices: 963491 - 1004272
#
# Market: Aweil,  Unit: kg,  Min Value: 2970.00,  Max Value: 9233.33,  Date Range: 2024-01-12 00:00:00 to 2024-05-31 00:00:00
# Market: Fangak,  Unit: kg,  Min Value: 400.00,  Max Value: 8000.00,  Date Range: 2024-02-02 00:00:00 to 2024-02-02 00:00:00
# Market: Juba, Konyokonyo,  Unit: kg,  Min Value: 2133.33,  Max Value: 6000.00,  Date Range: 2024-03-29 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: kg,  Min Value: 500.00,  Max Value: 8000.00,  Date Range: 2024-04-05 00:00:00 to 2024-05-31 00:00:00
# Market: Malakal, Aburoc,  Unit: kg,  Min Value: 300.00,  Max Value: 8000.00,  Date Range: 2024-05-03 00:00:00 to 2024-05-31 00:00:00
# Market: Pibor,  Unit: kg,  Min Value: 840.00,  Max Value: 8100.00,  Date Range: 2023-05-19 00:00:00 to 2024-05-31 00:00:00
# Market: Torit,  Unit: kg,  Min Value: 550.00,  Max Value: 8000.00,  Date Range: 2024-05-10 00:00:00 to 2024-05-31 00:00:00
# Market: Yei,  Unit: kg,  Min Value: 700.00,  Max Value: 6000.00,  Date Range: 2024-05-03 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Groundnuts (In Shell)
#
# Country: South Sudan
# ============================
# Min Value: 4166.67, Max Value: 5000.0, Indices: 971791 - 978596
#
# Market: Kapoeta,  Unit: kg,  Min Value: 2666.67,  Max Value: 4166.67,  Date Range: 2024-02-09 00:00:00 to 2024-02-09 00:00:00
# Market: Maiwut,  Unit: kg,  Min Value: 300.00,  Max Value: 5000.00,  Date Range: 2024-05-31 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Groundnut (without shell)
#
# Country: South Sudan
# ============================
# Min Value: 4533.33, Max Value: 7000.0, Indices: 964116 - 978749
#
# Market: Aweil,  Unit: kg,  Min Value: 900.00,  Max Value: 7000.00,  Date Range: 2024-04-26 00:00:00 to 2024-05-24 00:00:00
# Market: Kapoeta,  Unit: kg,  Min Value: 3466.67,  Max Value: 5066.67,  Date Range: 2024-02-09 00:00:00 to 2024-05-17 00:00:00
# Market: Maiwut,  Unit: kg,  Min Value: 400.00,  Max Value: 6000.00,  Date Range: 2024-04-26 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Maize Flour
#
# Country: South Sudan
# ============================
# Min Value: 98566.67, Max Value: 266500.0, Indices: 964426 - 1000239
#
# Market: Aweil,  Unit: 50_kg,  Min Value: 866.67,  Max Value: 113333.33,  Date Range: 2024-05-31 00:00:00 to 2024-05-31 00:00:00
# Market: Kapoeta,  Unit: kg,  Min Value: 1266.67,  Max Value: 99333.33,  Date Range: 2024-05-24 00:00:00 to 2024-05-31 00:00:00
# Market: Leer,  Unit: 50_kg,  Min Value: 770.00,  Max Value: 266500.00,  Date Range: 2024-04-05 00:00:00 to 2024-05-31 00:00:00
# Market: Meyendit,  Unit: 50_kg,  Min Value: 150.00,  Max Value: 247666.67,  Date Range: 2024-04-19 00:00:00 to 2024-05-31 00:00:00
# Market: Pibor,  Unit: 50_kg,  Min Value: 800.00,  Max Value: 218100.00,  Date Range: 2023-02-24 00:00:00 to 2024-05-31 00:00:00
# Market: Poktap,  Unit: 50_kg,  Min Value: 600.00,  Max Value: 149333.33,  Date Range: 2024-03-08 00:00:00 to 2024-05-31 00:00:00
# Market: Torit,  Unit: 50_kg,  Min Value: 250.00,  Max Value: 102500.00,  Date Range: 2024-05-10 00:00:00 to 2024-05-10 00:00:00
#
# Outlier Analysis for Sheep (2-3 years, Average Quality)
#
# Country: South Sudan
# ============================
# Min Value: 86600.0, Max Value: 470000.0, Indices: 965121 - 1005955
#
# Market: Aweil,  Unit: ea,  Min Value: 27833.33,  Max Value: 260833.33,  Date Range: 2024-05-10 00:00:00 to 2024-05-10 00:00:00
# Market: Fangak,  Unit: ea,  Min Value: 43000.00,  Max Value: 470000.00,  Date Range: 2024-04-05 00:00:00 to 2024-05-10 00:00:00
# Market: Juba, Konyokonyo,  Unit: ea,  Min Value: 106666.67,  Max Value: 106666.67,  Date Range: 2024-02-16 00:00:00 to 2024-02-16 00:00:00
# Market: Kapoeta,  Unit: ea,  Min Value: 40000.00,  Max Value: 108333.33,  Date Range: 2024-04-19 00:00:00 to 2024-05-17 00:00:00
# Market: Malakal, Aburoc,  Unit: ea,  Min Value: 9600.00,  Max Value: 262333.33,  Date Range: 2023-09-15 00:00:00 to 2024-05-31 00:00:00
# Market: Torit,  Unit: ea,  Min Value: 25000.00,  Max Value: 97500.00,  Date Range: 2024-03-29 00:00:00 to 2024-05-31 00:00:00
# Market: Yei,  Unit: ea,  Min Value: 25800.00,  Max Value: 130000.00,  Date Range: 2023-12-15 00:00:00 to 2024-05-31 00:00:00
#
# Outlier Analysis for Sorghum (Feterita)
#
# Country: South Sudan
# ============================
# Min Value: 62840.0, Max Value: 288028.8, Indices: 965402 - 1006175
#
# Market: Aweil,  Unit: 3.5_kg,  Min Value: 400.00,  Max Value: 141014.10,  Date Range: 2024-02-23 00:00:00 to 2024-04-12 00:00:00
# Market: Fangak,  Unit: 3.5_kg,  Min Value: 4166.67,  Max Value: 67506.75,  Date Range: 2024-05-03 00:00:00 to 2024-05-24 00:00:00
# Market: Leer,  Unit: 3.5_kg,  Min Value: 1540.00,  Max Value: 263312.33,  Date Range: 2023-04-21 00:00:00 to 2024-05-31 00:00:00
# Market: Maiwut,  Unit: 3.5_kg,  Min Value: 301.60,  Max Value: 288028.80,  Date Range: 2023-01-20 00:00:00 to 2024-05-31 00:00:00
# Market: Malakal, Aburoc,  Unit: 3.5_kg,  Min Value: 600.00,  Max Value: 85508.55,  Date Range: 2022-09-23 00:00:00 to 2024-05-31 00:00:00
# Market: Pibor,  Unit: 3.5_kg,  Min Value: 468.33,  Max Value: 99120.00,  Date Range: 2023-02-17 00:00:00 to 2023-11-24 00:00:00
# Market: Poktap,  Unit: 3.5_kg,  Min Value: 354.00,  Max Value: 95200.00,  Date Range: 2023-02-17 00:00:00 to 2023-05-05 00:00:00
# Market: Wau,  Unit: 3.5_kg,  Min Value: 2433.33,  Max Value: 120012.00,  Date Range: 2024-04-12 00:00:00 to 2024-04-12 00:00:00
# Market: Yei,  Unit: 3.5_kg,  Min Value: 392.00,  Max Value: 72000.00,  Date Range: 2023-06-16 00:00:00 to 2023-07-14 00:00:00
#
# Outlier Analysis for Roller Maize Meal
#
# Country: Zimbabwe
# =========================
# Min Value: 0.02, Max Value: 160.0, Indices: 1010112 - 1010489
#
# Market: Harare, Mbare,  Unit: kg,  Min Value: 0.02,  Max Value: 160.00,  Date Range: 2005-01-31 00:00:00 to 2022-04-30 00:00:00

# %% [markdown]
# Based on the thorough analysis of outliers, I strongly believe they are justified for various reasons:
#
# - **Currency Differences:** The value of goods is influenced by the currency used in each country. Countries with stronger currencies or higher inflation rates might show higher values, justifying outliers in countries like Haiti or Nigeria. For example,  In Somalia, the high value of camels can be attributed to the currency's purchasing power. If the local currency is weak or devalued, the recorded value might appear high compared to countries with stronger currencies, such as Nigeria or Haiti.
#
# - **Regional Price Differences:** Within a country, prices can vary significantly by region (admin_1 location). For example, the cost of goods in urban areas might be much higher than in rural areas, leading to higher recorded values in specific regions. In Ethiopia, the high values recorded for certain products might be due to significant regional price variations. Urban areas like Addis Ababa may have much higher prices for goods compared to rural regions, leading to outliers in urban data.
#
# - **Product-Specific Pricing:** Different products have different price ranges, which can lead to outliers when comparing values across products. A luxury item will naturally have a higher value than a basic commodity, justifying outliers in product-specific data. The value of camels in Somalia is a luxury item with a higher price range compared to everyday commodities. This results in higher values that are significantly different from other products, justifying outliers in camel data.
#
# - **Inflation and Economic Factors:** Countries experiencing high inflation or rapid economic changes may show higher values due to devaluation of currency or price increases. This can explain why some countries, like Ethiopia and South Sudan, have higher outliers. In South Sudan, high inflation rates and economic instability might lead to inflated prices for goods and services. This can result in high values recorded for various products, including commodities like camels or essential goods.
#
# - **Market Demand and Supply:** Variations in demand and supply dynamics in different countries can lead to higher values for certain products. High demand or low supply can drive prices up, resulting in outliers. In Nigeria, the high demand for specific products such as luxury items or essential resources can drive up prices. This higher demand can create outliers in value data, with items such as agricultural products or technology being priced higher.
#
# - **Data Reporting Standards:** Differences in how data is reported or recorded across countries can result in outliers. For example, discrepancies in data collection methods or reporting standards might lead to unusually high or low values.
#
# - **Economic Conditions and Local Costs:** Local economic conditions, such as cost of living, cost of production, and labor costs, impact the value of goods. Countries with higher local costs might show higher values, justifying outliers in such regions.
#
# - **Economic Variability:** Different countries have varying economic conditions which can result in significantly different values for similar products. For instance, higher values in Nigeria compared to Malawi can be attributed to Nigeria's larger economy and higher living costs. Nigeria, with its larger and more complex economy, might show higher values for various products compared to Malawi, where the economy is smaller. This economic variability can result in significant differences in recorded values across countries.
#
# ---

# %% [markdown]
# <!-- - **Somalia**
#   - **Maximum Value:** 26,300,000
#   - **Number of Outliers:** 13,070
#   - **Insights:** Somalia has extremely high maximum values compared to other countries. The significant number of outliers indicates a substantial amount of extreme values beyond the typical range.
#
# - **Congo, The Democratic Republic of the**
#   - **Maximum Value:** 5,920,000
#   - **Number of Outliers:** 9,615
#   - **Insights:** Congo has a high maximum value and a large number of outliers, suggesting that there are many extreme values relative to its distribution.
#
# - **South Sudan**
#   - **Maximum Value:** 1,120,000
#   - **Number of Outliers:** 2,879
#   - **Insights:** South Sudan shows a very high maximum value with a moderate number of outliers, indicating considerable variability in extreme values.
#
# - **Nigeria**
#   - **Maximum Value:** 799,000
#   - **Number of Outliers:** 18,464
#   - **Insights:** Nigeria's maximum value is high, and it has the highest number of outliers among the countries analyzed, pointing to extensive variability and extreme values in its data.
#
# - **Chad**
#   - **Maximum Value:** 355,530
#   - **Number of Outliers:** 11,874
#   - **Insights:** Chad has a high maximum value and a substantial number of outliers, reflecting considerable extremes in its dataset.
#
# - **Ethiopia**
#   - **Maximum Value:** 324,202.80
#   - **Number of Outliers:** 14,265
#   - **Insights:** Ethiopia has a high maximum value and a significant number of outliers, indicating a broad range of extreme values.
#
# - **Mauritania**
#   - **Maximum Value:** 75,000
#   - **Number of Outliers:** 8,529
#   - **Insights:** Mauritania has a relatively high maximum value and a moderate number of outliers, suggesting considerable variability.
#
# - **Haiti**
#   - **Maximum Value:** 3,500
#   - **Number of Outliers:** 16,910
#   - **Insights:** Haiti has a lower maximum value compared to the top countries but a high number of outliers, indicating significant extreme values within its data.
#
# - **Zimbabwe**
#   - **Maximum Value:** 1,849
#   - **Number of Outliers:** 1,005
#   - **Insights:** Zimbabwe's maximum value is the lowest among the countries analyzed, with a comparatively low number of outliers, indicating fewer extreme values.
#
# - **Malawi**
#   - **Maximum Value:** 1,500
#   - **Number of Outliers:** 35
#   - **Insights:** Malawi has a lower maximum value and few outliers, suggesting that its data is less prone to extreme values.
#
# - **Kenya**
#   - **Maximum Value:** 622
#   - **Number of Outliers:** 133
#   - **Insights:** Kenya has a low maximum value and a small number of outliers, indicating a relatively stable dataset with fewer extremes.
#
# - **Djibouti**
#   - **Maximum Value:** 405
#   - **Number of Outliers:** 3
#   - **Insights:** Djibouti has the lowest maximum value and the fewest outliers, indicating a tightly clustered data distribution with minimal extreme values.
#
# - **Angola**
#   - **Maximum Value:** 249.94
#   - **Number of Outliers:** 0
#   - **Insights:** Angola has the lowest maximum value and no outliers, suggesting a consistent dataset with no extreme values. -->

# %% [markdown]
# From the analysis of outliers, we have identified various variations in the staple foods and fuel prices:
# - **i. Country-Level Variations**
#
# Commodity prices can vary significantly from one country to another due to different economic conditions, currency values, inflation rates, and market dynamics.
#
# - **ii. Administrative Regions and Markets**
#
# Commodity prices within countries can vary widely across different regions and markets due to local supply and demand, cost of living, and other regional factors.
#
# - **iii. Time Period (Date)**
#
# Commodity prices can fluctuate over time due to seasonal effects, inflation, or other economic changes.
#
# ---
# **Suitable Imputation Approach and Method Selection**
#
# ---
# **a. Why Median Imputation Is Cumbersome**
#
# Median imputation involves filling missing values with the median of observed values within a specified group. While this method is straightforward and computationally inexpensive, it presents several limitations in this project:
#
# - **i. Granularity of Data**: Given the complexity of the pricing data, which varies by country, administrative region, market, and time period, using a single median value might not capture the variability within these dimensions. For instance, the median price for a commodity in one country may not be representative of its price in another country with different economic conditions.
#
# - **ii. Time Sensitivity**: Prices change over time due to inflation, seasonal effects, and market fluctuations. Median imputation does not account for temporal variations, potentially leading to misleading estimates if historical data differs significantly from current trends.
#
# - **iii. Regional Variations**: Prices can vary significantly between regions and markets within a country. Median imputation might oversimplify these variations, leading to inaccurate imputations for specific regions or markets.
#
# **b. Why K-Nearest Neighbors (KNN) Is Not Ideal for Initial Exploration**
#
# KNN imputation is a more sophisticated method that leverages the similarity between records to predict missing values. However, it requires several preprocessing steps that may hinder initial exploratory data analysissis (EDA):
#
# - **i. Preprocessing Complexity**: KNN requires encoding categorical variables and scaling numerical features. These preprocessing steps are crucial for ensuring the KNN algorithm performs effectively but can obscure initial insights during EDA, which should focus on understanding the raw data.
#
# - **ii. Data Splitting**: KNN involves splitting the data into features (X) and target values (y). This process, along with cross-validation for parameter tuning, adds complexity and may delay the exploratory phase, which is crucial for identifying patterns and outliers in the complete dataset.
#
# - **iii. Computational Overhead**: KNN is computationally intensive, especially with large datasets. Performing detailed EDA while managing the computational load of KNN can be challenging.
#
# ---
#
# **c. Suitable Imputation Approach**
#
# Given the dataset's complexity and the need for detailed initial exploration:
# I will start with **Linear Interpolation** to handle missing values. This method will allow me to maintain temporal trends and is less complex compared to KNN.I will then analyze the complete dataset to understand patterns, outliers, and variations across different dimensions (country, region, market, time). This exploration will provide insights into how prices vary and inform subsequent imputation strategies. Once I have a thorough understanding of the data, I will consider KNN for imputation if needed. This approach will be more effective after detailed EDA and when you are prepared for the additional preprocessing and computational requirements.

# %%
# Create a copy of the original DataFrame
df_clean = df_missing_value.copy()

# %%
# Filtered DataFrame with missing values
df_missing = df_clean[df_clean['value'].isna()]
df_missing.head(10)
# Out:
#     country                    market administrative_region  longitude  \
# 175  Angola  Lubango, Joao de Almeida                   NaN    13.5132
# 183  Angola  Lubango, Joao de Almeida                   NaN    13.5132
# 191  Angola  Lubango, Joao de Almeida                   NaN    13.5132
# 199  Angola  Lubango, Joao de Almeida                   NaN    13.5132
# 207  Angola  Lubango, Joao de Almeida                   NaN    13.5132
# 509    Chad                    Abeche               Ouaddai    20.8438
# 513    Chad                    Abeche               Ouaddai    20.8438
# 514    Chad                    Abeche               Ouaddai    20.8438
# 523    Chad                    Abeche               Ouaddai    20.8438
# 870    Chad                    Abeche               Ouaddai    20.8438
#
#      latitude product_code                                      product  \
# 175  -14.9050     R01701AA                                Beans (mixed)
# 183  -14.9050     R01592AA                                      Cassava
# 191  -14.9050     R01122AC                          Maize Grain (White)
# 199  -14.9050     P23130AA                                   Maize Meal
# 207  -14.9050     R01591AA                               Sweet Potatoes
# 509   13.8354     L02111AB  Cattle (Male, 2-3 years old, Local Quality)
# 513   13.8354     L02111AB  Cattle (Male, 2-3 years old, Local Quality)
# 514   13.8354     L02111AB  Cattle (Male, 2-3 years old, Local Quality)
# 523   13.8354     L02111AB  Cattle (Male, 2-3 years old, Local Quality)
# 870   13.8354     L02151AB                                     Chickens
#
#     period_date price_category product_source measurement_unit currency  value
# 175  2014-01-31         Retail          Local               kg      AOA    NaN
# 183  2014-01-31         Retail          Local               kg      AOA    NaN
# 191  2014-01-31         Retail          Local               kg      AOA    NaN
# 199  2014-01-31         Retail          Local               kg      AOA    NaN
# 207  2014-01-31         Retail          Local               kg      AOA    NaN
# 509  2022-05-25         Retail          Local               ea      XAF    NaN
# 513  2022-06-22         Retail          Local               ea      XAF    NaN
# 514  2022-06-29         Retail          Local               ea      XAF    NaN
# 523  2022-08-31         Retail          Local               ea      XAF    NaN
# 870  2022-05-25         Retail          Local               ea      XAF    NaN

# %%
# Set 'period_date' as index for time-series operations
df_clean.set_index('period_date', inplace=True)

# Interpolation
df_interpolation = df_clean.copy()
df_interpolation['value'] = df_interpolation['value'].interpolate(method='linear')

# Reset index to display
df_interpolation.reset_index(inplace=True)

# Filter the original missing value indices in the filled DataFrame
df_interpolation_filtered = df_interpolation[df_interpolation.index.isin(df_missing.index)]
df_interpolation_filtered. head(10)
# Out:
#     period_date country                    market administrative_region  \
# 175  2014-01-31  Angola  Lubango, Joao de Almeida                   NaN
# 183  2014-01-31  Angola  Lubango, Joao de Almeida                   NaN
# 191  2014-01-31  Angola  Lubango, Joao de Almeida                   NaN
# 199  2014-01-31  Angola  Lubango, Joao de Almeida                   NaN
# 207  2014-01-31  Angola  Lubango, Joao de Almeida                   NaN
# 509  2022-05-25    Chad                    Abeche               Ouaddai
# 513  2022-06-22    Chad                    Abeche               Ouaddai
# 514  2022-06-29    Chad                    Abeche               Ouaddai
# 523  2022-08-31    Chad                    Abeche               Ouaddai
# 870  2022-05-25    Chad                    Abeche               Ouaddai
#
#      longitude  latitude product_code  \
# 175    13.5132  -14.9050     R01701AA
# 183    13.5132  -14.9050     R01592AA
# 191    13.5132  -14.9050     R01122AC
# 199    13.5132  -14.9050     P23130AA
# 207    13.5132  -14.9050     R01591AA
# 509    20.8438   13.8354     L02111AB
# 513    20.8438   13.8354     L02111AB
# 514    20.8438   13.8354     L02111AB
# 523    20.8438   13.8354     L02111AB
# 870    20.8438   13.8354     L02151AB
#
#                                          product price_category  \
# 175                                Beans (mixed)         Retail
# 183                                      Cassava         Retail
# 191                          Maize Grain (White)         Retail
# 199                                   Maize Meal         Retail
# 207                               Sweet Potatoes         Retail
# 509  Cattle (Male, 2-3 years old, Local Quality)         Retail
# 513  Cattle (Male, 2-3 years old, Local Quality)         Retail
# 514  Cattle (Male, 2-3 years old, Local Quality)         Retail
# 523  Cattle (Male, 2-3 years old, Local Quality)         Retail
# 870                                     Chickens         Retail
#
#     product_source measurement_unit currency          value
# 175          Local               kg      AOA     122.005000
# 183          Local               kg      AOA     183.402500
# 191          Local               kg      AOA      91.360000
# 199          Local               kg      AOA      71.095000
# 207          Local               kg      AOA      89.265000
# 509          Local               ea      XAF  106250.000000
# 513          Local               ea      XAF  115833.333333
# 514          Local               ea      XAF  121666.666667
# 523          Local               ea      XAF   95500.000000
# 870          Local               ea      XAF    3325.000000

# %%
# Check for missing values in the DataFrame after linear interpolation
missing_after_interpolation = df_interpolation.isnull().sum()
print("Missing values after Linear Interpolation:")
missing_after_interpolation
# Out:
# Missing values after Linear Interpolation:
# period_date                 0
# country                     0
# market                      0
# administrative_region    1280
# longitude                   0
# latitude                    0
# product_code                0
# product                     0
# price_category              0
# product_source              0
# measurement_unit            0
# currency                    0
# value                       0
# dtype: int64

# %% [markdown]
# All the missing values in the value column have been handled.
#
# ---

# %%
# Create A Copy of The Merged Dataset
eda_df = df_interpolation.copy()
eda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011744 entries, 0 to 1011743
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   period_date            1011744 non-null  datetime64[ns]
#  1   country                1011744 non-null  object
#  2   market                 1011744 non-null  object
#  3   administrative_region  1010464 non-null  object
#  4   longitude              1011744 non-null  float64
#  5   latitude               1011744 non-null  float64
#  6   product_code           1011744 non-null  object
#  7   product                1011744 non-null  object
#  8   price_category         1011744 non-null  object
#  9   product_source         1011744 non-null  object
#  10  measurement_unit       1011744 non-null  object
#  11  currency               1011744 non-null  object
#  12  value                  1011744 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(9)
# memory usage: 100.3+ MB

# %% [markdown]
# ## 2.3.2. Univariate, Multivariate and Bivariate Analysis

# %% [markdown]
# ### i. Univariate Analysis

# %% [markdown]
# #### a. Distribution of the 'Period_Date' variable:

# %%
# Extract year and month for aggregation
eda_df['year'] = eda_df['period_date'].dt.year
eda_df['month'] = eda_df['period_date'].dt.to_period('M')

# Set the viridis palette
sns.set_palette('viridis')

# Plotting the distribution of records by year
plt.figure(figsize=(12, 6))
sns.histplot(eda_df['year'], bins=range(eda_df['year'].min(), eda_df['year'].max() + 1), discrete=True)
plt.title('Distribution of Records by Year')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# Most of the data has been collected in recent years, specifically between 2010 and 2024.
#
#
# ---

# %% [markdown]
# #### b. Distribution of the 'Country' variable:

# %%
# Create the count plot
plt.figure(figsize=(10, 6))
sns.countplot(y=eda_df['country'], order=eda_df['country'].value_counts().index, palette='viridis')
plt.title('Count of Records by Country')
plt.xlabel('Frequency')
plt.ylabel('Country')
plt.show()

# Frequency distribution for 'country'
print("\nFrequency Distribution for 'country':")
print('='*37)
print(eda_df['country'].value_counts())
# Out:
# Frequency Distribution for 'country':
# =====================================
# country
# Nigeria        305288
# Haiti          260705
# Ethiopia        96684
# Somalia         84339
# Congo (DRC)     83245
# Chad            62973
# Mauritania      61061
# South Sudan     44971
# Malawi           4958
# Zimbabwe         4878
# Kenya            1362
# Djibouti         1065
# Angola            215
# Name: count, dtype: int64

# %% [markdown]
# ---
#
#
# - **High Frequency**: Nigeria and Haiti have the highest number of records, suggesting extensive data collection or reporting.
# - **Moderate Frequency**: Ethiopia, Somalia, Congo (DRC), Chad, and Mauritania have substantial data volumes, indicating significant activity or data coverage.
# - **Low Frequency**: South Sudan, Malawi, Zimbabwe, Kenya, Djibouti, and Angola have fewer records, reflecting less data collection or reporting in these regions.
# - **Concentration**: The dataset is heavily concentrated in a few countries, which may offer more robust insights for these regions but could limit the analysis for countries with sparse data.
#
# ---

# %% [markdown]
# #### c. Distribution of the 'Market' variable:

# %%
# Count the number of records for each market
market_counts = eda_df['market'].value_counts()

# Top 20 markets
top_20_markets = market_counts.head(20)

# Bottom 20 markets
bottom_20_markets = market_counts.tail(20)

# Identify the countries and administrative areas for top 20 markets
top_20_info = eda_df[eda_df['market'].isin(top_20_markets.index)].groupby(['market', 'country', 'administrative_region']).size().reset_index(name='count')

# Identify the countries and administrative areas for bottom 10 markets
bottom_20_info = eda_df[eda_df['market'].isin(bottom_20_markets.index)].groupby(['market', 'country', 'administrative_region']).size().reset_index(name='count')

# Plotting the Top 20 Markets
plt.figure(figsize=(12, 6))
sns.countplot(y=eda_df[eda_df['market'].isin(top_20_markets.index)]['market'],
              order=top_20_markets.index,
              palette='viridis')
plt.title('Top 20 Markets by Record Count')
plt.xlabel('Frequency')
plt.ylabel('Market')
plt.show()

# Print the country and administrative area details for the Top 20 Markets
print("Top 20 Markets and Their Associated Countries and Administrative Areas:")
top_20_info.sort_values(by='count', ascending=False)
# Out:
# Top 20 Markets and Their Associated Countries and Administrative Areas:
#                                market  country administrative_region  count
# 9                              Hinche    Haiti                Centre  26736
# 12                            Jeremie    Haiti            Grand'Anse  26735
# 0                         Cap Haitien    Haiti                  Nord  26734
# 11                             Jacmel    Haiti               Sud-Est  26734
# 17  Port-au-Prince, Croix-de-Bossales    Haiti                 Ouest  26704
# 18                       Port-de-Paix    Haiti            Nord-Ouest  26219
# 16                        Ouanaminthe    Haiti              Nord-Est  26217
# 3                     Fond-des-Negres    Haiti                Nippes  26216
# 6                            Gonaives    Haiti            Artibonite  26216
# 1                               Cayes    Haiti                   Sud  22194
# 2                             Dandume  Nigeria               Katsina  21305
# 10                     Ibadan, Bodija  Nigeria                   Oyo  21204
# 5                               Gombe  Nigeria                 Gombe  21176
# 14                     Lagos, Mile 12  Nigeria                 Lagos  20776
# 19                           Saminaka  Nigeria                Kaduna  20725
# 4                                Giwa  Nigeria                Kaduna  20550
# 15                          Maiduguri  Nigeria                 Borno  20545
# 13                      Kano, Dawanau  Nigeria                  Kano  20383
# 8                      Gwandu, Dodoru  Nigeria                 Kebbi  19745
# 7                             Gujungu  Nigeria                Jigawa  19582

# %% [markdown]
# The analysis of the top 20 markets reveals the prominence of Haiti and Nigeria in market activities, highlighting key regions where economic activities are concentrated.
#
# ---

# %%
# Plotting the Bottom 20 Markets
plt.figure(figsize=(12, 6))
sns.countplot(y=eda_df[eda_df['market'].isin(bottom_20_markets.index)]['market'],
              order=bottom_20_markets.index,
              palette='viridis')
plt.title('Bottom 20 Markets by Record Count')
plt.xlabel('Frequency')
plt.ylabel('Market')
plt.show()

# Print the country and administrative area details for the Bottom 20 Markets
print("Bottom 20 Markets and Their Associated Countries and Administrative Areas:")
bottom_20_info.sort_values(by='count', ascending=False)
# Out:
# Bottom 20 Markets and Their Associated Countries and Administrative Areas:
#                                market      country administrative_region  \
# 10                           Mangochi       Malawi              Southern
# 13                             Ntcheu       Malawi               Central
# 16                             Salima       Malawi               Central
# 14                           Phalombe       Malawi              Southern
# 2                              Balaka       Malawi              Southern
# 12                              Mzuzu       Malawi              Northern
# 11                            Mitundu       Malawi               Central
# 0                         Aba, Akwete      Nigeria                  Abia
# 9             Lusambo, Marché Central  Congo (DRC)               Sankuru
# 7    Kinshasa, Marché de Somba Zigida  Congo (DRC)              Kinshasa
# 6   Kinshasa, Marché de Matadi Kibala  Congo (DRC)              Kinshasa
# 4              Inongo, Marché Central  Congo (DRC)            Mai-Ndombe
# 3           Gbadolite, Marché Central  Congo (DRC)          North Ubangi
# 8    Kisangani, Marché du 24 Novembre  Congo (DRC)                Tshopo
# 1                          Aba, Udele      Nigeria                  Abia
# 5                          Iskushuban      Somalia                  Bari
# 15                             Saakow      Somalia           Middle Juba
#
#     count
# 10    432
# 13    432
# 16    431
# 14    423
# 2     360
# 12    360
# 11    360
# 0     355
# 9     225
# 7     225
# 6     225
# 4     225
# 3     225
# 8     225
# 1     161
# 5     146
# 15    141

# %% [markdown]
# The analysis of the bottom 20 markets reveals the prominence of Malawi, Congo (DRC) and Angola in market activities, highlighting regions where economic activities are least concentrated.
#
# ---

# %% [markdown]
# #### d. Distribution of the 'Country' variable:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure
plt.figure(figsize=(12, 8))

# Get value counts for each country
country_counts = eda_df['country'].value_counts()

# Define a color map using seaborn's viridis palette
colors = sns.color_palette('viridis', len(country_counts))

# Plot the bar chart with viridis colors
bars = plt.bar(country_counts.index, country_counts.values, color=colors)

plt.title('Number of Entries per Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Create a figure
plt.figure(figsize=(12, 8))

# Get value counts for each country
country_counts = eda_df['country'].value_counts()

# Plot the bar chart with viridis colors
bars = plt.bar(country_counts.index, country_counts.values, color=colors)

plt.title('Number of Entries per Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Most of the data collected is from Nigeria, Haiti and Ethiopia. Kenya, Djibouti and Angola are underrepresented in the dataset.
#
# ---

# %% [markdown]
# #### e. Distribution of the 'Longitude and Latitude' variables:

# %%
# Plotting the geographic distribution of data points with the Viridis palette
plt.figure(figsize=(10, 6))
plt.scatter(eda_df['longitude'], eda_df['latitude'], c=eda_df['latitude'], cmap='viridis')
plt.title('Geographic Distribution of Data Points')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Latitude')
plt.show()

# %% [markdown]
# The scatter plot shows data points distributed across various longitudes and latitudes, representing different countries and regions within those countries.
# - The clustering of points indicates areas with higher data collection density, possibly reflecting regions with more significant market activities or more detailed data collection efforts.
#
# **Country Clusters:**
# - Based on the provided countries, the main clusters likely correspond to regions in Africa and one cluster in Haiti.
# - The dense cluster of points between longitudes 20 to 40 and latitudes 0 to 20 likely represents East African countries such as Kenya, Ethiopia, and South Sudan.
# - The isolated cluster around longitude -80 and latitude 20 corresponds to Haiti.
#
# **Data Collection Focus:**
# - The concentration of data points in specific regions suggests that these areas might have more detailed price monitoring, possibly due to their importance in terms of food security, market activity, or regional policies.
# - Regions with fewer data points might need more attention or indicate areas with less market activity or lower population density.
#
# ---

# %% [markdown]
# #### f. Distribution of the 'price_category' variable:

# %%
# Extract the value counts for the 'price_category' column
price_category_counts = eda_df['price_category'].value_counts()

# Get the Viridis color palette from Seaborn
viridis_palette = sns.color_palette("viridis", n_colors=len(price_category_counts))

# Plot the bar chart with Viridis colors
plt.figure(figsize=(10, 6))
bars = plt.bar(price_category_counts.index, price_category_counts.values, color=viridis_palette)

# Add titles and labels
plt.title('Number of Entries per Price Category')
plt.xlabel('Price Category')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# Most staple foods and fuels are from the retail category.
#
# ---

# %% [markdown]
# #### g. Distribution of the 'product_source' variable:

# %%
# Extract the value counts for the 'product_source' column
product_source_counts = eda_df['product_source'].value_counts()

# Get the Viridis color palette from Seaborn
viridis_palette = sns.color_palette("viridis", n_colors=len(product_source_counts))

# Plot the bar chart with Viridis colors
plt.figure(figsize=(10, 6))
bars = plt.bar(product_source_counts.index, product_source_counts.values, color=viridis_palette)

# Add titles and labels
plt.title('Number of Entries per Product Source')
plt.xlabel('Product Source')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# Most products in the dataset are locally sourced
#
# ---

# %% [markdown]
# #### h. Distribution of the 'measurement_unit' variable:

# %%
import pandas as pd

# Extract the value counts for the 'measurement_unit' column
measurement_unit_counts = eda_df['measurement_unit'].value_counts()

# Convert to DataFrame
measurement_unit_df = pd.DataFrame({
    'Measurement Unit': measurement_unit_counts.index,
    'Count': measurement_unit_counts.values
})

# Display the DataFrame
measurement_unit_df.T
# Out:
#                       0       1      2       3      4      5      6      7   \
# Measurement Unit      kg    6_lb     ea  100_kg      L    gal  50_kg  350_g
# Count             397435  153973  98542   91135  84446  49120  30113  29099
#
#                        8      9   ...     16     17    18         19     20  \
# Measurement Unit  226.8_g    day  ...  90_kg  500_g  30_L  60_tubers  700_g
# Count               14256  14189  ...   3102   1438   638        512    396
#
#                      21      22    23     24     25
# Measurement Unit  12_kg  500_ml  2_kg  125_g  400_g
# Count               302     229   217     64     39
#
# [2 rows x 26 columns]

# %% [markdown]
# Since there are large differences between values to be visualised, a logarithmic scale will help make the data more comprehensible. It is a powerful tool for revealing patterns and insights that might be obscured by a linear scale.

# %%
# Plot the bar chart with log scale
plt.figure(figsize=(12, 8))
plt.bar(measurement_unit_df['Measurement Unit'], measurement_unit_df['Count'], color=colors)
plt.yscale('log')
plt.title('Number of Entries per Measurement Unit (Log Scale)')
plt.xlabel('Measurement Unit')
plt.ylabel('Count (log scale)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Dominant Measurement Units (e.g., kg, 6_lb, ea):**
#
# - The most common measurement units are `kg` and `6_lb`, suggesting that these units are frequently used in the dataset for pricing food items.
# - Units with low counts might be rare or specific to certain products or markets.
# - There is a wide range of measurement units, indicating diverse types of products and pricing practices.
#
# Units like `day` and `pile` might not be standard measurement units for food prices and could represent data for unnecessary products or services not necessary for predicting staple food and fuel prices. Thus, I will analyse these units to identify if they are relevant to this project; if not, I will remove them or treat them differently in your analysis.
#
# ---

# %% [markdown]
# #### i. Distribution of the 'Currency' variable:

# %%
# currency
# Extract the value counts for the 'currency' column
currency_counts = eda_df['currency'].value_counts()

# Plot the bar chart with viridis colors
plt.figure(figsize=(10, 6))
currency_counts.plot(kind='bar', color=colors)
plt.title('Number of Entries per Currency')
plt.xlabel('Currency')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The Nigerian and Haiti currencies are the most prevalent in the dataset indicating that most of the data in the dataset was collected from the two countries.
#
# ---

# %% [markdown]
# ### ii. Bivariate Analysis

# %% [markdown]
# #### a. Value over Time

# %%
# Value over Time
plt.figure(figsize=(10, 6))
sns.lineplot(x='period_date', y='value', data=eda_df)
plt.title('Value Over Time')
plt.xlabel('Period Date')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# From the graph, we can observe that the values of staple foods and fuel exhibit some variations and fluctuations over time. There are periods of both highs and lows, indicating potential seasonality or other factors affecting the product price patterns.
#
# ---

# %%
# Group the data by date and calculate the total sales
daily_sales = daily_sales.groupby('date')['total_sales'].sum().reset_index()

# Create a time series plot with slider
fig = px.line(daily_sales, x='date', y='total_sales')
fig.update_xaxes(rangeslider_visible=True)
fig.update_layout(title='Trend of Sales Over Time', title_x=0.5)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[143], line 2
#       1 # Group the data by date and calculate the total sales
# ----> 2 daily_sales = daily_sales.groupby('date')['total_sales'].sum().reset_index()
#       4 # Create a time series plot with slider
#       5 fig = px.line(daily_sales, x='date', y='total_sales')
#
# NameError: name 'daily_sales' is not defined

# %%
import plotly.express as px
import pandas as pd

# Convert period_date to datetime format
eda_df['period_date'] = pd.to_datetime(eda_df['period_date'])

# Filter data for Kenya and the products of interest
kenya_df = eda_df[(eda_df['country'] == 'Kenya') & (eda_df['product'].isin(['Gasoline', 'Diesel']))]

# Group by period_date and product, and calculate average price
kenya_time_series_df = kenya_df.groupby(['period_date', 'product']).agg({'value': 'mean'}).reset_index()

# Create the time series plot with Plotly Express
fig = px.line(
    kenya_time_series_df, 
    x='period_date', 
    y='value', 
    color='product',
    title='Average Price of Gasoline and Diesel in Kenya Over Time',
    labels={'period_date': 'Date', 'value': 'Average Price'},
    line_shape='linear'
)

# Update layout for better appearance
fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Average Price',
    xaxis_rangeslider_visible=True  # Add the range slider to the x-axis
)

fig.show()

# %% [markdown]
# #### b. Value by Country

# %%
# Value by Country
plt.figure(figsize=(12, 8))
sns.boxplot(x='country', y='value', data=eda_df)
plt.title('Value by Country')
plt.xlabel('Country')
plt.ylabel('Value')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Somalia exhibits the highest variations in pricing/value as it has very many outliers in the higher price range followed by Congo (DRC). Countries like Kenya, Malawi, Angola and Djibouti display few outliers.
#
# ---

# %% [markdown]
# #### c. Value by Price Category

# %%
# Value by Price Category
plt.figure(figsize=(10, 6))
sns.boxplot(x='price_category', y='value', data=eda_df)
plt.title('Value by Price Category')
plt.xlabel('Price Category')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# Most of the retail products experience a wide range of pricing with very many having prices in the higher range as compared to their Wholesale and Wage counterparts.
#
# ---

# %% [markdown]
# #### d. Value by Product Source

# %%
# Value by Product Source
plt.figure(figsize=(10, 6))
sns.boxplot(x='product_source', y='value', data=eda_df)
plt.title('Value by Product Source')
plt.xlabel('Product Source')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# Most of the locally sourced products experience a wide range of pricing with very many having prices in the higher range as compared to their imported counterparts.
#
# ---

# %% [markdown]
# #### e. Value by Currency

# %%
# Value by Currency
plt.figure(figsize=(10, 6))
sns.boxplot(x='currency', y='value', data=eda_df)
plt.title('Value by Currency')
plt.xlabel('Currency')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# As earlier mentioned, Somalia exhibits the highest variations in pricing/value as it has very many outliers in the higher price range followed by Congo (DRC). Countries like Kenya, Malawi, Angola and Djibouti display few outliers.
#
# ---

# %% [markdown]
# ### iii. Multivariate Analysis

# %% [markdown]
# #### a. Correlation matrix of numerical variables

# %%
# Correlation Matrix
# Calculate the correlation matrix
correlation_matrix = eda_df.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ## 2.3.3.Hypothesis Testing and Answering Key Analytical Questions

# %% [markdown]
# ### a. Hypothesis Testing

# %% [markdown]
# **Hypothesis:** Influence of Region on Price
#    - **Null Hypothesis (H₀):** There is no significant difference in prices based on the administrative regions or countries.
#
#    - **Alternative Hypothesis (H₁):** There is a significant difference in prices based on the administrative regions or countries.

# %% [markdown]
# ---
#
# **Objective:** To determine if there are significant differences in prices based on the administrative regions or countries.
#
# The **ANOVA (Analysis of Variance) Test** is best-suited for this hypothesis test for various reasons:
#
# **i. Comparing Multiple Groups:**
#    - **Country:** There are multiple countries in the dataset.
#    - **Administrative Region:** There are multiple administrative regions in the dataset.
#    - ANOVA is suitable for comparing the means of more than two groups, helping us understand if at least one group mean is significantly different from others.
#
# **ii. Quantitative Dependent Variable:**
#    - The dependent variable, `value` (price), is quantitative.
#    - ANOVA is designed to compare the means of a quantitative dependent variable across different groups (categorical independent variables).
#
# **iii. Categorical Independent Variables:**
#    - **Country** and **Administrative Region** are categorical variables.
#    - ANOVA tests how these categorical variables influence the mean of the quantitative variable.
#
# **iv. Testing Overall Differences:**
#    - ANOVA provides a method to test for overall differences among group means rather than just comparing pairs of groups.
#    - This helps in identifying whether the observed differences in means are statistically significant when considering all groups simultaneously.
#
# ANOVA is the appropriate test for determining if there are significant differences in prices based on the administrative regions or countries in the dataset.
#
# ---

# %%
# Extract relevant columns
data = eda_df[['country', 'administrative_region', 'value']].dropna()

# Display the first few rows of the data
data.head()

# %%
# One-way ANOVA for countries
anova_country = ols('value ~ C(country)', data=data).fit()
anova_table_country = sm.stats.anova_lm(anova_country, typ=2)

# One-way ANOVA for administrative regions
anova_region = ols('value ~ C(administrative_region)', data=data).fit()
anova_table_region = sm.stats.anova_lm(anova_region, typ=2)

# Print the ANOVA tables
print("ANOVA Table for Country:")
print('='*25)
anova_table_country

# %%
print("\nANOVA Table for Administrative Region:")
print('='*38)
anova_table_region

# %% [markdown]
# ---
#
# **For this test:**
# - **Significance Level (α):** 0.05
#
# Decision Criteria:
# - **If p-value ≤ α:** Reject the null hypothesis (H₀).
# - **If p-value > α:** Fail to reject the null hypothesis (H₀).
#
# ---
#
# Applying the Decision Rule to Our Results:
#
# ---
#
# **i. For Country:**
# - **P-value:** 0.0
# - **Significance Level (α):** 0.05
#
# **Decision:** Since the p-value (0.0) is less than the significance level (0.05), we reject the null hypothesis.
#
# There is a significant difference in prices between different countries.
#
# ---
#
# **ii. For Administrative Region:**
# - **P-value:** 0.0
# - **Significance Level (α):** 0.05
#
# **Decision:** Since the p-value (0.0) is less than the significance level (0.05), we reject the null hypothesis.
#
# There is a significant difference in prices between different administrative regions.
#
# ---
#
# These results suggest that both the `country` and `administrative region` significantly influence the `value` or prices of commodities in the dataset.
#
# ---

# %% [markdown]
# # 2.3. Data Preparation

# %% [markdown]
# Since I already prepared all the data previously by handling missing values, I will now proceed to encode the categorical columns to prepare the dataset for modeling.

# %% [markdown]
# ## 2.3.1. Extracting Date Components (Year, Month and Day of Week).

# %%
# Extract date features
eda_df['year'] = eda_df['period_date'].dt.year
eda_df['month'] = eda_df['period_date'].dt.month
eda_df['day_of_week'] = eda_df['period_date'].dt.dayofweek


# Drop the original period_date column
eda_df = eda_df.drop(columns=['period_date'])

# Show an overview of the dataframe
eda_df.head()

# %% [markdown]
# ## 2.3.2. Product Categorization Based on Families

# %%
# Check the unique values of the product column
eda_df['product'].unique()

# %% [markdown]
# The product column contains very many unique values. Product categories need to be created to group similar items to make trends and patterns easier to identify, make data easier to understand and also make it easy for users to navigate on the depoloyed solution after modeling.

# %%
# Define product categories
categories = {
    'Grains and Cereals': [
        'Maize Grain (White)', 'Maize Grain (Yellow)', 'Rice (5% Broken)', 'Rice (Milled)', 'Rice (10/10)', 'Rice (4% Broken)', 
        'Rice (Bongu)', 'Rice (Mega)', 'Rice (Tchako)', 'Rice (TCS)', 'Rice (100% Broken)', 'Rice (Parboiled)', 
        'Wheat Grain', 'Wheat Bran', 'Millet (Pearl)', 'Millet', 'Sorghum', 'Sorghum (Berbere)', 'Sorghum (Red)', 'Sorghum (White)', 
        'Sorghum (Yellow)', 'Sorghum (Feterita)', 'Sorghum (Bichna, Mixed)', 'Sorghum (Bichna, Mixed))', 'Sorghum (Brown)',
         'Sorghum (R\'haya, Brown)', 'Sorghum (Taghalit, Mixed)', 'Beans (mixed)', 'Beans (White)', 'Beans (Haricot)', 
         'Beans (Black)', 'Beans (Lima)', 'Beans (Pinto)', 'Beans (Red)', 'Beans (Brown)', 'Beans (Yellow)', 'Cowpeas (Mixed)', 
        'Cowpeas (Brown)', 'Cowpeas (White)', 'Cowpeas (Red)', 'Groundnuts (Shelled)', 'Groundnut (without shell)',
        'Groundnuts (In Shell)', 'Dry Lentils', 'Gari (Yellow)', 'Gari (White)', 'Wild Straw', 'Rice Straw', 
        'Wheat bran', 'Sesame (White)', 'Pigeon Peas', 'Horse beans', 'Mixed Teff'
    ],

    'Processed Foods': [
        'Macaroni', 'Pasta (Mixed)', 'Spaghetti', 'Spaghetti (Bongu)', 'Spaghetti (Gourmet)', 'Spaghetti (Itala)', 'Spaghetti (Lavagi)',
       'Spaghetti (Vita)', 'Cassava Chips'

    ],

    'Flour': [
        'Cassava Flour', 'Maize Meal', 'Maize Meal (White)', 'Maize Meal (Yellow)', 'Maize Meal (Alberto)', 'Maize Meal (Gradoro)', 
        'Roller Maize Meal', 'Maize Flour', 'Wheat Flour', 'Sorghum Flour'
    ],
    
    'Vegetables and Fruits': [
        'Cassava', 'Yams', 'Sweet Potatoes', 'Onions', 'Tomato Paste (Famoza)', 'Tomato Paste (Laperla)',
        'Tomato Paste (Rika)'
    ],
    
    'Meat and Fish': [
        'Beef (Fresh bovine meat)', 'Camel Meat', 'Mutton (Sheep)', 'Fish (Dried, Yay Boy)'
    ],

    'Bread, Dairy, Salt and Sugar': [
        'Bread', 'Salt', 'Sugar (Cream)', 'Refined sugar',
        'Cow\'s Milk (Fresh, Pasteurized)', 'Camel\'s Milk (Raw)', 'Milk (Bongu)', 'Milk (Vita)', 'Whole milk powder'
    ],

    'Livestock and Poultry': [
        'Camels (Male, Average)', 'Camels (Local Quality)', 'Camels (Female, Average)', 'Cattle (Male, 1-2 years old, Uncastrated)', 
        'Cattle (Male, 2-3 years old, Local Quality)', 'Cattle (Medium-sized bull)', 'Cattle (Medium-sized cow)', 'Cattle (Male)', 
        'Goats (Male, Medium-sized, Castrated)', 'Goats (Adult, Male, Medium-sized)', 'Goats (Local Quality)', 'Goats (Male)', 
        'Sheep (Male, Medium-sized, Castrated)', 'Sheep (Local Quality)', 'Sheep (1 year old, Female)', 'Sheep (2-3 years, Average Quality)', 
        'Sheep (Male)', 'Oxen (Local Quality)', 'Chickens', 'Chickens (Live)', 'Goats (Female, Medium-sized)', 'Goats (Export Quality)', 
        'Pig (Adult, Male, Medium-sized)'
    ],
    
    'Oil and Fats': [
        'Refined Vegetable Oil', 'Refined Vegetable Oil (Alberto)', 'Refined Vegetable Oil (Bongu)',
        'Refined Vegetable Oil (Gourmet)', 'Refined Vegetable Oil (Rika)', 'Refined Vegetable Oil (Sinistre)',
        'Refined Vegetable Oil (Ti malice)', 'Palm oil, crude', 'Palm Oil (Refined)'
    ],
    
    'Fuel and Energy': [
        'Diesel', 'Petrol', 'Kerosene', 'Propane and butanes, liquefied', 'Charcoal', 'Firewood'
    ],
    
    'Water and Beverages': [
        'Cocoa', 'Parchment Coffee', 'Tea leaves (Mixed)', 'Water (potable, drinking)'
    ],
    
    'Laundry Supplies': [
        'Soap'
    ],
    
    'Tobacco Products': [
        'Tobacco (unspecified)'
    ],
    
    'Services': [
        'Grain milling services', 'Casual Labor (unskilled, daily, without food)'
    ],
    
    'Feeds': [
        'Rakhel (Feed)'
    ]
}

# Flatten the dictionary to create a product-to-category mapping
product_to_category = {product: category for category, products in categories.items() for product in products}

# Map the product names to their categories
eda_df['product_category'] = eda_df['product'].map(product_to_category)

eda_df.head()

# %%
# Create a list of columns in the desired order
columns = ['country', 'market', 'administrative_region', 'longitude', 'latitude', 'product_code', 
           'product', 'product_category', 'price_category', 'product_source', 'measurement_unit', 
           'currency', 'value', 'year', 'month', 'day_of_week']

# Reorder the DataFrame columns
eda_df = eda_df[columns]

# Display the DataFrame to check the new order
eda_df.head()

# %% [markdown]
# ## 2.3.3. Save the merged dataset in a new CSV file to be used in PowerBI Visualization

# %%
# # Save the merged dataset in a new CSV file 
# eda_df.to_excel('data/Visualization_Data.xlsx', index=False)
# eda_df.head()

# %% [markdown]
# ## 2.3.4. Encoding The Categorical Variables

# %%
# Check for categorical columns
categorical_cols = eda_df.select_dtypes(include=['object']).columns

# Analyze unique values and cardinality
for col in categorical_cols:
    unique_values = eda_df[col].unique()
    num_unique = len(unique_values)
    title = f"Column: {col}"
    print(title)
    print('='*len(title))
    print(f"Number of unique values: {num_unique}")
    print(f"Unique values: {unique_values[:10]}")
    print()

# %% [markdown]
# Based on the analysis of the unique values, this is the encoding strategies:
#
# - **i. One-Hot Encoding:** country, product_category, price_category, currency
#
# One-hot encoding is a method where each unique value in a categorical column is converted into a new binary column. For example, the country column with 13 unique values will be transformed into 13 binary columns, each representing one of the countries. This approach is effective for columns with a relatively small number of unique values (low cardinality) because it ensures that each category is represented distinctly without introducing ordinal relationships.
#
# - **ii. Label Encoding:** product_code, product_source
#
# Label encoding converts each unique category into a distinct integer value. For example, product_code will be converted into integer values from 0 to 136. This approach is suitable for categorical variables where the categories do not have a meaningful ordinal relationship, but the model might benefit from a simple numerical representation.
#
# - **Frequency Encoding:** market, administrative_region, measurement_unit, product
#
# Frequency encoding involves replacing each category with its frequency of occurrence in the dataset. For example, a market with 184 unique values will be encoded with the count of each market's occurrences. This method is useful for high cardinality features as it transforms the categories into numerical values based on their occurrence, potentially capturing the importance of each category based on its frequency.

# %%
# One-Hot Encoding
eda_df = pd.get_dummies(eda_df, columns=['country', 'product_category', 'price_category', 'currency'])

# Label Encoding
label_encoders = {}
for col in ['product_code', 'product_source']:
    le = LabelEncoder()
    eda_df[col] = le.fit_transform(eda_df[col])
    label_encoders[col] = le

# Frequency Encoding Function
def frequency_encoding(df, column):
    freq = df[column].value_counts()
    df[column + '_freq'] = df[column].map(freq)
    df.drop(column, axis=1, inplace=True)
    return df

# Apply Frequency Encoding to specified columns
for col in ['market', 'administrative_region', 'measurement_unit', 'product']:
    eda_df = frequency_encoding(eda_df, col)

# Display the head of the final encoded DataFrame
df_encoded = eda_df
df_encoded.head()

# %% [markdown]
# # 2.4. Modeling

# %% [markdown]
# ## 2.4.1. Data Splitting

# %% [markdown]
# In time series forecasting, the traditional concept of a random 80/20 train-test split isn't used because it doesn't respect the temporal order of the data. Instead, data is split chronologically to maintain the sequence of events, which is crucial for time series analysis. In my case, the train set comprises historical data up to and including December 2022, while the evaluation set consists of data from January 2023 onwards.

# %%
# Set the split point
train_end_year = 2022
train_end_month = 12

# Create train and test datasets
train_set = df_encoded[(df_encoded['year'] < train_end_year) | ((df_encoded['year'] == train_end_year) & (df_encoded['month'] <= train_end_month))]
eval_set = df_encoded[(df_encoded['year'] > train_end_year) | ((df_encoded['year'] == train_end_year) & (df_encoded['month'] > train_end_month))]

# Check the split
print(f"Training Set: {train_set.shape}")
print(f"Evaluation Set: {eval_set.shape}")

# %%
# Display a sample of the train data
train_set.head()

# %%
# Display a sample of the test data
eval_set.head()

# %%
# Separate the target variable and features for training and testing
X_train = df_encoded.drop('value', axis=1)  
y_train = df_encoded['value']


X_eval = eval_set.drop('value', axis=1)  
y_eval = eval_set['value']

print(f"Training Data: {X_train.shape}, {y_train.shape}")
print(f"Evaluation Data: {X_eval.shape}, {y_eval.shape}")

# %% [markdown]
# ## 2.4.2. Feature Scaling

# %%
# Check for numerical columns
num_cols = X_train.select_dtypes(include=['number']).columns

# Analyze unique values to identify columns to scale
for col in num_cols:
    unique_values = X_train[col].unique()
    num_unique = len(unique_values)
    title = f"Column: {col}"
    print(title)
    print('='*len(title))
    print(f"Number of unique values: {num_unique}")
    print(f"Unique values: {unique_values[:10]}")
    print()

# %% [markdown]
# ---
#
# - Many features in the dataset are on different scales (e.g., 'longitude' in degrees and 'value' in monetary units). Without scaling, the features with larger ranges or units will disproportionately affect the model's performance as they will dominate the model's learning process.
# - If one feature ranges from 0 to 1000 and another ranges from 0 to 1, the feature with the larger range will dominate the model's learning process. Scaling ensures that each feature contributes equally.
# - Therefore, these features need to be within the same scale.
#
# ---

# %% [markdown]
# - All features are scaled to a fixed range, typically to have a mean of 0 and a standard deviation of 1, which helps to make sure that no feature dominates due to its larger numerical range.
#
# - Let's identify the columns to scale.
#
# ---

# %%
# Function to automatically select columns for scaling
def get_numerical_columns_for_scaling(df):
    # Initialize a list to hold columns to scale
    columns_to_scale = []
    
    # Loop through each column
    for column in df.columns:
        # Get unique values for the column
        unique_values = df[column].unique()
        num_unique_values = len(unique_values)
        
        # Add the column to the list if it has more than 2 unique values
        if num_unique_values > 2:
            columns_to_scale.append(column)
    
    return columns_to_scale

# Identify numerical columns to scale
numerical_columns_to_scale = get_numerical_columns_for_scaling(X_train)
print(numerical_columns_to_scale)

# %% [markdown]
# Binary columns (0 or 1) are already normalized. Applying standard scaling to these columns might not be meaningful and could even distort their representation. That is why I am selecting features with more than 2 unique values for scaling.

# %%
# Initialize the scaler
scaler = StandardScaler()

# Copy the original data to ensure the original DataFrames are not modified
X_train_final = X_train.copy()
X_eval_final = X_eval.copy()

# Fit and transform the numerical columns in the training set
X_train_final[numerical_columns_to_scale] = scaler.fit_transform(X_train_final[numerical_columns_to_scale])

# Transform the numerical columns in the testing set
X_eval_final[numerical_columns_to_scale] = scaler.transform(X_eval_final[numerical_columns_to_scale])

# %%
# # Check the scaling in the train set
X_train_final.head()

# %%
# Display a sample of the test set
X_eval_final.head()

# %% [markdown]
# The numerical columns have been scaled.
#
# ---

# %% [markdown]
# ## 2.4.3. Model Training and Evaluation

# %%
# Initialize the results dataframe
results_df = pd.DataFrame(columns=['Model', 'RMSLE', 'RMSE', 'MSE', 'MAE'])

# %% [markdown]
# ### Model 1: Linear Regression

# %%
lr_model = LinearRegression()
lr_model.fit(X_train_final, y_train)
lr_predictions = lr_model.predict(X_eval_final)

lr_mse = mean_squared_error(y_eval, lr_predictions)
lr_mae = mean_absolute_error(y_eval, lr_predictions)
y_eval_abs = abs(y_eval)
lr_predictions_abs = abs(lr_predictions)
lr_rmsle = np.sqrt(mean_squared_log_error(y_eval_abs, lr_predictions_abs))

results_lr = pd.DataFrame({'Model': ['Linear Regression'],
                            'RMSLE': [lr_rmsle],
                            'RMSE': [np.sqrt(lr_mse)],
                            'MSE': [lr_mse],
                            'MAE': [lr_mae]}).round(2)

# Print the results_lr dataframe
results_lr

# %% [markdown]
# ### # Model 2: Random Forest Regression

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train_final, y_train)
rf_predictions = rf_model.predict(X_eval_final)

rf_mse = mean_squared_error(y_eval, rf_predictions)
rf_mae = mean_absolute_error(y_eval, rf_predictions)
rf_rmsle = np.sqrt(mean_squared_log_error(abs(y_eval), abs(rf_predictions)))

results_rf = pd.DataFrame({'Model': ['Random Forest'],
                            'RMSLE': [rf_rmsle],
                            'RMSE': [np.sqrt(rf_mse)],
                            'MSE': [rf_mse],
                            'MAE': [rf_mae]}).round(2)

# Print the results_rf dataframe
results_rf

# %% [markdown]
# ### Model 3: Gradient Boosting Regression

# %%
gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)
gb_model.fit(X_train_final, y_train)
gb_predictions = gb_model.predict(X_eval_final)

gb_mse = mean_squared_error(y_eval, gb_predictions)
gb_mae = mean_absolute_error(y_eval, gb_predictions)
gb_rmsle = np.sqrt(mean_squared_log_error(abs(y_eval), abs(gb_predictions)))

results_gb = pd.DataFrame({'Model': ['Gradient Boosting'],
                            'RMSLE': [gb_rmsle],
                            'RMSE': [np.sqrt(gb_mse)],
                            'MSE': [gb_mse],
                            'MAE': [gb_mae]}).round(2)

# Print the results_gb dataframe
results_gb

# %% [markdown]
# ### Model 4: Autoregressive Integrated Moving Average (ARIMA)

# %%
# Define the ARIMA model
p = 1
d = 0
q = 0

# Fit the ARIMA model
arima_model = ARIMA(y_train, order=(p, d, q))
arima_model_fit = arima_model.fit()

# Make predictions
arima_predictions = arima_model_fit.predict(start=len(y_train), end=len(y_train) + len(X_eval) - 1)

# Calculate metrics
arima_mse = mean_squared_error(y_eval, arima_predictions)
arima_rmse = np.sqrt(arima_mse)
arima_mae = mean_absolute_error(y_eval, arima_predictions)
arima_rmsle = np.sqrt(mean_squared_log_error(abs(y_eval), abs(arima_predictions)))

# Store results in DataFrame
results_arima = pd.DataFrame({
    'Model': ['ARIMA'],
    'RMSLE': [arima_rmsle],
    'RMSE': [arima_rmse],
    'MSE': [arima_mse],
    'MAE': [arima_mae]
}).round(2)

# Print the results_arima dataframe
results_arima

# %%
# Append all results to the results dataframe using pd.concat
results_df = pd.concat([results_lr, results_rf, results_gb, results_arima], ignore_index=True)

# Sort the results_df based on RMSLE in ascending order
results_df = results_df.sort_values(by='RMSLE', ascending=True)

# Reset the index of the DataFrame
results_df = results_df.reset_index(drop=True)

# Print the Final Results dataframe
results_df

# %%
# Select the best model based on RMSE
best_model = results_df.iloc[0]['Model']
print(f"\nBest model based on RMSLE: {best_model}")

# %% [markdown]
# The Random Forest model performs the best overall, with the lowest values across all metrics. This indicates it has the most accurate and reliable predictions among the models evaluated. Its low RMSLE suggests it is particularly good at handling predictions with a small range of error. I will now proceed to  tune and optimize its parameters to enhanceits performance.
#
# ---

# %% [markdown]
# ## 2.4.4. Creating a Pre-Processing Pipeline For Model Deployment

# %%
# Custom Transformers

class MissingValueIdentifier(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        # Identifying missing values, no direct transformation
        return X

class AdminRegionImputer(BaseEstimator, TransformerMixin):
    def __init__(self, api_key):
        self.api_key = api_key
        
    def get_admin_reg_from_coords(self, lat, lon):
        url = f'https://maps.googleapis.com/maps/api/geocode/json?latlng={lat},{lon}&key={self.api_key}'
        response = requests.get(url)
        result = response.json()
        if result['status'] == 'OK':
            address_components = result['results'][0]['address_components']
            for component in address_components:
                if 'administrative_area_level_1' in component['types']:
                    return component['long_name']
        return None

    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        # Impute missing admin regions
        X.loc[X['administrative_region'].isnull(), 'administrative_region'] = X.loc[X['administrative_region'].isnull(), ['latitude', 'longitude']].apply(
            lambda row: self.get_admin_reg_from_coords(row['latitude'], row['longitude']),
            axis=1
        )
        return X

class LabelEncoderTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
        self.encoders = {}
        
    def fit(self, X, y=None):
        for col in self.columns:
            le = LabelEncoder()
            le.fit(X[col])
            self.encoders[col] = le
        return self
    
    def transform(self, X):
        X = X.copy()
        for col in self.columns:
            le = self.encoders[col]
            X[col] = le.transform(X[col])
        return X

class FrequencyEncoderTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        for col in self.columns:
            freq = X[col].value_counts()
            X[col + '_freq'] = X[col].map(freq)
            X.drop(col, axis=1, inplace=True)
        return X

# Define categorical and numerical feature lists
categorical_features = data.select_dtypes(include=['object']).columns.tolist()
numerical_features = data.select_dtypes(include=['number']).columns.tolist()


# Define preprocessing for categorical and numerical features
preprocessor = ColumnTransformer(
    transformers=[
        ('categorical', Pipeline(steps=[
            ('missing_value_identifier', MissingValueIdentifier()),
            ('admin_region_imputer', AdminRegionImputer(api_key="YOUR_API_KEY")),
            ('one_hot_encoder', OneHotEncoder(handle_unknown='ignore')),
            ('label_encoder', LabelEncoderTransformer(columns=['product_code', 'product_source'])),
            ('frequency_encoder', FrequencyEncoderTransformer(columns=['market', 'administrative_region', 'measurement_unit', 'product']))
        ]), categorical_features),
        ('numerical', Pipeline(steps=[
            ('scaler', StandardScaler())
        ]), numerical_features)
    ],
)

# Define the full pipeline with preprocessing and classifier
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', rf_model)
])

pipe

# %% [markdown]
# ## 2.4.5. Saving The Best Model and Key Components

# %%
# Define the file path for saving the components
file_path = 'model_and_key_components.pkl'

# Create a dictionary to store the product_categoies, model and preprocessing_pipeline
saved_components = {
    'product_categories': categories,
    'model': rf_model,
    'preprocessing_pipeline': pipe
}

# Save all components in a single pickle file
with open(file_path, 'wb') as file:
    pickle.dump(saved_components, file)

print(f"Components saved successfully to {file_path}")

# %% [markdown]
# # 3. Conclusion

# %% [markdown]
# The analysis of staple food and fuel prices prices across different markets and countries highlights several significant findings. The price variations within markets and between countries reveal substantial disparities that can be attributed to regional supply and demand dynamics, economic conditions, and market stability.
#
# **Major Challenge: Lack of Common Currency**
#
# A major challenge encountered during this analysis is the lack of a common currency for comparing product prices across countries. Without a unified currency, such as the USD, direct price comparisons can be misleading and difficult to interpret. This issue is particularly prominent when comparing price data from Nigeria and Somalia, where significant price differences could be influenced by fluctuations in local currencies and economic conditions.
#
# To address this challenge, I will leverage historical exchange rates to convert prices into a common currency such as the US Dollar, allowing for a more accurate and meaningful comparison. This conversion will be performed prior to the project presentation, ensuring that all price data is standardized and comparable.
#
# **Model Deployment and Interactive Dashboard**
#
# To facilitate ongoing analysis and provide actionable insights, the trained model will be deployed as a web application using the Streamlit framework. This deployment will enable users to interact with the model and visualize price predictions in real-time, enhancing decision-making capabilities and accessibility.
#
# Additionally, an interactive dashboard will be created using Power BI, which will update on a monthly basis. This dashboard will be integrated with the FEWS NET data, which is collected and updated monthly. By providing real-time updates and interactive features, the Power BI dashboard will offer users dynamic insights into price trends and anomalies, supporting better market analysis and strategic planning.
#
# The combination of currency standardization and advanced deployment tools will ensure that the project delivers accurate, actionable, and timely insights into maize grain price variations across different markets and countries.
